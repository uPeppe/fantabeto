# %% [markdown]
# player_match_dataset_creation code for past seasons
#
# Select the season in season variable, and repeat the code if needed

# %%
season = '2021'

# %%
import pandas as pd

rcsv = pd.read_csv('fbref_data/season' + season + '/teams.csv')   
team = pd.DataFrame(rcsv)

rcsv = pd.read_csv('fbref_data/season' + season + '/teams_vs.csv')   
vs_team = pd.DataFrame(rcsv)

for i in range(1, team.shape[1]):
    team = team.rename(columns = {team.columns[i] : 'team_' + team.columns[i]})
    
for i in range(1, vs_team.shape[1]):
    vs_team = vs_team.rename(columns = {vs_team.columns[i] : 'vs_team_' + vs_team.columns[i]})
    
vs_team.pop('team')

team_data = pd.concat([team, vs_team], axis = 1)

team_data['team_idx'] = team_data['team']
for i in range(team_data.shape[0]):
    team_data['team_idx'][i] = team_data['team_idx'][i].split(' ')[-1]

team_data = team_data.set_index('team_idx')

team_data
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_5084\813865162.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_data['team_idx'][i] = team_data['team_idx'][i].split(' ')[-1]
#                      team  team_players_used  team_possession  team_games  \
# team_idx
# Atalanta         Atalanta               30.0             54.6        38.0
# Benevento       Benevento               29.0             42.6        38.0
# Bologna           Bologna               37.0             50.8        38.0
# Cagliari         Cagliari               32.0             44.8        38.0
# Crotone           Crotone               31.0             46.3        38.0
# Fiorentina     Fiorentina               30.0             46.3        38.0
# Genoa               Genoa               34.0             44.8        38.0
# Verona      Hellas Verona               32.0             49.8        38.0
# Inter               Inter               25.0             52.5        38.0
# Juventus         Juventus               30.0             56.9        38.0
# Lazio               Lazio               30.0             53.0        38.0
# Milan               Milan               29.0             51.7        38.0
# Napoli             Napoli               25.0             55.1        38.0
# Parma               Parma               42.0             47.8        38.0
# Roma                 Roma               31.0             52.2        38.0
# Sampdoria       Sampdoria               27.0             45.2        38.0
# Sassuolo         Sassuolo               28.0             60.3        38.0
# Spezia             Spezia               35.0             51.9        38.0
# Torino             Torino               29.0             47.3        38.0
# Udinese           Udinese               33.0             46.3        38.0
#
#             team_games_starts  team_minutes  team_goals  team_assists  \
# team_idx
# Atalanta                418.0        3420.0        90.0          65.0
# Benevento               418.0        3420.0        40.0          26.0
# Bologna                 418.0        3420.0        49.0          38.0
# Cagliari                418.0        3420.0        43.0          30.0
# Crotone                 418.0        3420.0        44.0          27.0
# Fiorentina              418.0        3420.0        44.0          31.0
# Genoa                   418.0        3420.0        46.0          32.0
# Verona                  418.0        3420.0        38.0          30.0
# Inter                   418.0        3420.0        84.0          62.0
# Juventus                418.0        3420.0        76.0          59.0
# Lazio                   418.0        3420.0        59.0          40.0
# Milan                   418.0        3420.0        72.0          47.0
# Napoli                  418.0        3420.0        83.0          56.0
# Parma                   418.0        3420.0        39.0          26.0
# Roma                    418.0        3420.0        67.0          51.0
# Sampdoria               418.0        3420.0        52.0          37.0
# Sassuolo                418.0        3420.0        61.0          36.0
# Spezia                  418.0        3420.0        52.0          37.0
# Torino                  418.0        3420.0        49.0          28.0
# Udinese                 418.0        3420.0        40.0          30.0
#
#             team_pens_made  team_pens_att  ...  vs_team_fouls  vs_team_fouled  \
# team_idx                                   ...
# Atalanta               6.0            7.0  ...          504.0           548.0
# Benevento              5.0            7.0  ...          621.0           463.0
# Bologna                3.0            4.0  ...          495.0           495.0
# Cagliari               4.0            5.0  ...          507.0           496.0
# Crotone                9.0            9.0  ...          524.0           499.0
# Fiorentina             6.0            6.0  ...          545.0           500.0
# Genoa                  4.0            4.0  ...          502.0           501.0
# Verona                 3.0            3.0  ...          557.0           593.0
# Inter                  8.0            9.0  ...          444.0           439.0
# Juventus               8.0           10.0  ...          490.0           483.0
# Lazio                  6.0           10.0  ...          454.0           480.0
# Milan                 15.0           20.0  ...          502.0           486.0
# Napoli                 7.0            8.0  ...          580.0           362.0
# Parma                  5.0            5.0  ...          508.0           486.0
# Roma                   7.0            8.0  ...          453.0           536.0
# Sampdoria              5.0            6.0  ...          520.0           473.0
# Sassuolo              13.0           14.0  ...          502.0           468.0
# Spezia                 4.0            5.0  ...          556.0           548.0
# Torino                 5.0            6.0  ...          632.0           544.0
# Udinese                4.0            4.0  ...          559.0           474.0
#
#             vs_team_offsides  vs_team_pens_won  vs_team_pens_conceded  \
# team_idx
# Atalanta                40.0               5.0                    7.0
# Benevento               94.0               4.0                    7.0
# Bologna                 71.0               6.0                    4.0
# Cagliari                83.0               4.0                    5.0
# Crotone                103.0               4.0                    9.0
# Fiorentina              94.0               9.0                    6.0
# Genoa                   37.0               7.0                    4.0
# Verona                  42.0               6.0                    3.0
# Inter                   32.0               5.0                    9.0
# Juventus                40.0               6.0                   10.0
# Lazio                   43.0              10.0                   10.0
# Milan                   44.0               5.0                   20.0
# Napoli                  72.0               5.0                    8.0
# Parma                   64.0               3.0                    5.0
# Roma                   125.0               5.0                    8.0
# Sampdoria              111.0               5.0                    6.0
# Sassuolo                91.0               5.0                   14.0
# Spezia                 140.0               7.0                    5.0
# Torino                  75.0               8.0                    6.0
# Udinese                 42.0               9.0                    4.0
#
#             vs_team_own_goals  vs_team_ball_recoveries  vs_team_aerials_won  \
# team_idx
# Atalanta                  0.0                   2251.0                506.0
# Benevento                 0.0                   1854.0                615.0
# Bologna                   2.0                   2024.0                594.0
# Cagliari                  0.0                   1920.0                602.0
# Crotone                   1.0                   2130.0                534.0
# Fiorentina                3.0                   1915.0                544.0
# Genoa                     1.0                   2197.0                643.0
# Verona                    5.0                   2102.0                832.0
# Inter                     5.0                   1690.0                428.0
# Juventus                  1.0                   1805.0                378.0
# Lazio                     2.0                   2054.0                510.0
# Milan                     2.0                   1977.0                539.0
# Napoli                    3.0                   1811.0                404.0
# Parma                     0.0                   1950.0                474.0
# Roma                      1.0                   1924.0                414.0
# Sampdoria                 0.0                   2132.0                597.0
# Sassuolo                  3.0                   1843.0                450.0
# Spezia                    0.0                   1985.0                568.0
# Torino                    1.0                   1936.0                622.0
# Udinese                   2.0                   1867.0                442.0
#
#             vs_team_aerials_lost  vs_team_aerials_won_pct
# team_idx
# Atalanta                   633.0                     44.4
# Benevento                  496.0                     55.4
# Bologna                    564.0                     51.3
# Cagliari                   637.0                     48.6
# Crotone                    472.0                     53.1
# Fiorentina                 538.0                     50.3
# Genoa                      505.0                     56.0
# Verona                     749.0                     52.6
# Inter                      439.0                     49.4
# Juventus                   426.0                     47.0
# Lazio                      539.0                     48.6
# Milan                      567.0                     48.7
# Napoli                     414.0                     49.4
# Parma                      630.0                     42.9
# Roma                       428.0                     49.2
# Sampdoria                  628.0                     48.7
# Sassuolo                   408.0                     52.4
# Spezia                     537.0                     51.4
# Torino                     595.0                     51.1
# Udinese                    491.0                     47.4
#
# [20 rows x 321 columns]

# %%
team_data.to_excel('mid_outputs/season' + season + '/team_data.xlsx')

# %%
rx = pd.read_excel('mid_outputs/season' + season + '/players_stats.xlsx', index_col = 3)   
players = pd.DataFrame(rx)

players
# Out:
#                Unnamed: 0    id  r       team     surname initial  fb_ID  age  \
# name
# Donnarumma G.           0   350  P      Milan  Donnarumma       G    629   21
# Szczesny                1   453  P   Juventus    Szczesny     NaN    664   30
# Handanovic              2   250  P      Inter  Handanovic     NaN    635   36
# Gollini                 3   610  P   Atalanta     Gollini     NaN    634   25
# Audero                  4   761  P  Sampdoria      Audero     NaN    620   23
# ...                   ...   ... ..        ...         ...     ...    ...  ...
# Rabbi                 559  5361  A    Bologna       Rabbi     NaN    464   18
# Oddei                 560  5378  A   Sassuolo       Oddei     NaN    400   17
# Karamoko Is.          561  5414  A   Sassuolo    Karamoko       I    267   18
# Correia               562  5419  A   Juventus     Correia     NaN    113   19
# Raimondo              563  5436  A    Bologna    Raimondo     NaN    470   16
#
#                birth_year  games  ...  gk_pct_goal_kicks_launched  \
# name                              ...
# Donnarumma G.        1999      0  ...                        41.5
# Szczesny             1990      0  ...                        10.6
# Handanovic           1984      0  ...                        26.9
# Gollini              1995      0  ...                        63.8
# Audero               1997      0  ...                        64.1
# ...                   ...    ...  ...                         ...
# Rabbi                2001      4  ...                         0.0
# Oddei                2002      5  ...                         0.0
# Karamoko Is.         2002      1  ...                         0.0
# Correia              2001      1  ...                         0.0
# Raimondo             2004      1  ...                         0.0
#
#                gk_goal_kick_length_avg  gk_crosses  gk_crosses_stopped  \
# name
# Donnarumma G.                     33.7       556.0                29.0
# Szczesny                          22.0       399.0                12.0
# Handanovic                        30.8       441.0                13.0
# Gollini                           49.7       234.0                 6.0
# Audero                            45.3       563.0                12.0
# ...                                ...         ...                 ...
# Rabbi                              0.0         0.0                 0.0
# Oddei                              0.0         0.0                 0.0
# Karamoko Is.                       0.0         0.0                 0.0
# Correia                            0.0         0.0                 0.0
# Raimondo                           0.0         0.0                 0.0
#
#                gk_crosses_stopped_pct  gk_def_actions_outside_pen_area  \
# name
# Donnarumma G.                     5.2                             43.0
# Szczesny                          3.0                             37.0
# Handanovic                        2.9                             22.0
# Gollini                           2.6                             39.0
# Audero                            2.1                             34.0
# ...                               ...                              ...
# Rabbi                             0.0                              0.0
# Oddei                             0.0                              0.0
# Karamoko Is.                      0.0                              0.0
# Correia                           0.0                              0.0
# Raimondo                          0.0                              0.0
#
#                gk_def_actions_outside_pen_area_per90  \
# name
# Donnarumma G.                                   1.16
# Szczesny                                        1.24
# Handanovic                                      0.61
# Gollini                                         1.63
# Audero                                          0.92
# ...                                              ...
# Rabbi                                           0.00
# Oddei                                           0.00
# Karamoko Is.                                    0.00
# Correia                                         0.00
# Raimondo                                        0.00
#
#                gk_avg_distance_def_actions  vote_avg  vote_std
# name
# Donnarumma G.                         14.8  6.283784  0.394909
# Szczesny                              16.2  6.216667  0.441273
# Handanovic                            14.9  6.027027  0.505990
# Gollini                               17.4  6.100000  0.632456
# Audero                                14.8  6.378378  0.409439
# ...                                    ...       ...       ...
# Rabbi                                  0.0  6.027304  0.472755
# Oddei                                  0.0  6.207968  0.447162
# Karamoko Is.                           0.0  6.186813  0.444240
# Correia                                0.0  6.600386  0.396770
# Raimondo                               0.0  6.209072  0.275318
#
# [564 rows x 169 columns]

# %%
def player_match_data(player, pteam, oppteam):
    if(not(player in players.index)):
        return None
    
    pdata = players.loc[[player]]
    
    pteam_stats = team_data.loc[[pteam]].rename(index = {pteam : player})
    
    oppteam_stats = team_data.loc[[oppteam]].rename(index = {oppteam : player})
    
    oppteam_stats = oppteam_stats.rename(lambda x: 'opp_' + x, axis='columns')
    
    out = pd.concat([pdata, pteam_stats, oppteam_stats], axis = 1)
    
    return(out)

# %%
test = player_match_data('Immobile', 'Lazio', 'Atalanta')
test.to_excel('tmp/playermatchdata.xlsx')

test
# Out:
#           Unnamed: 0   id  r   team   surname initial  fb_ID  age  birth_year  \
# Immobile         452  785  A  Lazio  Immobile     NaN    250   30        1990
#
#           games  ...  opp_vs_team_fouls  opp_vs_team_fouled  \
# Immobile     35  ...              504.0               548.0
#
#           opp_vs_team_offsides  opp_vs_team_pens_won  \
# Immobile                  40.0                   5.0
#
#           opp_vs_team_pens_conceded  opp_vs_team_own_goals  \
# Immobile                        7.0                    0.0
#
#           opp_vs_team_ball_recoveries  opp_vs_team_aerials_won  \
# Immobile                       2251.0                    506.0
#
#           opp_vs_team_aerials_lost  opp_vs_team_aerials_won_pct
# Immobile                     633.0                         44.4
#
# [1 rows x 811 columns]

# %%
pteam = 'Lazio'
pteam_stats = team_data.loc[[pteam]]
pteam_stats.index[0]
# Out:
# 'Lazio'

# %%
rx = pd.read_excel('tmp/playermatchdata_sel.xlsx', index_col = 0, header = None)   

out = list()

for i in range(1, rx.shape[1]):
        if(rx[i][2] == "x"):
            out.append(rx[i][0])
            
out
# Out:
# ['r',
#  'fb_ID',
#  'games',
#  'games_starts',
#  'minutes',
#  'goals',
#  'assists',
#  'cards_yellow',
#  'cards_red',
#  'xg',
#  'npxg',
#  'shots_on_target',
#  'shots_on_target_pct',
#  'goals_per_shot',
#  'goals_per_shot_on_target',
#  'passes_completed',
#  'passes_pct',
#  'passes_into_final_third',
#  'passes_into_penalty_area',
#  'progressive_passes',
#  'passes_live',
#  'passes_dead',
#  'through_balls',
#  'passes_switches',
#  'crosses',
#  'corner_kicks',
#  'dribble_tackles',
#  'dribbles_vs',
#  'dribble_tackles_pct',
#  'dribbled_past',
#  'blocks',
#  'blocked_shots',
#  'blocked_passes',
#  'interceptions',
#  'clearances',
#  'errors',
#  'touches',
#  'touches_def_pen_area',
#  'touches_def_3rd',
#  'touches_mid_3rd',
#  'touches_att_3rd',
#  'touches_att_pen_area',
#  'touches_live_ball',
#  'dribbles_completed',
#  'dribbles',
#  'dribbles_completed_pct',
#  'carries',
#  'progressive_carries',
#  'carries_into_final_third',
#  'carries_into_penalty_area',
#  'passes_received',
#  'miscontrols',
#  'dispossessed',
#  'fouls',
#  'fouled',
#  'aerials_won',
#  'aerials_lost',
#  'aerials_won_pct',
#  'team_possession',
#  'team_goals_assists_per90',
#  'team_goals_pens_per90',
#  'team_goals_assists_pens_per90',
#  'team_xg_per90',
#  'team_gk_goals_against_per90',
#  'team_gk_save_pct',
#  'team_gk_clean_sheets_pct',
#  'team_passes_pct',
#  'team_passes_pct_medium',
#  'team_passes_pct_long',
#  'team_sca_per90',
#  'team_gca_per90',
#  'team_dribble_tackles_pct',
#  'team_aerials_won_pct',
#  'vs_team_possession',
#  'vs_team_goals_per90',
#  'vs_team_assists_per90',
#  'vs_team_xg_per90',
#  'vs_team_gk_save_pct',
#  'vs_team_gk_clean_sheets_pct',
#  'vs_team_gk_pct_passes_launched',
#  'vs_team_gk_crosses_stopped_pct',
#  'vs_team_shots_on_target_per90',
#  'vs_team_passes_pct',
#  'vs_team_passes_pct_short',
#  'vs_team_passes_pct_medium',
#  'vs_team_passes_pct_long',
#  'vs_team_sca_per90',
#  'vs_team_gca_per90',
#  'vs_team_dribble_tackles_pct',
#  'vs_team_dribbles_completed_pct',
#  'vs_team_aerials_won_pct']

# %%
features_abs = ['r',
 'games',
 'games_starts',                
 'minutes',
 'shots_on_target_pct',
 'goals_per_shot',
 'goals_per_shot_on_target',
 'passes_pct',
 'dribble_tackles_pct',
 'dribbles_completed_pct',
 'aerials_won_pct',
 'team_possession',
 'team_goals_assists_per90',
 'team_goals_pens_per90',
 'team_goals_assists_pens_per90',
 'team_xg_per90',
 'team_gk_goals_against_per90',
 'team_gk_save_pct',
 'team_gk_clean_sheets_pct',
 'team_passes_pct',
 'team_passes_pct_medium',
 'team_passes_pct_long',
 'team_sca_per90',
 'team_gca_per90',
 'team_dribble_tackles_pct',
 'team_aerials_won_pct',
 'vs_team_possession',
 'vs_team_goals_per90',
 'vs_team_assists_per90',
 'vs_team_xg_per90',
 'vs_team_gk_save_pct',
 'vs_team_gk_clean_sheets_pct',
 'vs_team_gk_pct_passes_launched',
 'vs_team_gk_crosses_stopped_pct',
 'vs_team_shots_on_target_per90',
 'vs_team_passes_pct',
 'vs_team_passes_pct_short',
 'vs_team_passes_pct_medium',
 'vs_team_passes_pct_long',
 'vs_team_sca_per90',
 'vs_team_gca_per90',
 'vs_team_dribble_tackles_pct',
 'vs_team_dribbles_completed_pct',
 'vs_team_aerials_won_pct',
 'opp_team_possession',
 'opp_team_goals_assists_per90',
 'opp_team_goals_pens_per90',
 'opp_team_goals_assists_pens_per90',
 'opp_team_xg_per90',
 'opp_team_gk_goals_against_per90',
 'opp_team_gk_save_pct',
 'opp_team_gk_clean_sheets_pct',
 'opp_team_passes_pct',
 'opp_team_passes_pct_medium',
 'opp_team_passes_pct_long',
 'opp_team_sca_per90',
 'opp_team_gca_per90',
 'opp_team_dribble_tackles_pct',
 'opp_team_aerials_won_pct',
 'opp_vs_team_possession',
 'opp_vs_team_goals_per90',
 'opp_vs_team_assists_per90',
 'opp_vs_team_xg_per90',
 'opp_vs_team_gk_save_pct',
 'opp_vs_team_gk_clean_sheets_pct',
 'opp_vs_team_gk_pct_passes_launched',
 'opp_vs_team_gk_crosses_stopped_pct',
 'opp_vs_team_shots_on_target_per90',
 'opp_vs_team_passes_pct',
 'opp_vs_team_passes_pct_short',
 'opp_vs_team_passes_pct_medium',
 'opp_vs_team_passes_pct_long',
 'opp_vs_team_sca_per90',
 'opp_vs_team_gca_per90',
 'opp_vs_team_dribble_tackles_pct',
 'opp_vs_team_dribbles_completed_pct',
 'opp_vs_team_aerials_won_pct',
                
 'vote_avg',
 'vote_std']

features_rel = [
 'goals',
 'assists',
 'cards_yellow',
 'cards_red',
 'xg',
 'npxg',
 'shots_on_target',
 'passes_completed',
 'passes_into_final_third',
 'passes_into_penalty_area',
 'progressive_passes',
 'passes_live',
 'passes_dead',
 'through_balls',
 'passes_switches',
 'crosses',
 'corner_kicks',
 'dribble_tackles',
 'dribbles_vs',
 'dribbled_past',
 'blocks',
 'blocked_shots',
 'blocked_passes',
 'interceptions',
 'clearances',
 'errors',
 'touches',
 'touches_def_pen_area',
 'touches_def_3rd',
 'touches_mid_3rd',
 'touches_att_3rd',
 'touches_att_pen_area',
 'touches_live_ball',
 'dribbles_completed',
 'dribbles',
 'passes_received',
 'miscontrols',
 'dispossessed',
 'fouls',
 'fouled',
 'aerials_won',
 'aerials_lost',
 'carries',
 'progressive_carries',
 'carries_into_final_third',
 'carries_into_penalty_area']

features_rel_gamecorr = [
    'goals',
    'assists',
    'xg',
    'npxg',
    'cards_yellow',
    'cards_red'
]

# %%
def player_match_data_ext(player, pteam, oppteam):
    pdata = player_match_data(player, pteam, oppteam)
    
    if(not isinstance(pdata, pd.DataFrame)):
        return None
    
    out = pd.concat([pdata[features_abs], pdata[features_rel]], axis = 1)
    
    out[features_rel] = out[features_rel] / max(pdata['minutes'][0], 1)
    
    out[features_rel_gamecorr] = out[features_rel_gamecorr] * (pdata['minutes'][0] / max(pdata['games'][0], 1) / 90)
    
    return out

# %%
test = player_match_data_ext('Immobile', 'Lazio', 'Atalanta')

add_columns = test.columns

test
# Out:
#           r  games  games_starts  minutes  shots_on_target_pct  \
# Immobile  A     35            34     2849                 39.3
#
#           goals_per_shot  goals_per_shot_on_target  passes_pct  \
# Immobile            0.14                      0.36        72.6
#
#           dribble_tackles_pct  dribbles_completed_pct  ...  miscontrols  \
# Immobile                 31.8                    57.4  ...     0.024921
#
#           dispossessed     fouls    fouled  aerials_won  aerials_lost  \
# Immobile      0.011934  0.012987  0.015444     0.009126      0.018954
#
#           carries  progressive_carries  carries_into_final_third  \
# Immobile   0.2457             0.025974                  0.015093
#
#           carries_into_penalty_area
# Immobile                   0.013338
#
# [1 rows x 125 columns]

# %%
votes = pd.read_excel('mid_outputs/season' + season + '/players_votes.xlsx', index_col = 0)
votes
# Out:
#        matchday      player      team oppteam  home  vote  goals  assists  \
# 0             1  Sportiello  Atalanta   Lazio     0   6.5     -1        0
# 1             1       Toloi  Atalanta   Lazio     0   6.0      0        0
# 2             1    Djimsiti  Atalanta   Lazio     0   6.5      0        0
# 3             1    Hateboer  Atalanta   Lazio     0   7.5      1        0
# 4             1      Gosens  Atalanta   Lazio     0   7.5      1        1
# ...         ...         ...       ...     ...   ...   ...    ...      ...
# 10569        38       Bessa    Verona  Napoli     0   6.0      0        0
# 10570        38    Zaccagni    Verona  Napoli     0   6.5      0        0
# 10571        38        Ilic    Verona  Napoli     0   6.5      0        0
# 10572        38     Lasagna    Verona  Napoli     0   5.5      0        0
# 10573        38     Kalinic    Verona  Napoli     0   5.5      0        0
#
#        cards_malus  fantavote
# 0              0.0        5.5
# 1              0.5        5.5
# 2              0.5        6.0
# 3              0.0       10.5
# 4              0.0       11.5
# ...            ...        ...
# 10569          0.0        6.0
# 10570          0.0        6.5
# 10571          0.5        6.0
# 10572          0.0        5.5
# 10573          0.0        5.5
#
# [10574 rows x 10 columns]

# %%
db = votes.copy()

delta = pd.DataFrame(columns = add_columns)

for i in range(db.shape[0]):
    ext_data = player_match_data_ext(db['player'][i], db['team'][i], db['oppteam'][i])
    
    if(not isinstance(ext_data, pd.DataFrame)):
        continue
    
    ext_data = ext_data.rename(index = {db['player'][i] : i})
    
    delta = pd.concat([delta, ext_data], axis = 0)
    
    if(i % 100 == 0):
        print(i)
    
db = pd.concat([db, delta], axis = 1)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 700
# 800
# 900
# 1000
# 1100
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500

# %%
db
# Out:
#        matchday      player      team oppteam  home  vote  goals  assists  \
# 0             1  Sportiello  Atalanta   Lazio     0   6.5     -1        0
# 1             1       Toloi  Atalanta   Lazio     0   6.0      0        0
# 2             1    Djimsiti  Atalanta   Lazio     0   6.5      0        0
# 3             1    Hateboer  Atalanta   Lazio     0   7.5      1        0
# 4             1      Gosens  Atalanta   Lazio     0   7.5      1        1
# ...         ...         ...       ...     ...   ...   ...    ...      ...
# 10569        38       Bessa    Verona  Napoli     0   6.0      0        0
# 10570        38    Zaccagni    Verona  Napoli     0   6.5      0        0
# 10571        38        Ilic    Verona  Napoli     0   6.5      0        0
# 10572        38     Lasagna    Verona  Napoli     0   5.5      0        0
# 10573        38     Kalinic    Verona  Napoli     0   5.5      0        0
#
#        cards_malus  fantavote  ... miscontrols dispossessed     fouls  \
# 0              0.0        5.5  ...    0.000000     0.000000  0.000000
# 1              0.5        5.5  ...    0.008672     0.005124  0.014978
# 2              0.5        6.0  ...    0.009524     0.003429  0.011810
# 3              0.0       10.5  ...    0.015891     0.006810  0.011351
# 4              0.0       11.5  ...    0.016250     0.006342  0.019818
# ...            ...        ...  ...         ...          ...       ...
# 10569          0.0        6.0  ...    0.029268     0.019512  0.026016
# 10570          0.0        6.5  ...    0.028363     0.024530  0.013798
# 10571          0.5        6.0  ...    0.014169     0.007084  0.012534
# 10572          0.0        5.5  ...    0.040253     0.014207  0.025257
# 10573          0.0        5.5  ...    0.032926     0.012230  0.025400
#
#          fouled  aerials_won  aerials_lost   carries  progressive_carries  \
# 0      0.000000     0.000000      0.000000  0.000000             0.000000
# 1      0.005912     0.018132      0.011037  0.430430             0.015767
# 2      0.009905     0.028952      0.011810  0.460571             0.016000
# 3      0.004540     0.013053      0.011351  0.386493             0.023269
# 4      0.010305     0.014269      0.007927  0.417757             0.028141
# ...         ...          ...           ...       ...                  ...
# 10569  0.009756     0.003252      0.026016  0.401626             0.030894
# 10570  0.041778     0.018015      0.021847  0.329628             0.045228
# 10571  0.015804     0.019074      0.013624  0.407084             0.020708
# 10572  0.016575     0.020521      0.037885  0.183899             0.022099
# 10573  0.031985     0.015992      0.047977  0.199436             0.006585
#
#        carries_into_final_third  carries_into_penalty_area
# 0                      0.000000                   0.000000
# 1                      0.014190                   0.001182
# 2                      0.019810                   0.001905
# 3                      0.017026                   0.003973
# 4                      0.022592                   0.006342
# ...                         ...                        ...
# 10569                  0.030894                   0.006504
# 10570                  0.026447                   0.017631
# 10571                  0.015804                   0.000545
# 10572                  0.014207                   0.013418
# 10573                  0.004704                   0.002822
#
# [10574 rows x 135 columns]

# %%
db = db.drop(db[db.r == 'P'].index) # remove goalkeepers
db = db.drop(db[db.r != db.r].index) # remove non extisting players
db = db.drop(db[db.r != db.r].index) # remove non extisting players
db = db.drop(db[db.xg != db.xg].index)

# %%
db
# Out:
#        matchday    player      team oppteam  home  vote  goals  assists  \
# 1             1     Toloi  Atalanta   Lazio     0   6.0      0        0
# 2             1  Djimsiti  Atalanta   Lazio     0   6.5      0        0
# 3             1  Hateboer  Atalanta   Lazio     0   7.5      1        0
# 4             1    Gosens  Atalanta   Lazio     0   7.5      1        1
# 5             1  Palomino  Atalanta   Lazio     0   6.5      0        0
# ...         ...       ...       ...     ...   ...   ...    ...      ...
# 10569        38     Bessa    Verona  Napoli     0   6.0      0        0
# 10570        38  Zaccagni    Verona  Napoli     0   6.5      0        0
# 10571        38      Ilic    Verona  Napoli     0   6.5      0        0
# 10572        38   Lasagna    Verona  Napoli     0   5.5      0        0
# 10573        38   Kalinic    Verona  Napoli     0   5.5      0        0
#
#        cards_malus  fantavote  ... miscontrols dispossessed     fouls  \
# 1              0.5        5.5  ...    0.008672     0.005124  0.014978
# 2              0.5        6.0  ...    0.009524     0.003429  0.011810
# 3              0.0       10.5  ...    0.015891     0.006810  0.011351
# 4              0.0       11.5  ...    0.016250     0.006342  0.019818
# 5              0.0        6.5  ...    0.005354     0.002059  0.019769
# ...            ...        ...  ...         ...          ...       ...
# 10569          0.0        6.0  ...    0.029268     0.019512  0.026016
# 10570          0.0        6.5  ...    0.028363     0.024530  0.013798
# 10571          0.5        6.0  ...    0.014169     0.007084  0.012534
# 10572          0.0        5.5  ...    0.040253     0.014207  0.025257
# 10573          0.0        5.5  ...    0.032926     0.012230  0.025400
#
#          fouled  aerials_won  aerials_lost   carries  progressive_carries  \
# 1      0.005912     0.018132      0.011037  0.430430             0.015767
# 2      0.009905     0.028952      0.011810  0.460571             0.016000
# 3      0.004540     0.013053      0.011351  0.386493             0.023269
# 4      0.010305     0.014269      0.007927  0.417757             0.028141
# 5      0.006590     0.024300      0.018534  0.404448             0.006590
# ...         ...          ...           ...       ...                  ...
# 10569  0.009756     0.003252      0.026016  0.401626             0.030894
# 10570  0.041778     0.018015      0.021847  0.329628             0.045228
# 10571  0.015804     0.019074      0.013624  0.407084             0.020708
# 10572  0.016575     0.020521      0.037885  0.183899             0.022099
# 10573  0.031985     0.015992      0.047977  0.199436             0.006585
#
#        carries_into_final_third  carries_into_penalty_area
# 1                      0.014190                   0.001182
# 2                      0.019810                   0.001905
# 3                      0.017026                   0.003973
# 4                      0.022592                   0.006342
# 5                      0.004942                   0.000824
# ...                         ...                        ...
# 10569                  0.030894                   0.006504
# 10570                  0.026447                   0.017631
# 10571                  0.015804                   0.000545
# 10572                  0.014207                   0.013418
# 10573                  0.004704                   0.002822
#
# [9663 rows x 135 columns]

# %%
db.to_excel('mid_outputs/season' + season + '/database_entries.xlsx')

# %% [markdown]
# Goalkeepers

# %%
features_abs_gk = [
 'gk_games',
 'gk_games_starts',
 'gk_minutes',
 'gk_goals_against_per90', 
 'gk_save_pct',
 'gk_clean_sheets_pct',
 'gk_psxg_net_per90',
 'gk_passes_pct_launched',
 'gk_pct_passes_launched',
 'gk_passes_length_avg',
 'gk_pct_goal_kicks_launched',
 'gk_goal_kick_length_avg',
 'gk_crosses_stopped_pct',
 'gk_def_actions_outside_pen_area_per90',
 'gk_avg_distance_def_actions',
    
 'team_possession',
 'team_goals_assists_per90',
 'team_goals_pens_per90',
 'team_goals_assists_pens_per90',
 'team_xg_per90',
 'team_gk_goals_against_per90',
 'team_gk_save_pct',
 'team_gk_clean_sheets_pct',
 'team_passes_pct',
 'team_passes_pct_medium',
 'team_passes_pct_long',
 'team_sca_per90',
 'team_gca_per90',
 'team_dribble_tackles_pct',
 'team_aerials_won_pct',
 'vs_team_possession',
 'vs_team_goals_per90',
 'vs_team_assists_per90',
 'vs_team_xg_per90',
 'vs_team_gk_save_pct',
 'vs_team_gk_clean_sheets_pct',
 'vs_team_gk_pct_passes_launched',
 'vs_team_gk_crosses_stopped_pct',
 'vs_team_shots_on_target_per90',
 'vs_team_passes_pct',
 'vs_team_passes_pct_short',
 'vs_team_passes_pct_medium',
 'vs_team_passes_pct_long',
 'vs_team_sca_per90',
 'vs_team_gca_per90',
 'vs_team_dribble_tackles_pct',
 'vs_team_dribbles_completed_pct',
 'vs_team_aerials_won_pct',
 'opp_team_possession',
 'opp_team_goals_assists_per90',
 'opp_team_goals_pens_per90',
 'opp_team_goals_assists_pens_per90',
 'opp_team_xg_per90',
 'opp_team_gk_goals_against_per90',
 'opp_team_gk_save_pct',
 'opp_team_gk_clean_sheets_pct',
 'opp_team_passes_pct',
 'opp_team_passes_pct_medium',
 'opp_team_passes_pct_long',
 'opp_team_sca_per90',
 'opp_team_gca_per90',
 'opp_team_dribble_tackles_pct',
 'opp_team_aerials_won_pct',
 'opp_vs_team_possession',
 'opp_vs_team_goals_per90',
 'opp_vs_team_assists_per90',
 'opp_vs_team_xg_per90',
 'opp_vs_team_gk_save_pct',
 'opp_vs_team_gk_clean_sheets_pct',
 'opp_vs_team_gk_pct_passes_launched',
 'opp_vs_team_gk_crosses_stopped_pct',
 'opp_vs_team_shots_on_target_per90',
 'opp_vs_team_passes_pct',
 'opp_vs_team_passes_pct_short',
 'opp_vs_team_passes_pct_medium',
 'opp_vs_team_passes_pct_long',
 'opp_vs_team_sca_per90',
 'opp_vs_team_gca_per90',
 'opp_vs_team_dribble_tackles_pct',
 'opp_vs_team_dribbles_completed_pct',
 'opp_vs_team_aerials_won_pct',
                
 'vote_avg',
 'vote_std']

features_rel_gk = [
 'gk_shots_on_target_against',
 'gk_saves',
 'gk_free_kick_goals_against',
 'gk_corner_kick_goals_against',
 'gk_own_goals_against',
 'gk_psxg',
 'gk_psnpxg_per_shot_on_target_against',
 'gk_psxg_net',
 'gk_passes_completed_launched',
 'gk_passes_launched',
 'gk_passes',
 'gk_passes_throws',
 'gk_goal_kicks',
 'gk_crosses',
 'gk_crosses_stopped',
]

# %%
def player_match_data_ext_gk(player, pteam, oppteam):
    pdata = player_match_data(player, pteam, oppteam)
    
    if(not isinstance(pdata, pd.DataFrame)):
        return None
    
    if(pdata['gk_games'][0] <= 0):
        return None
    
    out = pd.concat([pdata[features_abs_gk], pdata[features_rel_gk]], axis = 1)
    
    out[features_rel_gk] = out[features_rel_gk] / max(pdata['minutes'][0], 1)

    return out

# %%
test = player_match_data_ext_gk('Consigli', 'Sassuolo', 'Atalanta')

add_columns_gk = test.columns

test
# Out:
#           gk_games  gk_games_starts  gk_minutes  gk_goals_against_per90  \
# Consigli      37.0             37.0      3322.0                    1.71
#
#           gk_save_pct  gk_clean_sheets_pct  gk_psxg_net_per90  \
# Consigli         67.8                  8.1              -0.16
#
#           gk_passes_pct_launched  gk_pct_passes_launched  \
# Consigli                    43.2                    29.0
#
#           gk_passes_length_avg  ...  gk_psxg  \
# Consigli                  30.9  ...     56.0
#
#           gk_psnpxg_per_shot_on_target_against  gk_psxg_net  \
# Consigli                                  0.28         -6.0
#
#           gk_passes_completed_launched  gk_passes_launched  gk_passes  \
# Consigli                         186.0               431.0     1219.0
#
#           gk_passes_throws  gk_goal_kicks  gk_crosses  gk_crosses_stopped
# Consigli             174.0          246.0       491.0                21.0
#
# [1 rows x 98 columns]

# %%
db_gk = votes.copy()

delta = pd.DataFrame(columns = add_columns_gk)

for i in range(db_gk.shape[0]):
    ext_data = player_match_data_ext_gk(db_gk['player'][i], db_gk['team'][i], db_gk['oppteam'][i])
    
    if(i % 100 == 0):
        print(i)
        
    if(not isinstance(ext_data, pd.DataFrame)):
        continue
    
    ext_data = ext_data.rename(index = {db_gk['player'][i] : i})
    
    delta = pd.concat([delta, ext_data], axis = 0)
    
    
    
db_gk = pd.concat([db_gk, delta], axis = 1)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200

# %%
db_gk = db_gk.drop(db_gk[db_gk.gk_games != db_gk.gk_games].index) # remove non extisting players

# %%
db_gk.to_excel('mid_outputs/season' + season + '/database_entries_gk.xlsx')
