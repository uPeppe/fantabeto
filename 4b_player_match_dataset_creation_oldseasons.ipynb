# %% [markdown]
# player_match_dataset_creation code for past seasons
#
# Select the season in season variable, and repeat the code if needed

# %%
season = '2122'

# %%
import pandas as pd

rcsv = pd.read_csv('fbref_data/season' + season + '/teams.csv')   
team = pd.DataFrame(rcsv)

rcsv = pd.read_csv('fbref_data/season' + season + '/teams_vs.csv')   
vs_team = pd.DataFrame(rcsv)

for i in range(1, team.shape[1]):
    team = team.rename(columns = {team.columns[i] : 'team_' + team.columns[i]})
    
for i in range(1, vs_team.shape[1]):
    vs_team = vs_team.rename(columns = {vs_team.columns[i] : 'vs_team_' + vs_team.columns[i]})
    
vs_team.pop('team')

team_data = pd.concat([team, vs_team], axis = 1)

team_data['team_idx'] = team_data['team']
for i in range(team_data.shape[0]):
    team_data['team_idx'][i] = team_data['team_idx'][i].split(' ')[-1]

team_data = team_data.set_index('team_idx')

team_data
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_1244\813865162.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_data['team_idx'][i] = team_data['team_idx'][i].split(' ')[-1]
#                       team  team_players_used  team_possession  team_games  \
# team_idx
# Atalanta          Atalanta               32.0             55.0        38.0
# Bologna            Bologna               36.0             50.6        38.0
# Cagliari          Cagliari               33.0             44.5        38.0
# Empoli              Empoli               28.0             47.4        38.0
# Fiorentina      Fiorentina               28.0             57.7        38.0
# Genoa                Genoa               40.0             43.9        38.0
# Verona       Hellas Verona               31.0             50.6        38.0
# Inter                Inter               27.0             56.5        38.0
# Juventus          Juventus               32.0             51.5        38.0
# Lazio                Lazio               27.0             55.4        38.0
# Milan                Milan               28.0             54.0        38.0
# Napoli              Napoli               27.0             58.3        38.0
# Roma                  Roma               29.0             51.4        38.0
# Salernitana    Salernitana               42.0             41.2        38.0
# Sampdoria        Sampdoria               34.0             46.1        38.0
# Sassuolo          Sassuolo               29.0             54.9        38.0
# Spezia              Spezia               30.0             42.7        38.0
# Torino              Torino               31.0             53.3        38.0
# Udinese            Udinese               29.0             42.7        38.0
# Venezia            Venezia               39.0             42.3        38.0
#
#              team_games_starts  team_minutes  team_goals  team_assists  \
# team_idx
# Atalanta                 418.0        3420.0        62.0          48.0
# Bologna                  418.0        3420.0        43.0          34.0
# Cagliari                 418.0        3420.0        34.0          26.0
# Empoli                   418.0        3420.0        47.0          27.0
# Fiorentina               418.0        3420.0        59.0          33.0
# Genoa                    418.0        3420.0        26.0          19.0
# Verona                   418.0        3420.0        63.0          44.0
# Inter                    418.0        3420.0        83.0          57.0
# Juventus                 418.0        3420.0        56.0          37.0
# Lazio                    418.0        3420.0        74.0          48.0
# Milan                    418.0        3420.0        66.0          39.0
# Napoli                   418.0        3420.0        74.0          46.0
# Roma                     418.0        3420.0        58.0          31.0
# Salernitana              418.0        3420.0        32.0          19.0
# Sampdoria                418.0        3420.0        42.0          29.0
# Sassuolo                 418.0        3420.0        60.0          39.0
# Spezia                   418.0        3420.0        38.0          25.0
# Torino                   418.0        3420.0        43.0          27.0
# Udinese                  418.0        3420.0        58.0          36.0
# Venezia                  418.0        3420.0        34.0          23.0
#
#              team_pens_made  team_pens_att  ...  vs_team_fouls  \
# team_idx                                    ...
# Atalanta                5.0            6.0  ...          491.0
# Bologna                 4.0            5.0  ...          527.0
# Cagliari                3.0            4.0  ...          526.0
# Empoli                  7.0            7.0  ...          488.0
# Fiorentina              9.0           12.0  ...          585.0
# Genoa                   6.0            7.0  ...          523.0
# Verona                  7.0            8.0  ...          463.0
# Inter                   7.0           11.0  ...          440.0
# Juventus                5.0            6.0  ...          525.0
# Lazio                   7.0            9.0  ...          474.0
# Milan                   5.0            8.0  ...          533.0
# Napoli                 10.0           14.0  ...          517.0
# Roma                    7.0            9.0  ...          497.0
# Salernitana             4.0            5.0  ...          546.0
# Sampdoria               2.0            4.0  ...          538.0
# Sassuolo                7.0            7.0  ...          519.0
# Spezia                  3.0            5.0  ...          474.0
# Torino                  6.0            6.0  ...          485.0
# Udinese                 3.0            4.0  ...          494.0
# Venezia                 3.0            5.0  ...          476.0
#
#              vs_team_fouled  vs_team_offsides  vs_team_pens_won  \
# team_idx
# Atalanta              488.0              69.0               4.0
# Bologna               416.0              88.0               8.0
# Cagliari              524.0              76.0               6.0
# Empoli                482.0              66.0               7.0
# Fiorentina            441.0             119.0               4.0
# Genoa                 530.0              59.0               4.0
# Verona                534.0              32.0               3.0
# Inter                 441.0              34.0               3.0
# Juventus              471.0              35.0               5.0
# Lazio                 418.0              73.0               6.0
# Milan                 440.0              63.0               3.0
# Napoli                415.0              60.0               0.0
# Roma                  477.0              81.0               5.0
# Salernitana           463.0              63.0               6.0
# Sampdoria             471.0              64.0               1.0
# Sassuolo              434.0             142.0               6.0
# Spezia                477.0              62.0               8.0
# Torino                611.0              60.0              10.0
# Udinese               537.0              57.0               6.0
# Venezia               492.0              48.0               5.0
#
#              vs_team_pens_conceded  vs_team_own_goals  \
# team_idx
# Atalanta                       6.0                3.0
# Bologna                        5.0                1.0
# Cagliari                       4.0                0.0
# Empoli                         7.0                3.0
# Fiorentina                    12.0                0.0
# Genoa                          7.0                1.0
# Verona                         8.0                2.0
# Inter                         11.0                1.0
# Juventus                       6.0                1.0
# Lazio                          9.0                3.0
# Milan                          8.0                3.0
# Napoli                        14.0                0.0
# Roma                           9.0                1.0
# Salernitana                    5.0                1.0
# Sampdoria                      4.0                4.0
# Sassuolo                       7.0                4.0
# Spezia                         5.0                3.0
# Torino                         6.0                3.0
# Udinese                        4.0                3.0
# Venezia                        5.0                0.0
#
#              vs_team_ball_recoveries  vs_team_aerials_won  \
# team_idx
# Atalanta                      2240.0                518.0
# Bologna                       2032.0                520.0
# Cagliari                      2112.0                742.0
# Empoli                        2051.0                549.0
# Fiorentina                    1825.0                456.0
# Genoa                         2257.0                743.0
# Verona                        2206.0                733.0
# Inter                         1767.0                476.0
# Juventus                      1894.0                440.0
# Lazio                         1956.0                427.0
# Milan                         2106.0                517.0
# Napoli                        1963.0                403.0
# Roma                          1970.0                441.0
# Salernitana                   2043.0                506.0
# Sampdoria                     2174.0                506.0
# Sassuolo                      2041.0                404.0
# Spezia                        2064.0                589.0
# Torino                        1989.0                891.0
# Udinese                       2010.0                534.0
# Venezia                       2059.0                583.0
#
#              vs_team_aerials_lost  vs_team_aerials_won_pct
# team_idx
# Atalanta                    685.0                     43.1
# Bologna                     492.0                     51.4
# Cagliari                    696.0                     51.6
# Empoli                      427.0                     56.3
# Fiorentina                  469.0                     49.3
# Genoa                       635.0                     53.9
# Verona                      689.0                     51.5
# Inter                       549.0                     46.4
# Juventus                    550.0                     44.4
# Lazio                       411.0                     51.0
# Milan                       521.0                     49.8
# Napoli                      393.0                     50.6
# Roma                        524.0                     45.7
# Salernitana                 657.0                     43.5
# Sampdoria                   609.0                     45.4
# Sassuolo                    343.0                     54.1
# Spezia                      530.0                     52.6
# Torino                      781.0                     53.3
# Udinese                     453.0                     54.1
# Venezia                     564.0                     50.8
#
# [20 rows x 313 columns]

# %%
team_data.to_excel('mid_outputs/season' + season + '/team_data.xlsx')

# %%
rx = pd.read_excel('mid_outputs/season' + season + '/players_stats.xlsx', index_col = 3)   
players = pd.DataFrame(rx)

players
# Out:
#             Unnamed: 0    id  r        team     surname initial  fb_ID  age  \
# name
# Maignan              0  4312  P       Milan     Maignan     NaN    647   26
# Szczesny             1   453  P    Juventus    Szczesny     NaN    675   31
# Ospina               2  2468  P      Napoli      Ospina     NaN    653   32
# Handanovic           3   250  P       Inter  Handanovic     NaN    644   37
# Berisha              4   316  P      Torino     Berisha     NaN    637   32
# ...                ...   ... ..         ...         ...     ...    ...  ...
# Kokorin            545  5391  A  Fiorentina     Kokorin     NaN    283   30
# Munteanu           546  5458  A  Fiorentina    Munteanu     NaN     -1    0
# Buksa              547  5459  A       Genoa       Buksa     NaN     83   18
# Kaio Jorge         548  5505  A    Juventus       Jorge     NaN    266   19
# Lazetic            549  5785  A       Milan     Lazetic     NaN     -1    0
#
#             birth_year  games  ...  gk_pct_goal_kicks_launched  \
# name                           ...
# Maignan           1995      0  ...                        38.9
# Szczesny          1990      0  ...                        29.7
# Ospina            1988      0  ...                        14.1
# Handanovic        1984      0  ...                        20.4
# Berisha           1989      0  ...                        87.2
# ...                ...    ...  ...                         ...
# Kokorin           1991      6  ...                         0.0
# Munteanu             0      0  ...                         0.0
# Buksa             2003      4  ...                         0.0
# Kaio Jorge        2002      9  ...                         0.0
# Lazetic              0      0  ...                         0.0
#
#             gk_goal_kick_length_avg  gk_crosses  gk_crosses_stopped  \
# name
# Maignan                        36.5       347.0                25.0
# Szczesny                       31.5       481.0                24.0
# Ospina                         22.5       353.0                18.0
# Handanovic                     26.5       393.0                15.0
# Berisha                        58.6       148.0                 7.0
# ...                             ...         ...                 ...
# Kokorin                         0.0         0.0                 0.0
# Munteanu                        0.0         0.0                 0.0
# Buksa                           0.0         0.0                 0.0
# Kaio Jorge                      0.0         0.0                 0.0
# Lazetic                         0.0         0.0                 0.0
#
#             gk_crosses_stopped_pct  gk_def_actions_outside_pen_area  \
# name
# Maignan                        7.2                             45.0
# Szczesny                       5.0                             25.0
# Ospina                         5.1                             31.0
# Handanovic                     3.8                             10.0
# Berisha                        4.7                             10.0
# ...                            ...                              ...
# Kokorin                        0.0                              0.0
# Munteanu                       0.0                              0.0
# Buksa                          0.0                              0.0
# Kaio Jorge                     0.0                              0.0
# Lazetic                        0.0                              0.0
#
#             gk_def_actions_outside_pen_area_per90  \
# name
# Maignan                                      1.41
# Szczesny                                     0.76
# Ospina                                       1.00
# Handanovic                                   0.27
# Berisha                                      1.00
# ...                                           ...
# Kokorin                                      0.00
# Munteanu                                     0.00
# Buksa                                        0.00
# Kaio Jorge                                   0.00
# Lazetic                                      0.00
#
#             gk_avg_distance_def_actions  vote_avg  vote_std
# name
# Maignan                            16.8  6.265625  0.483871
# Szczesny                           13.5  6.121212  0.628012
# Ospina                             17.0  6.258065  0.332899
# Handanovic                         11.2  6.162162  0.533399
# Berisha                            14.6  6.100000  0.700000
# ...                                 ...       ...       ...
# Kokorin                             0.0  5.901518  0.269227
# Munteanu                            0.0  6.215233  0.275498
# Buksa                               0.0  6.035319  0.591212
# Kaio Jorge                          0.0  6.137790  0.468234
# Lazetic                             0.0  6.325366  0.472207
#
# [550 rows x 165 columns]

# %%
def player_match_data(player, pteam, oppteam):
    if(not(player in players.index)):
        return None
    
    pdata = players.loc[[player]]
    
    pteam_stats = team_data.loc[[pteam]].rename(index = {pteam : player})
    
    oppteam_stats = team_data.loc[[oppteam]].rename(index = {oppteam : player})
    
    oppteam_stats = oppteam_stats.rename(lambda x: 'opp_' + x, axis='columns')
    
    out = pd.concat([pdata, pteam_stats, oppteam_stats], axis = 1)
    
    return(out)

# %%
test = player_match_data('Immobile', 'Lazio', 'Atalanta')
test.to_excel('tmp/playermatchdata.xlsx')

test
# Out:
#           Unnamed: 0   id  r   team   surname initial  fb_ID  age  birth_year  \
# Immobile         438  785  A  Lazio  Immobile     NaN    258   31        1990
#
#           games  ...  opp_vs_team_fouls  opp_vs_team_fouled  \
# Immobile     31  ...              491.0               488.0
#
#           opp_vs_team_offsides  opp_vs_team_pens_won  \
# Immobile                  69.0                   4.0
#
#           opp_vs_team_pens_conceded  opp_vs_team_own_goals  \
# Immobile                        6.0                    3.0
#
#           opp_vs_team_ball_recoveries  opp_vs_team_aerials_won  \
# Immobile                       2240.0                    518.0
#
#           opp_vs_team_aerials_lost  opp_vs_team_aerials_won_pct
# Immobile                     685.0                         43.1
#
# [1 rows x 791 columns]

# %%
pteam = 'Lazio'
pteam_stats = team_data.loc[[pteam]]
pteam_stats.index[0]
# Out:
# 'Lazio'

# %%
rx = pd.read_excel('tmp/playermatchdata_sel.xlsx', index_col = 0, header = None)   

out = list()

for i in range(1, rx.shape[1]):
        if(rx[i][2] == "x"):
            out.append(rx[i][0])
            
out
# Out:
# ['r',
#  'fb_ID',
#  'games',
#  'games_starts',
#  'minutes',
#  'goals',
#  'assists',
#  'cards_yellow',
#  'cards_red',
#  'xg',
#  'npxg',
#  'shots_on_target',
#  'shots_on_target_pct',
#  'goals_per_shot',
#  'goals_per_shot_on_target',
#  'passes_completed',
#  'passes_pct',
#  'passes_into_final_third',
#  'passes_into_penalty_area',
#  'progressive_passes',
#  'passes_live',
#  'passes_dead',
#  'through_balls',
#  'passes_switches',
#  'crosses',
#  'corner_kicks',
#  'dribble_tackles',
#  'dribbles_vs',
#  'dribble_tackles_pct',
#  'dribbled_past',
#  'blocks',
#  'blocked_shots',
#  'blocked_passes',
#  'interceptions',
#  'clearances',
#  'errors',
#  'touches',
#  'touches_def_pen_area',
#  'touches_def_3rd',
#  'touches_mid_3rd',
#  'touches_att_3rd',
#  'touches_att_pen_area',
#  'touches_live_ball',
#  'dribbles_completed',
#  'dribbles',
#  'dribbles_completed_pct',
#  'passes_received',
#  'miscontrols',
#  'dispossessed',
#  'fouls',
#  'fouled',
#  'aerials_won',
#  'aerials_lost',
#  'aerials_won_pct',
#  'team_possession',
#  'team_goals_assists_per90',
#  'team_goals_pens_per90',
#  'team_goals_assists_pens_per90',
#  'team_xg_per90',
#  'team_gk_goals_against_per90',
#  'team_gk_save_pct',
#  'team_gk_clean_sheets_pct',
#  'team_passes_pct',
#  'team_passes_pct_medium',
#  'team_passes_pct_long',
#  'team_sca_per90',
#  'team_gca_per90',
#  'team_dribble_tackles_pct',
#  'team_aerials_won_pct',
#  'vs_team_possession',
#  'vs_team_goals_per90',
#  'vs_team_assists_per90',
#  'vs_team_xg_per90',
#  'vs_team_gk_save_pct',
#  'vs_team_gk_clean_sheets_pct',
#  'vs_team_gk_pct_passes_launched',
#  'vs_team_gk_crosses_stopped_pct',
#  'vs_team_shots_on_target_per90',
#  'vs_team_passes_pct',
#  'vs_team_passes_pct_short',
#  'vs_team_passes_pct_medium',
#  'vs_team_passes_pct_long',
#  'vs_team_sca_per90',
#  'vs_team_gca_per90',
#  'vs_team_dribble_tackles_pct',
#  'vs_team_dribbles_completed_pct',
#  'vs_team_aerials_won_pct']

# %%
features_abs = ['r',
 'games',
 'games_starts',                
 'minutes',
 'shots_on_target_pct',
 'goals_per_shot',
 'goals_per_shot_on_target',
 'passes_pct',
 'dribble_tackles_pct',
 'dribbles_completed_pct',
 'aerials_won_pct',
 'team_possession',
 'team_goals_assists_per90',
 'team_goals_pens_per90',
 'team_goals_assists_pens_per90',
 'team_xg_per90',
 'team_gk_goals_against_per90',
 'team_gk_save_pct',
 'team_gk_clean_sheets_pct',
 'team_passes_pct',
 'team_passes_pct_medium',
 'team_passes_pct_long',
 'team_sca_per90',
 'team_gca_per90',
 'team_dribble_tackles_pct',
 'team_aerials_won_pct',
 'vs_team_possession',
 'vs_team_goals_per90',
 'vs_team_assists_per90',
 'vs_team_xg_per90',
 'vs_team_gk_save_pct',
 'vs_team_gk_clean_sheets_pct',
 'vs_team_gk_pct_passes_launched',
 'vs_team_gk_crosses_stopped_pct',
 'vs_team_shots_on_target_per90',
 'vs_team_passes_pct',
 'vs_team_passes_pct_short',
 'vs_team_passes_pct_medium',
 'vs_team_passes_pct_long',
 'vs_team_sca_per90',
 'vs_team_gca_per90',
 'vs_team_dribble_tackles_pct',
 'vs_team_dribbles_completed_pct',
 'vs_team_aerials_won_pct',
 'opp_team_possession',
 'opp_team_goals_assists_per90',
 'opp_team_goals_pens_per90',
 'opp_team_goals_assists_pens_per90',
 'opp_team_xg_per90',
 'opp_team_gk_goals_against_per90',
 'opp_team_gk_save_pct',
 'opp_team_gk_clean_sheets_pct',
 'opp_team_passes_pct',
 'opp_team_passes_pct_medium',
 'opp_team_passes_pct_long',
 'opp_team_sca_per90',
 'opp_team_gca_per90',
 'opp_team_dribble_tackles_pct',
 'opp_team_aerials_won_pct',
 'opp_vs_team_possession',
 'opp_vs_team_goals_per90',
 'opp_vs_team_assists_per90',
 'opp_vs_team_xg_per90',
 'opp_vs_team_gk_save_pct',
 'opp_vs_team_gk_clean_sheets_pct',
 'opp_vs_team_gk_pct_passes_launched',
 'opp_vs_team_gk_crosses_stopped_pct',
 'opp_vs_team_shots_on_target_per90',
 'opp_vs_team_passes_pct',
 'opp_vs_team_passes_pct_short',
 'opp_vs_team_passes_pct_medium',
 'opp_vs_team_passes_pct_long',
 'opp_vs_team_sca_per90',
 'opp_vs_team_gca_per90',
 'opp_vs_team_dribble_tackles_pct',
 'opp_vs_team_dribbles_completed_pct',
 'opp_vs_team_aerials_won_pct',
                
 'vote_avg',
 'vote_std']

features_rel = [
 'goals',
 'assists',
 'cards_yellow',
 'cards_red',
 'xg',
 'npxg',
 'shots_on_target',
 'passes_completed',
 'passes_into_final_third',
 'passes_into_penalty_area',
 'progressive_passes',
 'passes_live',
 'passes_dead',
 'through_balls',
 'passes_switches',
 'crosses',
 'corner_kicks',
 'dribble_tackles',
 'dribbles_vs',
 'dribbled_past',
 'blocks',
 'blocked_shots',
 'blocked_passes',
 'interceptions',
 'clearances',
 'errors',
 'touches',
 'touches_def_pen_area',
 'touches_def_3rd',
 'touches_mid_3rd',
 'touches_att_3rd',
 'touches_att_pen_area',
 'touches_live_ball',
 'dribbles_completed',
 'dribbles',
 'passes_received',
 'miscontrols',
 'dispossessed',
 'fouls',
 'fouled',
 'aerials_won',
 'aerials_lost']

features_rel_gamecorr = [
    'goals',
    'assists',
    'xg',
    'npxg',
    'cards_yellow',
    'cards_red'
]

# %%
def player_match_data_ext(player, pteam, oppteam):
    pdata = player_match_data(player, pteam, oppteam)
    
    if(not isinstance(pdata, pd.DataFrame)):
        return None
    
    out = pd.concat([pdata[features_abs], pdata[features_rel]], axis = 1)
    
    out[features_rel] = out[features_rel] / max(pdata['minutes'][0], 1)
    
    out[features_rel_gamecorr] = out[features_rel_gamecorr] * (pdata['minutes'][0] / max(pdata['games'][0], 1) / 90)
    
    return out

# %%
test = player_match_data_ext('Immobile', 'Lazio', 'Atalanta')

add_columns = test.columns

test
# Out:
#           r  games  games_starts  minutes  shots_on_target_pct  \
# Immobile  A     31            31     2711                 45.9
#
#           goals_per_shot  goals_per_shot_on_target  passes_pct  \
# Immobile            0.18                       0.4        77.0
#
#           dribble_tackles_pct  dribbles_completed_pct  ...  touches_live_ball  \
# Immobile                  6.7                    47.5  ...           0.430468
#
#           dribbles_completed  dribbles  passes_received  miscontrols  \
# Immobile            0.007008  0.014755         0.362966     0.028403
#
#           dispossessed     fouls    fouled  aerials_won  aerials_lost
# Immobile       0.01623  0.013279  0.014386     0.008115      0.016968
#
# [1 rows x 121 columns]

# %%
votes = pd.read_excel('mid_outputs/season' + season + '/players_votes.xlsx', index_col = 0)
votes
# Out:
#        matchday         player      team oppteam  home  vote  goals  assists  \
# 0             1          Musso  Atalanta  Torino     0   6.0     -1        0
# 1             1  Pezzella Giu.  Atalanta  Torino     0   6.0      0        0
# 2             1       Djimsiti  Atalanta  Torino     0   6.0      0        0
# 3             1         Gosens  Atalanta  Torino     0   5.5      0        0
# 4             1       Palomino  Atalanta  Torino     0   6.5      0        0
# ...         ...            ...       ...     ...   ...   ...    ...      ...
# 10649        38         Tameze    Verona   Lazio     0   5.5      0        0
# 10650        38         Hongla    Verona   Lazio     0   7.0      1        0
# 10651        38        Lasagna    Verona   Lazio     0   7.0      1        0
# 10652        38        Caprari    Verona   Lazio     0   6.0      0        0
# 10653        38        Simeone    Verona   Lazio     0   7.0      1        0
#
#        cards_malus  fantavote
# 0              0.5        4.5
# 1              0.0        6.0
# 2              0.0        6.0
# 3              0.0        5.5
# 4              0.0        6.5
# ...            ...        ...
# 10649          0.0        5.5
# 10650          0.5        9.5
# 10651          0.5        9.5
# 10652          0.0        6.0
# 10653          0.0       10.0
#
# [10654 rows x 10 columns]

# %%
db = votes.copy()

delta = pd.DataFrame(columns = add_columns)

for i in range(db.shape[0]):
    ext_data = player_match_data_ext(db['player'][i], db['team'][i], db['oppteam'][i])
    
    if(not isinstance(ext_data, pd.DataFrame)):
        continue
    
    ext_data = ext_data.rename(index = {db['player'][i] : i})
    
    delta = pd.concat([delta, ext_data], axis = 0)
    
    if(i % 100 == 0):
        print(i)
    
db = pd.concat([db, delta], axis = 1)
# Out:
# 0
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600

# %%
db
# Out:
#        matchday         player      team oppteam  home  vote  goals  assists  \
# 0             1          Musso  Atalanta  Torino     0   6.0     -1        0
# 1             1  Pezzella Giu.  Atalanta  Torino     0   6.0      0        0
# 2             1       Djimsiti  Atalanta  Torino     0   6.0      0        0
# 3             1         Gosens  Atalanta  Torino     0   5.5      0        0
# 4             1       Palomino  Atalanta  Torino     0   6.5      0        0
# ...         ...            ...       ...     ...   ...   ...    ...      ...
# 10649        38         Tameze    Verona   Lazio     0   5.5      0        0
# 10650        38         Hongla    Verona   Lazio     0   7.0      1        0
# 10651        38        Lasagna    Verona   Lazio     0   7.0      1        0
# 10652        38        Caprari    Verona   Lazio     0   6.0      0        0
# 10653        38        Simeone    Verona   Lazio     0   7.0      1        0
#
#        cards_malus  fantavote  ... touches_live_ball dribbles_completed  \
# 0              0.5        6.5  ...          0.000000           0.000000
# 1              0.0        6.0  ...          0.728545           0.007463
# 2              0.0        6.0  ...          0.731826           0.001773
# 3              0.0        5.5  ...          0.745562           0.000000
# 4              0.0        6.5  ...          0.752620           0.002246
# ...            ...        ...  ...               ...                ...
# 10649          0.0        5.5  ...          0.629371           0.013209
# 10650          0.5        9.5  ...          0.582181           0.001536
# 10651          0.5        9.5  ...          0.369932           0.008446
# 10652          0.0        6.0  ...          0.602410           0.023731
# 10653          0.0       10.0  ...          0.407086           0.008669
#
#        dribbles passes_received  miscontrols  dispossessed     fouls  \
# 0      0.000000        0.000000     0.000000      0.000000  0.000000
# 1      0.017724        0.458022     0.016791      0.011194  0.017724
# 2      0.002660        0.460550     0.007979      0.001330  0.009309
# 3      0.005917        0.473373     0.017751      0.000000  0.005917
# 4      0.002994        0.399326     0.005614      0.002620  0.014596
# ...         ...             ...          ...           ...       ...
# 10649  0.023310        0.358197     0.019814      0.010101  0.012821
# 10650  0.007680        0.341014     0.018433      0.012289  0.023041
# 10651  0.016047        0.262669     0.046453      0.022804  0.016047
# 10652  0.043447        0.453815     0.033954      0.019715  0.015334
# 10653  0.022993        0.320392     0.051263      0.030155  0.021108
#
#          fouled  aerials_won  aerials_lost
# 0      0.000000     0.000000      0.000000
# 1      0.027985     0.013060      0.013060
# 2      0.006206     0.025266      0.011968
# 3      0.011834     0.023669      0.005917
# 4      0.006362     0.039296      0.017964
# ...         ...          ...           ...
# 10649  0.013209     0.023699      0.021368
# 10650  0.007680     0.023041      0.026114
# 10651  0.008446     0.026182      0.041385
# 10652  0.027017     0.002921      0.009858
# 10653  0.021862     0.022616      0.040709
#
# [10654 rows x 131 columns]

# %%
db = db.drop(db[db.r == 'P'].index) # remove goalkeepers
db = db.drop(db[db.r != db.r].index) # remove non extisting players
db = db.drop(db[db.r != db.r].index) # remove non extisting players
db = db.drop(db[db.xg != db.xg].index)

# %%
db
# Out:
#        matchday         player      team oppteam  home  vote  goals  assists  \
# 1             1  Pezzella Giu.  Atalanta  Torino     0   6.0      0        0
# 2             1       Djimsiti  Atalanta  Torino     0   6.0      0        0
# 3             1         Gosens  Atalanta  Torino     0   5.5      0        0
# 4             1       Palomino  Atalanta  Torino     0   6.5      0        0
# 5             1        Demiral  Atalanta  Torino     0   5.5      0        0
# ...         ...            ...       ...     ...   ...   ...    ...      ...
# 10649        38         Tameze    Verona   Lazio     0   5.5      0        0
# 10650        38         Hongla    Verona   Lazio     0   7.0      1        0
# 10651        38        Lasagna    Verona   Lazio     0   7.0      1        0
# 10652        38        Caprari    Verona   Lazio     0   6.0      0        0
# 10653        38        Simeone    Verona   Lazio     0   7.0      1        0
#
#        cards_malus  fantavote  ... touches_live_ball dribbles_completed  \
# 1              0.0        6.0  ...          0.728545           0.007463
# 2              0.0        6.0  ...          0.731826           0.001773
# 3              0.0        5.5  ...          0.745562           0.000000
# 4              0.0        6.5  ...          0.752620           0.002246
# 5              0.5        5.0  ...          0.553469           0.001043
# ...            ...        ...  ...               ...                ...
# 10649          0.0        5.5  ...          0.629371           0.013209
# 10650          0.5        9.5  ...          0.582181           0.001536
# 10651          0.5        9.5  ...          0.369932           0.008446
# 10652          0.0        6.0  ...          0.602410           0.023731
# 10653          0.0       10.0  ...          0.407086           0.008669
#
#        dribbles passes_received  miscontrols  dispossessed     fouls  \
# 1      0.017724        0.458022     0.016791      0.011194  0.017724
# 2      0.002660        0.460550     0.007979      0.001330  0.009309
# 3      0.005917        0.473373     0.017751      0.000000  0.005917
# 4      0.002994        0.399326     0.005614      0.002620  0.014596
# 5      0.002087        0.283255     0.007825      0.002608  0.015128
# ...         ...             ...          ...           ...       ...
# 10649  0.023310        0.358197     0.019814      0.010101  0.012821
# 10650  0.007680        0.341014     0.018433      0.012289  0.023041
# 10651  0.016047        0.262669     0.046453      0.022804  0.016047
# 10652  0.043447        0.453815     0.033954      0.019715  0.015334
# 10653  0.022993        0.320392     0.051263      0.030155  0.021108
#
#          fouled  aerials_won  aerials_lost
# 1      0.027985     0.013060      0.013060
# 2      0.006206     0.025266      0.011968
# 3      0.011834     0.023669      0.005917
# 4      0.006362     0.039296      0.017964
# 5      0.008346     0.044340      0.019301
# ...         ...          ...           ...
# 10649  0.013209     0.023699      0.021368
# 10650  0.007680     0.023041      0.026114
# 10651  0.008446     0.026182      0.041385
# 10652  0.027017     0.002921      0.009858
# 10653  0.021862     0.022616      0.040709
#
# [9567 rows x 131 columns]

# %%
db.to_excel('mid_outputs/season' + season + '/database_entries.xlsx')

# %%
features_abs_gk = [
 'gk_games',
 'gk_games_starts',
 'gk_minutes',
 'gk_goals_against_per90', 
 'gk_save_pct',
 'gk_clean_sheets_pct',
 'gk_psxg_net_per90',
 'gk_passes_pct_launched',
 'gk_pct_passes_launched',
 'gk_passes_length_avg',
 'gk_pct_goal_kicks_launched',
 'gk_goal_kick_length_avg',
 'gk_crosses_stopped_pct',
 'gk_def_actions_outside_pen_area_per90',
 'gk_avg_distance_def_actions',
    
 'team_possession',
 'team_goals_assists_per90',
 'team_goals_pens_per90',
 'team_goals_assists_pens_per90',
 'team_xg_per90',
 'team_gk_goals_against_per90',
 'team_gk_save_pct',
 'team_gk_clean_sheets_pct',
 'team_passes_pct',
 'team_passes_pct_medium',
 'team_passes_pct_long',
 'team_sca_per90',
 'team_gca_per90',
 'team_dribble_tackles_pct',
 'team_aerials_won_pct',
 'vs_team_possession',
 'vs_team_goals_per90',
 'vs_team_assists_per90',
 'vs_team_xg_per90',
 'vs_team_gk_save_pct',
 'vs_team_gk_clean_sheets_pct',
 'vs_team_gk_pct_passes_launched',
 'vs_team_gk_crosses_stopped_pct',
 'vs_team_shots_on_target_per90',
 'vs_team_passes_pct',
 'vs_team_passes_pct_short',
 'vs_team_passes_pct_medium',
 'vs_team_passes_pct_long',
 'vs_team_sca_per90',
 'vs_team_gca_per90',
 'vs_team_dribble_tackles_pct',
 'vs_team_dribbles_completed_pct',
 'vs_team_aerials_won_pct',
 'opp_team_possession',
 'opp_team_goals_assists_per90',
 'opp_team_goals_pens_per90',
 'opp_team_goals_assists_pens_per90',
 'opp_team_xg_per90',
 'opp_team_gk_goals_against_per90',
 'opp_team_gk_save_pct',
 'opp_team_gk_clean_sheets_pct',
 'opp_team_passes_pct',
 'opp_team_passes_pct_medium',
 'opp_team_passes_pct_long',
 'opp_team_sca_per90',
 'opp_team_gca_per90',
 'opp_team_dribble_tackles_pct',
 'opp_team_aerials_won_pct',
 'opp_vs_team_possession',
 'opp_vs_team_goals_per90',
 'opp_vs_team_assists_per90',
 'opp_vs_team_xg_per90',
 'opp_vs_team_gk_save_pct',
 'opp_vs_team_gk_clean_sheets_pct',
 'opp_vs_team_gk_pct_passes_launched',
 'opp_vs_team_gk_crosses_stopped_pct',
 'opp_vs_team_shots_on_target_per90',
 'opp_vs_team_passes_pct',
 'opp_vs_team_passes_pct_short',
 'opp_vs_team_passes_pct_medium',
 'opp_vs_team_passes_pct_long',
 'opp_vs_team_sca_per90',
 'opp_vs_team_gca_per90',
 'opp_vs_team_dribble_tackles_pct',
 'opp_vs_team_dribbles_completed_pct',
 'opp_vs_team_aerials_won_pct',
                
 'vote_avg',
 'vote_std']

features_rel_gk = [
 'gk_shots_on_target_against',
 'gk_saves',
 'gk_free_kick_goals_against',
 'gk_corner_kick_goals_against',
 'gk_own_goals_against',
 'gk_psxg',
 'gk_psnpxg_per_shot_on_target_against',
 'gk_psxg_net',
 'gk_passes_completed_launched',
 'gk_passes_launched',
 'gk_passes',
 'gk_passes_throws',
 'gk_goal_kicks',
 'gk_crosses',
 'gk_crosses_stopped',
]

# %%
def player_match_data_ext_gk(player, pteam, oppteam):
    pdata = player_match_data(player, pteam, oppteam)
    
    if(not isinstance(pdata, pd.DataFrame)):
        return None
    
    if(pdata['gk_games'][0] <= 0):
        return None
    
    out = pd.concat([pdata[features_abs_gk], pdata[features_rel_gk]], axis = 1)
    
    out[features_rel_gk] = out[features_rel_gk] / max(pdata['minutes'][0], 1)

    return out

# %%
test = player_match_data_ext_gk('Consigli', 'Sassuolo', 'Atalanta')

add_columns_gk = test.columns

test
# Out:
#           gk_games  gk_games_starts  gk_minutes  gk_goals_against_per90  \
# Consigli      37.0             37.0      3322.0                    1.71
#
#           gk_save_pct  gk_clean_sheets_pct  gk_psxg_net_per90  \
# Consigli         67.8                  8.1              -0.16
#
#           gk_passes_pct_launched  gk_pct_passes_launched  \
# Consigli                    43.2                    29.0
#
#           gk_passes_length_avg  ...  gk_psxg  \
# Consigli                  30.9  ...     56.0
#
#           gk_psnpxg_per_shot_on_target_against  gk_psxg_net  \
# Consigli                                  0.28         -6.0
#
#           gk_passes_completed_launched  gk_passes_launched  gk_passes  \
# Consigli                         186.0               431.0     1219.0
#
#           gk_passes_throws  gk_goal_kicks  gk_crosses  gk_crosses_stopped
# Consigli             174.0          246.0       491.0                21.0
#
# [1 rows x 98 columns]

# %%
db_gk = votes.copy()

delta = pd.DataFrame(columns = add_columns_gk)

for i in range(db_gk.shape[0]):
    ext_data = player_match_data_ext_gk(db_gk['player'][i], db_gk['team'][i], db_gk['oppteam'][i])
    
    if(i % 100 == 0):
        print(i)
        
    if(not isinstance(ext_data, pd.DataFrame)):
        continue
    
    ext_data = ext_data.rename(index = {db_gk['player'][i] : i})
    
    delta = pd.concat([delta, ext_data], axis = 0)
    
    
    
db_gk = pd.concat([db_gk, delta], axis = 1)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200

# %%
db_gk = db_gk.drop(db_gk[db_gk.gk_games != db_gk.gk_games].index) # remove non extisting players

# %%
db_gk.to_excel('mid_outputs/season' + season + '/database_entries_gk.xlsx')
