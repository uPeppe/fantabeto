# %% [markdown]
# player_match_dataset_creation code for past seasons
#
# Select the season in season variable, and repeat the code if needed

# %%
season = '2223'

# %%
import pandas as pd

rcsv = pd.read_csv('fbref_data/season' + season + '/teams.csv')   
team = pd.DataFrame(rcsv)

rcsv = pd.read_csv('fbref_data/season' + season + '/teams_vs.csv')   
vs_team = pd.DataFrame(rcsv)

for i in range(1, team.shape[1]):
    team = team.rename(columns = {team.columns[i] : 'team_' + team.columns[i]})
    
for i in range(1, vs_team.shape[1]):
    vs_team = vs_team.rename(columns = {vs_team.columns[i] : 'vs_team_' + vs_team.columns[i]})
    
vs_team.pop('team')

team_data = pd.concat([team, vs_team], axis = 1)

team_data['team_idx'] = team_data['team']
for i in range(team_data.shape[0]):
    team_data.loc[i, 'team_idx'] = team_data.loc[i, 'team_idx'].split(' ')[-1]

team_data = team_data.set_index('team_idx')

team_data
# Out:
# C:\Users\Peppe\AppData\Local\Temp\ipykernel_7752\813865162.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_data['team_idx'][i] = team_data['team_idx'][i].split(' ')[-1]
#                       team  team_players_used  team_possession  team_games  \
# team_idx
# Atalanta          Atalanta               27.0             49.9        38.0
# Bologna            Bologna               27.0             54.7        38.0
# Cremonese        Cremonese               33.0             42.1        38.0
# Empoli              Empoli               32.0             47.3        38.0
# Fiorentina      Fiorentina               30.0             56.1        38.0
# Verona       Hellas Verona               36.0             41.2        38.0
# Inter                Inter               25.0             55.7        38.0
# Juventus          Juventus               29.0             49.6        38.0
# Lazio                Lazio               24.0             52.1        38.0
# Lecce                Lecce               29.0             41.3        38.0
# Milan                Milan               30.0             55.6        38.0
# Monza                Monza               31.0             55.2        38.0
# Napoli              Napoli               27.0             61.8        38.0
# Roma                  Roma               30.0             48.6        38.0
# Salernitana    Salernitana               30.0             44.9        38.0
# Sampdoria        Sampdoria               40.0             46.1        38.0
# Sassuolo          Sassuolo               31.0             49.2        38.0
# Spezia              Spezia               34.0             47.4        38.0
# Torino              Torino               28.0             53.2        38.0
# Udinese            Udinese               30.0             48.0        38.0
#
#              team_games_starts  team_minutes  team_goals  team_assists  \
# team_idx
# Atalanta                 418.0        3420.0        64.0          42.0
# Bologna                  418.0        3420.0        52.0          41.0
# Cremonese                418.0        3420.0        35.0          18.0
# Empoli                   418.0        3420.0        35.0          20.0
# Fiorentina               418.0        3420.0        51.0          37.0
# Verona                   418.0        3420.0        29.0          22.0
# Inter                    418.0        3420.0        68.0          50.0
# Juventus                 418.0        3420.0        56.0          41.0
# Lazio                    418.0        3420.0        59.0          37.0
# Lecce                    418.0        3420.0        31.0          21.0
# Milan                    418.0        3420.0        61.0          49.0
# Monza                    418.0        3420.0        46.0          31.0
# Napoli                   418.0        3420.0        75.0          57.0
# Roma                     418.0        3420.0        50.0          33.0
# Salernitana              418.0        3420.0        46.0          34.0
# Sampdoria                418.0        3420.0        23.0          18.0
# Sassuolo                 418.0        3420.0        46.0          30.0
# Spezia                   418.0        3420.0        29.0          18.0
# Torino                   418.0        3420.0        41.0          34.0
# Udinese                  418.0        3420.0        46.0          41.0
#
#              team_pens_made  team_pens_att  ...  vs_team_fouls  \
# team_idx                                    ...
# Atalanta                6.0            8.0  ...          406.0
# Bologna                 6.0            6.0  ...          451.0
# Cremonese               5.0            7.0  ...          434.0
# Empoli                  2.0            2.0  ...          488.0
# Fiorentina              4.0            6.0  ...          542.0
# Verona                  1.0            1.0  ...          410.0
# Inter                   4.0            5.0  ...          436.0
# Juventus                3.0            6.0  ...          427.0
# Lazio                   6.0            8.0  ...          500.0
# Lecce                   4.0            6.0  ...          461.0
# Milan                   5.0            5.0  ...          462.0
# Monza                   5.0            6.0  ...          534.0
# Napoli                  8.0           10.0  ...          495.0
# Roma                    7.0           10.0  ...          533.0
# Salernitana             2.0            2.0  ...          478.0
# Sampdoria               1.0            2.0  ...          530.0
# Sassuolo                9.0           10.0  ...          479.0
# Spezia                  4.0            4.0  ...          407.0
# Torino                  2.0            2.0  ...          413.0
# Udinese                 1.0            2.0  ...          505.0
#
#              vs_team_fouled  vs_team_offsides  vs_team_pens_won  \
# team_idx
# Atalanta              438.0              50.0               1.0
# Bologna               452.0              58.0               6.0
# Cremonese             432.0              72.0               4.0
# Empoli                422.0              75.0               4.0
# Fiorentina            459.0              93.0               5.0
# Verona                518.0              44.0               2.0
# Inter                 412.0              36.0               3.0
# Juventus              412.0              53.0               2.0
# Lazio                 376.0              63.0               2.0
# Lecce                 521.0              64.0               5.0
# Milan                 430.0              41.0               5.0
# Monza                 466.0              55.0               1.0
# Napoli                363.0              50.0               1.0
# Roma                  417.0              22.0               2.0
# Salernitana           447.0              72.0              11.0
# Sampdoria             480.0              90.0               8.0
# Sassuolo              376.0             119.0               2.0
# Spezia                478.0              76.0               5.0
# Torino                476.0              42.0               4.0
# Udinese               458.0              61.0               5.0
#
#              vs_team_pens_conceded  vs_team_own_goals  \
# team_idx
# Atalanta                       8.0                2.0
# Bologna                        6.0                1.0
# Cremonese                      7.0                1.0
# Empoli                         2.0                2.0
# Fiorentina                     6.0                2.0
# Verona                         1.0                2.0
# Inter                          5.0                3.0
# Juventus                       6.0                0.0
# Lazio                          8.0                1.0
# Lecce                          6.0                2.0
# Milan                          5.0                3.0
# Monza                          6.0                2.0
# Napoli                        10.0                2.0
# Roma                           9.0                0.0
# Salernitana                    2.0                2.0
# Sampdoria                      2.0                1.0
# Sassuolo                      10.0                1.0
# Spezia                         4.0                2.0
# Torino                         2.0                1.0
# Udinese                        2.0                1.0
#
#              vs_team_ball_recoveries  vs_team_aerials_won  \
# team_idx
# Atalanta                      2239.0                483.0
# Bologna                       2005.0                447.0
# Cremonese                     2131.0                730.0
# Empoli                        1953.0                519.0
# Fiorentina                    1910.0                517.0
# Verona                        2125.0                735.0
# Inter                         1767.0                415.0
# Juventus                      1893.0                477.0
# Lazio                         2041.0                381.0
# Lecce                         2030.0                728.0
# Milan                         1972.0                478.0
# Monza                         1983.0                441.0
# Napoli                        1901.0                403.0
# Roma                          1979.0                429.0
# Salernitana                   2106.0                585.0
# Sampdoria                     2079.0                636.0
# Sassuolo                      1928.0                438.0
# Spezia                        2038.0                570.0
# Torino                        1940.0                629.0
# Udinese                       1933.0                406.0
#
#              vs_team_aerials_lost  vs_team_aerials_won_pct
# team_idx
# Atalanta                    575.0                     45.7
# Bologna                     369.0                     54.8
# Cremonese                   562.0                     56.5
# Empoli                      434.0                     54.5
# Fiorentina                  588.0                     46.8
# Verona                      810.0                     47.6
# Inter                       500.0                     45.4
# Juventus                    486.0                     49.5
# Lazio                       399.0                     48.8
# Lecce                       567.0                     56.2
# Milan                       561.0                     46.0
# Monza                       448.0                     49.6
# Napoli                      483.0                     45.5
# Roma                        543.0                     44.1
# Salernitana                 528.0                     52.6
# Sampdoria                   617.0                     50.8
# Sassuolo                    375.0                     53.9
# Spezia                      535.0                     51.6
# Torino                      590.0                     51.6
# Udinese                     477.0                     46.0
#
# [20 rows x 303 columns]

# %%
team_data.to_excel('mid_outputs/season' + season + '/team_data.xlsx')

# %%
rx = pd.read_excel('mid_outputs/season' + season + '/players_stats.xlsx', index_col = 3)   
players = pd.DataFrame(rx)

players
# Out:
#                      Unnamed: 0    id  r       team    surname initial  fb_ID  \
# name
# Meret                         0   572  P     Napoli      Meret     NaN    620
# Provedel                      1  2814  P      Lazio   Provedel     NaN    632
# Vicario                       2  4964  P     Empoli    Vicario     NaN    649
# Szczesny                      3   453  P   Juventus   Szczesny     NaN    644
# Falcone                       4  2134  P      Lecce    Falcone     NaN    612
# ...                         ...   ... ..        ...        ...     ...    ...
# De Luca                     538  5512  A  Sampdoria       Luca     NaN    151
# Voelkerling Persson         539  5837  A      Lecce    Persson     NaN    565
# Montevago                   540  6113  A  Sampdoria  Montevago     NaN    365
# Krollis                     541  6143  A     Spezia    Krollis     NaN    288
# Vivaldo                     542  6160  A    Udinese    Vivaldo     NaN     -1
#
#                      age  birth_year  games  ...  gk_pct_goal_kicks_launched  \
# name                                         ...
# Meret                 25        1997      0  ...                        20.2
# Provedel              28        1994      0  ...                        33.3
# Vicario               25        1996      0  ...                        50.0
# Szczesny              32        1990      0  ...                        43.1
# Falcone               27        1995      0  ...                        79.1
# ...                  ...         ...    ...  ...                         ...
# De Luca               24        1998      2  ...                         0.0
# Voelkerling Persson   19        2003      9  ...                         0.0
# Montevago             19        2003      6  ...                         0.0
# Krollis               20        2001      4  ...                         0.0
# Vivaldo                0           0      0  ...                         0.0
#
#                      gk_goal_kick_length_avg  gk_crosses  gk_crosses_stopped  \
# name
# Meret                                   26.9       335.0                11.0
# Provedel                                33.2       493.0                21.0
# Vicario                                 42.9       606.0                34.0
# Szczesny                                38.3       389.0                11.0
# Falcone                                 53.5       534.0                23.0
# ...                                      ...         ...                 ...
# De Luca                                  0.0         0.0                 0.0
# Voelkerling Persson                      0.0         0.0                 0.0
# Montevago                                0.0         0.0                 0.0
# Krollis                                  0.0         0.0                 0.0
# Vivaldo                                  0.0         0.0                 0.0
#
#                      gk_crosses_stopped_pct  gk_def_actions_outside_pen_area  \
# name
# Meret                                   3.3                             39.0
# Provedel                                4.3                             55.0
# Vicario                                 5.6                             22.0
# Szczesny                                2.8                             21.0
# Falcone                                 4.3                             42.0
# ...                                     ...                              ...
# De Luca                                 0.0                              0.0
# Voelkerling Persson                     0.0                              0.0
# Montevago                               0.0                              0.0
# Krollis                                 0.0                              0.0
# Vivaldo                                 0.0                              0.0
#
#                      gk_def_actions_outside_pen_area_per90  \
# name
# Meret                                                 1.15
# Provedel                                              1.45
# Vicario                                               0.71
# Szczesny                                              0.76
# Falcone                                               1.11
# ...                                                    ...
# De Luca                                               0.00
# Voelkerling Persson                                   0.00
# Montevago                                             0.00
# Krollis                                               0.00
# Vivaldo                                               0.00
#
#                      gk_avg_distance_def_actions  vote_avg  vote_std
# name
# Meret                                       17.0  6.176471  0.400043
# Provedel                                    16.5  6.263158  0.409378
# Vicario                                     11.5  6.403226  0.447562
# Szczesny                                    14.7  6.107143  0.309295
# Falcone                                     14.1  6.250000  0.547122
# ...                                          ...       ...       ...
# De Luca                                      0.0  5.871240  0.394770
# Voelkerling Persson                          0.0  6.132748  0.474211
# Montevago                                    0.0  5.722482  0.229188
# Krollis                                      0.0  6.357731  0.405367
# Vivaldo                                      0.0  6.006617  0.274006
#
# [543 rows x 160 columns]

# %%
def player_match_data(player, pteam, oppteam):
    if(not(player in players.index)):
        return None
    
    pdata = players.loc[[player]]
    
    pteam_stats = team_data.loc[[pteam]].rename(index = {pteam : player})
    
    oppteam_stats = team_data.loc[[oppteam]].rename(index = {oppteam : player})
    
    oppteam_stats = oppteam_stats.rename(lambda x: 'opp_' + x, axis='columns')
    
    out = pd.concat([pdata, pteam_stats, oppteam_stats], axis = 1)
    
    return(out)

# %%
test = player_match_data('Immobile', 'Lazio', 'Atalanta')
test.to_excel('tmp/playermatchdata.xlsx')

test
# Out:
#           Unnamed: 0   id  r   team   surname initial  fb_ID  age  birth_year  \
# Immobile         448  785  A  Lazio  Immobile     NaN    264   32        1990
#
#           games  ...  opp_vs_team_fouls  opp_vs_team_fouled  \
# Immobile     31  ...              406.0               438.0
#
#           opp_vs_team_offsides  opp_vs_team_pens_won  \
# Immobile                  50.0                   1.0
#
#           opp_vs_team_pens_conceded  opp_vs_team_own_goals  \
# Immobile                        8.0                    2.0
#
#           opp_vs_team_ball_recoveries  opp_vs_team_aerials_won  \
# Immobile                       2239.0                    483.0
#
#           opp_vs_team_aerials_lost  opp_vs_team_aerials_won_pct
# Immobile                     575.0                         45.7
#
# [1 rows x 766 columns]

# %%
pteam = 'Lazio'
pteam_stats = team_data.loc[[pteam]]
pteam_stats.index[0]
# Out:
# 'Lazio'

# %%
rx = pd.read_excel('tmp/playermatchdata_sel.xlsx', index_col = 0, header = None)   

out = list()

for i in range(1, rx.shape[1]):
        if(rx[i][2] == "x"):
            out.append(rx[i][0])
            
out
# Out:
# ['r',
#  'fb_ID',
#  'games',
#  'games_starts',
#  'minutes',
#  'goals',
#  'assists',
#  'cards_yellow',
#  'cards_red',
#  'xg',
#  'npxg',
#  'shots_on_target',
#  'shots_on_target_pct',
#  'goals_per_shot',
#  'goals_per_shot_on_target',
#  'passes_completed',
#  'passes_pct',
#  'passes_into_final_third',
#  'passes_into_penalty_area',
#  'progressive_passes',
#  'passes_live',
#  'passes_dead',
#  'through_balls',
#  'passes_switches',
#  'crosses',
#  'corner_kicks',
#  'dribble_tackles',
#  'dribbles_vs',
#  'dribble_tackles_pct',
#  'dribbled_past',
#  'blocks',
#  'blocked_shots',
#  'blocked_passes',
#  'interceptions',
#  'clearances',
#  'errors',
#  'touches',
#  'touches_def_pen_area',
#  'touches_def_3rd',
#  'touches_mid_3rd',
#  'touches_att_3rd',
#  'touches_att_pen_area',
#  'touches_live_ball',
#  'dribbles_completed',
#  'dribbles',
#  'dribbles_completed_pct',
#  'carries',
#  'progressive_carries',
#  'carries_into_final_third',
#  'carries_into_penalty_area',
#  'passes_received',
#  'miscontrols',
#  'dispossessed',
#  'fouls',
#  'fouled',
#  'aerials_won',
#  'aerials_lost',
#  'aerials_won_pct',
#  'team_possession',
#  'team_goals_assists_per90',
#  'team_goals_pens_per90',
#  'team_goals_assists_pens_per90',
#  'team_xg_per90',
#  'team_gk_goals_against_per90',
#  'team_gk_save_pct',
#  'team_gk_clean_sheets_pct',
#  'team_passes_pct',
#  'team_passes_pct_medium',
#  'team_passes_pct_long',
#  'team_sca_per90',
#  'team_gca_per90',
#  'team_dribble_tackles_pct',
#  'team_aerials_won_pct',
#  'vs_team_possession',
#  'vs_team_goals_per90',
#  'vs_team_assists_per90',
#  'vs_team_xg_per90',
#  'vs_team_gk_save_pct',
#  'vs_team_gk_clean_sheets_pct',
#  'vs_team_gk_pct_passes_launched',
#  'vs_team_gk_crosses_stopped_pct',
#  'vs_team_shots_on_target_per90',
#  'vs_team_passes_pct',
#  'vs_team_passes_pct_short',
#  'vs_team_passes_pct_medium',
#  'vs_team_passes_pct_long',
#  'vs_team_sca_per90',
#  'vs_team_gca_per90',
#  'vs_team_dribble_tackles_pct',
#  'vs_team_dribbles_completed_pct',
#  'vs_team_aerials_won_pct']

# %%
features_abs = ['r',
 'games',
 'games_starts',                
 'minutes',
 'shots_on_target_pct',
 'goals_per_shot',
 'goals_per_shot_on_target',
 'passes_pct',
 #'dribble_tackles_pct',
 #'dribbles_completed_pct',
 'aerials_won_pct',
 'team_possession',
 'team_goals_assists_per90',
 'team_goals_pens_per90',
 'team_goals_assists_pens_per90',
 'team_xg_per90',
 'team_gk_goals_against_per90',
 'team_gk_save_pct',
 'team_gk_clean_sheets_pct',
 'team_passes_pct',
 'team_passes_pct_medium',
 'team_passes_pct_long',
 'team_sca_per90',
 'team_gca_per90',
 #'team_dribble_tackles_pct',
 'team_aerials_won_pct',
 'vs_team_possession',
 'vs_team_goals_per90',
 'vs_team_assists_per90',
 'vs_team_xg_per90',
 'vs_team_gk_save_pct',
 'vs_team_gk_clean_sheets_pct',
 'vs_team_gk_pct_passes_launched',
 'vs_team_gk_crosses_stopped_pct',
 'vs_team_shots_on_target_per90',
 'vs_team_passes_pct',
 'vs_team_passes_pct_short',
 'vs_team_passes_pct_medium',
 'vs_team_passes_pct_long',
 'vs_team_sca_per90',
 'vs_team_gca_per90',
 #'vs_team_dribble_tackles_pct',
 #'vs_team_dribbles_completed_pct',
 'vs_team_aerials_won_pct',
 'opp_team_possession',
 'opp_team_goals_assists_per90',
 'opp_team_goals_pens_per90',
 'opp_team_goals_assists_pens_per90',
 'opp_team_xg_per90',
 'opp_team_gk_goals_against_per90',
 'opp_team_gk_save_pct',
 'opp_team_gk_clean_sheets_pct',
 'opp_team_passes_pct',
 'opp_team_passes_pct_medium',
 'opp_team_passes_pct_long',
 'opp_team_sca_per90',
 'opp_team_gca_per90',
 #'opp_team_dribble_tackles_pct',
 'opp_team_aerials_won_pct',
 'opp_vs_team_possession',
 'opp_vs_team_goals_per90',
 'opp_vs_team_assists_per90',
 'opp_vs_team_xg_per90',
 'opp_vs_team_gk_save_pct',
 'opp_vs_team_gk_clean_sheets_pct',
 'opp_vs_team_gk_pct_passes_launched',
 'opp_vs_team_gk_crosses_stopped_pct',
 'opp_vs_team_shots_on_target_per90',
 'opp_vs_team_passes_pct',
 'opp_vs_team_passes_pct_short',
 'opp_vs_team_passes_pct_medium',
 'opp_vs_team_passes_pct_long',
 'opp_vs_team_sca_per90',
 'opp_vs_team_gca_per90',
 #'opp_vs_team_dribble_tackles_pct',
 #'opp_vs_team_dribbles_completed_pct',
 'opp_vs_team_aerials_won_pct',
                
 'vote_avg',
 'vote_std']

features_rel = [
 'goals',
 'assists',
 'cards_yellow',
 'cards_red',
 'xg',
 'npxg',
 'shots_on_target',
 'passes_completed',
 'passes_into_final_third',
 'passes_into_penalty_area',
 'progressive_passes',
 'passes_live',
 'passes_dead',
 'through_balls',
 'passes_switches',
 'crosses',
 'corner_kicks',
 #'dribble_tackles',
 #'dribbles_vs',
 #'dribbled_past',
 'blocks',
 'blocked_shots',
 'blocked_passes',
 'interceptions',
 'clearances',
 'errors',
 'touches',
 'touches_def_pen_area',
 'touches_def_3rd',
 'touches_mid_3rd',
 'touches_att_3rd',
 'touches_att_pen_area',
 'touches_live_ball',
 #'dribbles_completed',
 #'dribbles',
 'passes_received',
 'miscontrols',
 'dispossessed',
 'fouls',
 'fouled',
 'aerials_won',
 'aerials_lost',
 'carries',
 'progressive_carries',
 'carries_into_final_third',
 'carries_into_penalty_area']

features_rel_gamecorr = [
    'goals',
    'assists',
    'xg',
    'npxg',
    'cards_yellow',
    'cards_red'
]

# %%
def player_match_data_ext(player, pteam, oppteam):
    pdata = player_match_data(player, pteam, oppteam)
    
    if(not isinstance(pdata, pd.DataFrame)):
        return None
    
    out = pd.concat([pdata[features_abs], pdata[features_rel]], axis = 1)
    
    out[features_rel] = out[features_rel] / max(pdata['minutes'][0], 1)
    
    out[features_rel_gamecorr] = out[features_rel_gamecorr] * (pdata['minutes'][0] / max(pdata['games'][0], 1) / 90)
    
    return out

# %%
test = player_match_data_ext('Immobile', 'Lazio', 'Atalanta')

add_columns = test.columns

test
# Out:
#           r  games  games_starts  minutes  shots_on_target_pct  \
# Immobile  A     31            27     2219                 41.7
#
#           goals_per_shot  goals_per_shot_on_target  passes_pct  \
# Immobile            0.11                      0.27        75.0
#
#           aerials_won_pct  team_possession  ...  miscontrols  dispossessed  \
# Immobile             29.8             52.1  ...     0.028391      0.009914
#
#              fouls    fouled  aerials_won  aerials_lost   carries  \
# Immobile  0.009464  0.010816     0.006309      0.014872  0.226679
#
#           progressive_carries  carries_into_final_third  \
# Immobile             0.018026                  0.009464
#
#           carries_into_penalty_area
# Immobile                   0.012168
#
# [1 rows x 112 columns]

# %%
votes = pd.read_excel('mid_outputs/season' + season + '/players_votes.xlsx', index_col = 0)
votes
# Out:
#        matchday         player      team    oppteam  home  vote  goals  \
# 0             1          Musso  Atalanta  Sampdoria     0   6.0      0
# 1             1          Toloi  Atalanta  Sampdoria     0   7.0      1
# 2             1       Djimsiti  Atalanta  Sampdoria     0   6.0      0
# 3             1       Hateboer  Atalanta  Sampdoria     0   6.0      0
# 4             1          Okoli  Atalanta  Sampdoria     0   5.5      0
# ...         ...            ...       ...        ...   ...   ...    ...
# 10805        38  Miguel Veloso    Verona      Milan     0   5.5      0
# 10806        38         Tameze    Verona      Milan     0   5.5      0
# 10807        38    Sulemana I.    Verona      Milan     0   6.0      0
# 10808        38         Djuric    Verona      Milan     0   5.5      0
# 10809        38         Ngonge    Verona      Milan     0   5.5      0
#
#        assists  cards_malus  fantavote
# 0            0          0.5        5.5
# 1            0          0.0       10.0
# 2            0          0.0        6.0
# 3            0          0.5        5.5
# 4            0          0.5        5.0
# ...        ...          ...        ...
# 10805        0          0.0        5.5
# 10806        0          0.0        5.5
# 10807        0          0.5        5.5
# 10808        0          0.0        5.5
# 10809        0          0.0        5.5
#
# [10810 rows x 10 columns]

# %%
db = votes.copy()

delta = pd.DataFrame(columns = add_columns)

for i in range(db.shape[0]):
    ext_data = player_match_data_ext(db['player'][i], db['team'][i], db['oppteam'][i])
    
    if(not isinstance(ext_data, pd.DataFrame)):
        continue
    
    ext_data = ext_data.rename(index = {db['player'][i] : i})
    
    delta = pd.concat([delta, ext_data], axis = 0)
    
    if(i % 100 == 0):
        print(i)
    
db = pd.concat([db, delta], axis = 1)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 700
# 800
# 900
# 1000
# 1100
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800

# %%
db
# Out:
#        matchday         player      team    oppteam  home  vote  goals  \
# 0             1          Musso  Atalanta  Sampdoria     0   6.0      0
# 1             1          Toloi  Atalanta  Sampdoria     0   7.0      1
# 2             1       Djimsiti  Atalanta  Sampdoria     0   6.0      0
# 3             1       Hateboer  Atalanta  Sampdoria     0   6.0      0
# 4             1          Okoli  Atalanta  Sampdoria     0   5.5      0
# ...         ...            ...       ...        ...   ...   ...    ...
# 10805        38  Miguel Veloso    Verona      Milan     0   5.5      0
# 10806        38         Tameze    Verona      Milan     0   5.5      0
# 10807        38    Sulemana I.    Verona      Milan     0   6.0      0
# 10808        38         Djuric    Verona      Milan     0   5.5      0
# 10809        38         Ngonge    Verona      Milan     0   5.5      0
#
#        assists  cards_malus  fantavote  ... miscontrols dispossessed  \
# 0            0          0.5        5.5  ...    0.000000     0.000000
# 1            0          0.0       10.0  ...    0.007543     0.001796
# 2            0          0.0        6.0  ...    0.005565     0.002782
# 3            0          0.5        5.5  ...    0.005727     0.005011
# 4            0          0.5        5.0  ...    0.012500     0.005208
# ...        ...          ...        ...  ...         ...          ...
# 10805        0          0.0        5.5  ...    0.006019     0.006019
# 10806        0          0.0        5.5  ...    0.012867     0.011217
# 10807        0          0.5        5.5  ...    0.015361     0.013825
# 10808        0          0.0        5.5  ...    0.019034     0.010981
# 10809        0          0.0        5.5  ...    0.030872     0.016107
#
#           fouls    fouled  aerials_won  aerials_lost   carries  \
# 0      0.000000  0.000000     0.000000      0.000000  0.000000
# 1      0.013649  0.007184     0.015445      0.011853  0.393319
# 2      0.008347  0.004452     0.032832      0.023372  0.389538
# 3      0.013601  0.002147     0.017180      0.010021  0.284896
# 4      0.015625  0.008333     0.044792      0.026042  0.276042
# ...         ...       ...          ...           ...       ...
# 10805  0.017197  0.006879     0.012038      0.012038  0.265692
# 10806  0.010558  0.010228     0.008908      0.010228  0.235236
# 10807  0.016897  0.004608     0.015361      0.018433  0.201229
# 10808  0.017570  0.021230     0.144217      0.041728  0.191801
# 10809  0.017450  0.014765     0.022819      0.046980  0.242953
#
#        progressive_carries  carries_into_final_third  \
# 0                 0.000000                  0.000000
# 1                 0.007543                  0.015086
# 2                 0.003895                  0.003895
# 3                 0.011453                  0.010021
# 4                 0.004167                  0.005208
# ...                    ...                       ...
# 10805             0.014617                  0.011178
# 10806             0.010558                  0.011217
# 10807             0.006144                  0.010753
# 10808             0.001464                  0.003660
# 10809             0.024161                  0.014765
#
#        carries_into_penalty_area
# 0                       0.000000
# 1                       0.000000
# 2                       0.000556
# 3                       0.000716
# 4                       0.000000
# ...                          ...
# 10805                   0.000860
# 10806                   0.001320
# 10807                   0.000000
# 10808                   0.002196
# 10809                   0.012081
#
# [10810 rows x 122 columns]

# %%
db = db.drop(db[db.r == 'P'].index) # remove goalkeepers
db = db.drop(db[db.r != db.r].index) # remove non extisting players
db = db.drop(db[db.r != db.r].index) # remove non extisting players
db = db.drop(db[db.xg != db.xg].index)

# %%
db
# Out:
#        matchday         player      team    oppteam  home  vote  goals  \
# 1             1          Toloi  Atalanta  Sampdoria     0   7.0      1
# 2             1       Djimsiti  Atalanta  Sampdoria     0   6.0      0
# 3             1       Hateboer  Atalanta  Sampdoria     0   6.0      0
# 4             1          Okoli  Atalanta  Sampdoria     0   5.5      0
# 5             1         Zortea  Atalanta  Sampdoria     0   6.0      0
# ...         ...            ...       ...        ...   ...   ...    ...
# 10805        38  Miguel Veloso    Verona      Milan     0   5.5      0
# 10806        38         Tameze    Verona      Milan     0   5.5      0
# 10807        38    Sulemana I.    Verona      Milan     0   6.0      0
# 10808        38         Djuric    Verona      Milan     0   5.5      0
# 10809        38         Ngonge    Verona      Milan     0   5.5      0
#
#        assists  cards_malus  fantavote  ... miscontrols dispossessed  \
# 1            0          0.0       10.0  ...    0.007543     0.001796
# 2            0          0.0        6.0  ...    0.005565     0.002782
# 3            0          0.5        5.5  ...    0.005727     0.005011
# 4            0          0.5        5.0  ...    0.012500     0.005208
# 5            0          0.5        5.5  ...    0.018265     0.007610
# ...        ...          ...        ...  ...         ...          ...
# 10805        0          0.0        5.5  ...    0.006019     0.006019
# 10806        0          0.0        5.5  ...    0.012867     0.011217
# 10807        0          0.5        5.5  ...    0.015361     0.013825
# 10808        0          0.0        5.5  ...    0.019034     0.010981
# 10809        0          0.0        5.5  ...    0.030872     0.016107
#
#           fouls    fouled  aerials_won  aerials_lost   carries  \
# 1      0.013649  0.007184     0.015445      0.011853  0.393319
# 2      0.008347  0.004452     0.032832      0.023372  0.389538
# 3      0.013601  0.002147     0.017180      0.010021  0.284896
# 4      0.015625  0.008333     0.044792      0.026042  0.276042
# 5      0.016743  0.009132     0.009132      0.012177  0.420091
# ...         ...       ...          ...           ...       ...
# 10805  0.017197  0.006879     0.012038      0.012038  0.265692
# 10806  0.010558  0.010228     0.008908      0.010228  0.235236
# 10807  0.016897  0.004608     0.015361      0.018433  0.201229
# 10808  0.017570  0.021230     0.144217      0.041728  0.191801
# 10809  0.017450  0.014765     0.022819      0.046980  0.242953
#
#        progressive_carries  carries_into_final_third  \
# 1                 0.007543                  0.015086
# 2                 0.003895                  0.003895
# 3                 0.011453                  0.010021
# 4                 0.004167                  0.005208
# 5                 0.036530                  0.028919
# ...                    ...                       ...
# 10805             0.014617                  0.011178
# 10806             0.010558                  0.011217
# 10807             0.006144                  0.010753
# 10808             0.001464                  0.003660
# 10809             0.024161                  0.014765
#
#        carries_into_penalty_area
# 1                       0.000000
# 2                       0.000556
# 3                       0.000716
# 4                       0.000000
# 5                       0.004566
# ...                          ...
# 10805                   0.000860
# 10806                   0.001320
# 10807                   0.000000
# 10808                   0.002196
# 10809                   0.012081
#
# [9769 rows x 122 columns]

# %%
db.to_excel('mid_outputs/season' + season + '/database_entries.xlsx')

# %% [markdown]
# Goalkeepers

# %%
features_abs_gk = [
 'gk_games',
 'gk_games_starts',
 'gk_minutes',
 'gk_goals_against_per90', 
 'gk_save_pct',
 'gk_clean_sheets_pct',
 'gk_psxg_net_per90',
 'gk_passes_pct_launched',
 'gk_pct_passes_launched',
 'gk_passes_length_avg',
 'gk_pct_goal_kicks_launched',
 'gk_goal_kick_length_avg',
 'gk_crosses_stopped_pct',
 'gk_def_actions_outside_pen_area_per90',
 'gk_avg_distance_def_actions',
    
 'team_possession',
 'team_goals_assists_per90',
 'team_goals_pens_per90',
 'team_goals_assists_pens_per90',
 'team_xg_per90',
 'team_gk_goals_against_per90',
 'team_gk_save_pct',
 'team_gk_clean_sheets_pct',
 'team_passes_pct',
 'team_passes_pct_medium',
 'team_passes_pct_long',
 'team_sca_per90',
 'team_gca_per90',
 #'team_dribble_tackles_pct',
 'team_aerials_won_pct',
 'vs_team_possession',
 'vs_team_goals_per90',
 'vs_team_assists_per90',
 'vs_team_xg_per90',
 'vs_team_gk_save_pct',
 'vs_team_gk_clean_sheets_pct',
 'vs_team_gk_pct_passes_launched',
 'vs_team_gk_crosses_stopped_pct',
 'vs_team_shots_on_target_per90',
 'vs_team_passes_pct',
 'vs_team_passes_pct_short',
 'vs_team_passes_pct_medium',
 'vs_team_passes_pct_long',
 'vs_team_sca_per90',
 'vs_team_gca_per90',
 #'vs_team_dribble_tackles_pct',
 #'vs_team_dribbles_completed_pct',
 'vs_team_aerials_won_pct',
 'opp_team_possession',
 'opp_team_goals_assists_per90',
 'opp_team_goals_pens_per90',
 'opp_team_goals_assists_pens_per90',
 'opp_team_xg_per90',
 'opp_team_gk_goals_against_per90',
 'opp_team_gk_save_pct',
 'opp_team_gk_clean_sheets_pct',
 'opp_team_passes_pct',
 'opp_team_passes_pct_medium',
 'opp_team_passes_pct_long',
 'opp_team_sca_per90',
 'opp_team_gca_per90',
 #'opp_team_dribble_tackles_pct',
 'opp_team_aerials_won_pct',
 'opp_vs_team_possession',
 'opp_vs_team_goals_per90',
 'opp_vs_team_assists_per90',
 'opp_vs_team_xg_per90',
 'opp_vs_team_gk_save_pct',
 'opp_vs_team_gk_clean_sheets_pct',
 'opp_vs_team_gk_pct_passes_launched',
 'opp_vs_team_gk_crosses_stopped_pct',
 'opp_vs_team_shots_on_target_per90',
 'opp_vs_team_passes_pct',
 'opp_vs_team_passes_pct_short',
 'opp_vs_team_passes_pct_medium',
 'opp_vs_team_passes_pct_long',
 'opp_vs_team_sca_per90',
 'opp_vs_team_gca_per90',
 #'opp_vs_team_dribble_tackles_pct',
 #'opp_vs_team_dribbles_completed_pct',
 'opp_vs_team_aerials_won_pct',
                
 'vote_avg',
 'vote_std']

features_rel_gk = [
 'gk_shots_on_target_against',
 'gk_saves',
 'gk_free_kick_goals_against',
 'gk_corner_kick_goals_against',
 'gk_own_goals_against',
 'gk_psxg',
 'gk_psnpxg_per_shot_on_target_against',
 'gk_psxg_net',
 'gk_passes_completed_launched',
 'gk_passes_launched',
 'gk_passes',
 'gk_passes_throws',
 'gk_goal_kicks',
 'gk_crosses',
 'gk_crosses_stopped',
]

# %%
def player_match_data_ext_gk(player, pteam, oppteam):
    pdata = player_match_data(player, pteam, oppteam)
    
    if(not isinstance(pdata, pd.DataFrame)):
        return None
    
    if(pdata['gk_games'][0] <= 0):
        return None
    
    out = pd.concat([pdata[features_abs_gk], pdata[features_rel_gk]], axis = 1)
    
    out[features_rel_gk] = out[features_rel_gk] / max(pdata['minutes'][0], 1)

    return out

# %%
test = player_match_data_ext_gk('Consigli', 'Sassuolo', 'Atalanta')

add_columns_gk = test.columns

test
# Out:
#           gk_games  gk_games_starts  gk_minutes  gk_goals_against_per90  \
# Consigli        35               35        3150                    1.57
#
#           gk_save_pct  gk_clean_sheets_pct  gk_psxg_net_per90  \
# Consigli         55.6                 25.7              -0.41
#
#           gk_passes_pct_launched  gk_pct_passes_launched  \
# Consigli                    40.4                    30.4
#
#           gk_passes_length_avg  ...  gk_psxg  \
# Consigli                  33.3  ...     38.5
#
#           gk_psnpxg_per_shot_on_target_against  gk_psxg_net  \
# Consigli                                  0.31        -14.5
#
#           gk_passes_completed_launched  gk_passes_launched  gk_passes  \
# Consigli                         176.0               436.0     1140.0
#
#           gk_passes_throws  gk_goal_kicks  gk_crosses  gk_crosses_stopped
# Consigli             187.0          285.0       467.0                28.0
#
# [1 rows x 92 columns]

# %%
db_gk = votes.copy()

delta = pd.DataFrame(columns = add_columns_gk)

for i in range(db_gk.shape[0]):
    ext_data = player_match_data_ext_gk(db_gk['player'][i], db_gk['team'][i], db_gk['oppteam'][i])
    
    if(i % 100 == 0):
        print(i)
        
    if(not isinstance(ext_data, pd.DataFrame)):
        continue
    
    ext_data = ext_data.rename(index = {db_gk['player'][i] : i})
    
    delta = pd.concat([delta, ext_data], axis = 0)
    
    
    
db_gk = pd.concat([db_gk, delta], axis = 1)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700
# 5800
# 5900
# 6000
# 6100
# 6200
# 6300
# 6400
# 6500
# 6600
# 6700
# 6800
# 6900
# 7000
# 7100
# 7200
# 7300
# 7400
# 7500
# 7600
# 7700
# 7800
# 7900
# 8000
# 8100
# 8200
# 8300
# 8400
# 8500
# 8600
# 8700
# 8800
# 8900
# 9000
# 9100
# 9200
# 9300
# 9400
# 9500
# 9600
# 9700
# 9800
# 9900
# 10000
# 10100
# 10200
# 10300
# 10400
# 10500
# 10600
# 10700
# 10800

# %%
db_gk = db_gk.drop(db_gk[db_gk.gk_games != db_gk.gk_games].index) # remove non extisting players

# %%
db_gk.to_excel('mid_outputs/season' + season + '/database_entries_gk.xlsx')
