# %% [markdown]
# Player/match dataset creation
#
# For each serie A (already happened) match and player, a database entry is generated, with this form:
#
# [y = player votes data, player data, team data, vs team data, opp team data, vs opp team data]

# %%
import pandas as pd

# %% [markdown]
# Load team data from FBref

# %%
rcsv = pd.read_csv('fbref_data/teams.csv')   
team = pd.DataFrame(rcsv)

rcsv = pd.read_csv('fbref_data/teams_vs.csv')   
vs_team = pd.DataFrame(rcsv)

for i in range(1, team.shape[1]):
    team = team.rename(columns = {team.columns[i] : 'team_' + team.columns[i]})
    
for i in range(1, vs_team.shape[1]):
    vs_team = vs_team.rename(columns = {vs_team.columns[i] : 'vs_team_' + vs_team.columns[i]})
    
vs_team.pop('team')

team_data = pd.concat([team, vs_team], axis = 1)

team_data['team_idx'] = team_data['team']
for i in range(team_data.shape[0]):
    team_data['team_idx'][i] = team_data['team_idx'][i].split(' ')[-1]

team_data = team_data.set_index('team_idx')

team_data
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_7952\552672520.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_data['team_idx'][i] = team_data['team_idx'][i].split(' ')[-1]
#                       team  team_players_used  team_possession  team_games  \
# team_idx
# Atalanta          Atalanta               24.0             48.4        19.0
# Bologna            Bologna               24.0             52.6        20.0
# Cremonese        Cremonese               29.0             44.0        19.0
# Empoli              Empoli               26.0             46.3        19.0
# Fiorentina      Fiorentina               27.0             57.2        19.0
# Verona       Hellas Verona               29.0             43.4        19.0
# Inter                Inter               23.0             52.9        19.0
# Juventus          Juventus               26.0             49.5        19.0
# Lazio                Lazio               21.0             51.2        19.0
# Lecce                Lecce               26.0             42.5        20.0
# Milan                Milan               27.0             54.5        19.0
# Monza                Monza               29.0             55.1        19.0
# Napoli              Napoli               24.0             61.3        19.0
# Roma                  Roma               25.0             49.4        19.0
# Salernitana    Salernitana               28.0             44.8        20.0
# Sampdoria        Sampdoria               29.0             49.4        19.0
# Sassuolo          Sassuolo               27.0             48.7        19.0
# Spezia              Spezia               30.0             46.7        20.0
# Torino              Torino               23.0             52.8        19.0
# Udinese            Udinese               22.0             50.1        19.0
#
#              team_games_starts  team_minutes  team_goals  team_assists  \
# team_idx
# Atalanta                 209.0        1710.0        36.0          25.0
# Bologna                  220.0        1800.0        25.0          19.0
# Cremonese                209.0        1710.0        14.0           6.0
# Empoli                   209.0        1710.0        17.0           9.0
# Fiorentina               209.0        1710.0        21.0          17.0
# Verona                   209.0        1710.0        16.0          13.0
# Inter                    209.0        1710.0        37.0          25.0
# Juventus                 209.0        1710.0        30.0          23.0
# Lazio                    209.0        1710.0        34.0          25.0
# Lecce                    220.0        1800.0        18.0          12.0
# Milan                    209.0        1710.0        33.0          28.0
# Monza                    209.0        1710.0        22.0          13.0
# Napoli                   209.0        1710.0        46.0          37.0
# Roma                     209.0        1710.0        25.0          16.0
# Salernitana              220.0        1800.0        24.0          16.0
# Sampdoria                209.0        1710.0         8.0           7.0
# Sassuolo                 209.0        1710.0        18.0          13.0
# Spezia                   220.0        1800.0        15.0          10.0
# Torino                   209.0        1710.0        19.0          14.0
# Udinese                  209.0        1710.0        26.0          22.0
#
#              team_pens_made  team_pens_att  ...  vs_team_fouls  \
# team_idx                                    ...
# Atalanta                6.0            8.0  ...          209.0
# Bologna                 3.0            3.0  ...          252.0
# Cremonese               2.0            4.0  ...          205.0
# Empoli                  0.0            0.0  ...          251.0
# Fiorentina              2.0            4.0  ...          259.0
# Verona                  0.0            0.0  ...          192.0
# Inter                   2.0            2.0  ...          242.0
# Juventus                2.0            3.0  ...          210.0
# Lazio                   3.0            4.0  ...          261.0
# Lecce                   1.0            2.0  ...          263.0
# Milan                   2.0            2.0  ...          234.0
# Monza                   3.0            3.0  ...          279.0
# Napoli                  4.0            5.0  ...          258.0
# Roma                    3.0            5.0  ...          266.0
# Salernitana             1.0            1.0  ...          226.0
# Sampdoria               0.0            0.0  ...          299.0
# Sassuolo                3.0            4.0  ...          249.0
# Spezia                  2.0            2.0  ...          207.0
# Torino                  1.0            1.0  ...          209.0
# Udinese                 0.0            0.0  ...          250.0
#
#              vs_team_fouled  vs_team_offsides  vs_team_pens_won  \
# team_idx
# Atalanta              218.0              25.0               1.0
# Bologna               229.0              33.0               3.0
# Cremonese             247.0              29.0               3.0
# Empoli                214.0              31.0               2.0
# Fiorentina            229.0              52.0               1.0
# Verona                276.0              22.0               1.0
# Inter                 214.0              18.0               2.0
# Juventus              210.0              25.0               0.0
# Lazio                 185.0              42.0               1.0
# Lecce                 265.0              43.0               3.0
# Milan                 226.0              20.0               3.0
# Monza                 242.0              34.0               0.0
# Napoli                167.0              27.0               1.0
# Roma                  214.0              10.0               0.0
# Salernitana           233.0              49.0               7.0
# Sampdoria             266.0              55.0               3.0
# Sassuolo              182.0              62.0               2.0
# Spezia                261.0              46.0               1.0
# Torino                265.0              21.0               3.0
# Udinese               227.0              29.0               2.0
#
#              vs_team_pens_conceded  vs_team_own_goals  \
# team_idx
# Atalanta                       8.0                1.0
# Bologna                        3.0                1.0
# Cremonese                      4.0                0.0
# Empoli                         0.0                0.0
# Fiorentina                     4.0                0.0
# Verona                         0.0                1.0
# Inter                          2.0                1.0
# Juventus                       3.0                0.0
# Lazio                          4.0                1.0
# Lecce                          2.0                1.0
# Milan                          2.0                2.0
# Monza                          3.0                1.0
# Napoli                         4.0                0.0
# Roma                           5.0                0.0
# Salernitana                    1.0                1.0
# Sampdoria                      0.0                0.0
# Sassuolo                       4.0                0.0
# Spezia                         2.0                2.0
# Torino                         1.0                0.0
# Udinese                        0.0                1.0
#
#              vs_team_ball_recoveries  vs_team_aerials_won  \
# team_idx
# Atalanta                      1165.0                239.0
# Bologna                       1081.0                224.0
# Cremonese                     1052.0                348.0
# Empoli                         999.0                217.0
# Fiorentina                     942.0                249.0
# Verona                        1038.0                345.0
# Inter                          869.0                198.0
# Juventus                       947.0                230.0
# Lazio                         1021.0                183.0
# Lecce                         1072.0                373.0
# Milan                          964.0                224.0
# Monza                          958.0                197.0
# Napoli                         933.0                201.0
# Roma                           981.0                184.0
# Salernitana                   1084.0                257.0
# Sampdoria                     1017.0                300.0
# Sassuolo                       986.0                216.0
# Spezia                        1182.0                322.0
# Torino                         998.0                323.0
# Udinese                        950.0                189.0
#
#              vs_team_aerials_lost  vs_team_aerials_won_pct
# team_idx
# Atalanta                    279.0                     46.1
# Bologna                     180.0                     55.4
# Cremonese                   267.0                     56.6
# Empoli                      189.0                     53.4
# Fiorentina                  289.0                     46.3
# Verona                      388.0                     47.1
# Inter                       232.0                     46.0
# Juventus                    230.0                     50.0
# Lazio                       181.0                     50.3
# Lecce                       294.0                     55.9
# Milan                       275.0                     44.9
# Monza                       215.0                     47.8
# Napoli                      231.0                     46.5
# Roma                        225.0                     45.0
# Salernitana                 240.0                     51.7
# Sampdoria                   318.0                     48.5
# Sassuolo                    173.0                     55.5
# Spezia                      281.0                     53.4
# Torino                      295.0                     52.3
# Udinese                     237.0                     44.4
#
# [20 rows x 313 columns]

# %%
team_data.to_excel('mid_outputs/team_data.xlsx')

# %% [markdown]
# Load data generated from players_dataset_creation

# %%
rx = pd.read_excel('mid_outputs/players_stats.xlsx', index_col = 3)   
players = pd.DataFrame(rx)

players
# Out:
#             Unnamed: 0    id  r       team    surname initial  fb_ID     age  \
# name
# Meret                0   572  P     Napoli      Meret     NaN    529  25-312
# Provedel             1  2814  P      Lazio   Provedel     NaN    538  28-317
# Vicario              2  4964  P     Empoli    Vicario     NaN    547  26-113
# Szczesny             3   453  P   Juventus   Szczesny     NaN    544  32-285
# Falcone              4  2134  P      Lecce    Falcone     NaN    524  27-291
# ...                ...   ... ..        ...        ...     ...    ...     ...
# Kaio Jorge         542  5505  A   Juventus      Jorge     NaN     -1       0
# De Luca            543  5512  A  Sampdoria       Luca     NaN    128  24-195
# Lazetic            544  5785  A      Milan    Lazetic     NaN    258  19-006
# Montevago          545  6113  A  Sampdoria  Montevago     NaN    318  19-316
# Krollis            546  6143  A     Spezia    Krollis     NaN     -1       0
#
#             birth_year  games  ...  gk_pct_goal_kicks_launched  \
# name                           ...
# Meret             1997      0  ...                        20.2
# Provedel          1994      0  ...                        34.8
# Vicario           1996      0  ...                        45.6
# Szczesny          1990      0  ...                        41.0
# Falcone           1995      0  ...                        75.0
# ...                ...    ...  ...                         ...
# Kaio Jorge           0      0  ...                         0.0
# De Luca           1998      1  ...                         0.0
# Lazetic           2004      1  ...                         0.0
# Montevago         2003      6  ...                         0.0
# Krollis              0      0  ...                         0.0
#
#             gk_goal_kick_length_avg  gk_crosses  gk_crosses_stopped  \
# name
# Meret                          27.1       197.0                 6.0
# Provedel                       34.8       256.0                 7.0
# Vicario                        41.8       399.0                25.0
# Szczesny                       39.2       155.0                 4.0
# Falcone                        51.4       304.0                13.0
# ...                             ...         ...                 ...
# Kaio Jorge                      0.0         0.0                 0.0
# De Luca                         0.0         0.0                 0.0
# Lazetic                         0.0         0.0                 0.0
# Montevago                       0.0         0.0                 0.0
# Krollis                         0.0         0.0                 0.0
#
#             gk_crosses_stopped_pct  gk_def_actions_outside_pen_area  \
# name
# Meret                          3.0                             23.0
# Provedel                       2.7                             37.0
# Vicario                        6.3                              8.0
# Szczesny                       2.6                              7.0
# Falcone                        4.3                             20.0
# ...                            ...                              ...
# Kaio Jorge                     0.0                              0.0
# De Luca                        0.0                              0.0
# Lazetic                        0.0                              0.0
# Montevago                      0.0                              0.0
# Krollis                        0.0                              0.0
#
#             gk_def_actions_outside_pen_area_per90  \
# name
# Meret                                        1.21
# Provedel                                     1.96
# Vicario                                      0.42
# Szczesny                                     0.56
# Falcone                                      1.00
# ...                                           ...
# Kaio Jorge                                   0.00
# De Luca                                      0.00
# Lazetic                                      0.00
# Montevago                                    0.00
# Krollis                                      0.00
#
#             gk_avg_distance_def_actions  vote_avg  vote_std
# name
# Meret                              17.2  6.263158  0.496525
# Provedel                           18.1  6.236842  0.339055
# Vicario                            10.5  6.473684  0.379532
# Szczesny                           14.2  6.038462  0.364878
# Falcone                            12.5  6.342105  0.364642
# ...                                 ...       ...       ...
# Kaio Jorge                          0.0  6.092280  0.894197
# De Luca                             0.0  6.284927  0.532298
# Lazetic                             0.0  6.094004  0.625570
# Montevago                           0.0  5.711934  0.225193
# Krollis                             0.0  5.748895  0.595450
#
# [547 rows x 165 columns]

# %% [markdown]
# Function for merging match data (player, team, opponent team)

# %%
def player_match_data(player, pteam, oppteam):
    if(not(player in players.index)):
        return None
    
    pdata = players.loc[[player]]
    
    pteam_stats = team_data.loc[[pteam]].rename(index = {pteam : player})
    
    oppteam_stats = team_data.loc[[oppteam]].rename(index = {oppteam : player})
    
    oppteam_stats = oppteam_stats.rename(lambda x: 'opp_' + x, axis='columns')
    
    out = pd.concat([pdata, pteam_stats, oppteam_stats], axis = 1)
    
    return(out)

# %% [markdown]
# Output to excel file data for a player.
#
# The file is copied and there the desired features are manually selected and printed.

# %%
test = player_match_data('Frattesi', 'Sassuolo', 'Atalanta')
test.to_excel('tmp/playermatchdata.xlsx')

test
# Out:
#           Unnamed: 0    id  r      team   surname initial  fb_ID     age  \
# Frattesi         276  2848  C  Sassuolo  Frattesi     NaN    184  23-098
#
#           birth_year  games  ...  opp_vs_team_fouls  opp_vs_team_fouled  \
# Frattesi        1999     19  ...              209.0               218.0
#
#           opp_vs_team_offsides  opp_vs_team_pens_won  \
# Frattesi                  25.0                   1.0
#
#           opp_vs_team_pens_conceded  opp_vs_team_own_goals  \
# Frattesi                        8.0                    1.0
#
#           opp_vs_team_ball_recoveries  opp_vs_team_aerials_won  \
# Frattesi                       1165.0                    239.0
#
#           opp_vs_team_aerials_lost  opp_vs_team_aerials_won_pct
# Frattesi                     279.0                         46.1
#
# [1 rows x 791 columns]

# %%
pteam = 'Sassuolo'
pteam_stats = team_data.loc[[pteam]]
pteam_stats.index[0]
# Out:
# 'Sassuolo'

# %%
rx = pd.read_excel('tmp/playermatchdata_sel.xlsx', index_col = 0, header = None)   

out = list()

for i in range(1, rx.shape[1]):
        if(rx[i][2] == "x"):
            out.append(rx[i][0])
            
out
# Out:
# ['r',
#  'fb_ID',
#  'games',
#  'games_starts',
#  'minutes',
#  'goals',
#  'assists',
#  'cards_yellow',
#  'cards_red',
#  'xg',
#  'npxg',
#  'shots_on_target',
#  'shots_on_target_pct',
#  'goals_per_shot',
#  'goals_per_shot_on_target',
#  'passes_completed',
#  'passes_pct',
#  'passes_into_final_third',
#  'passes_into_penalty_area',
#  'progressive_passes',
#  'passes_live',
#  'passes_dead',
#  'through_balls',
#  'passes_switches',
#  'crosses',
#  'corner_kicks',
#  'dribble_tackles',
#  'dribbles_vs',
#  'dribble_tackles_pct',
#  'dribbled_past',
#  'blocks',
#  'blocked_shots',
#  'blocked_passes',
#  'interceptions',
#  'clearances',
#  'errors',
#  'touches',
#  'touches_def_pen_area',
#  'touches_def_3rd',
#  'touches_mid_3rd',
#  'touches_att_3rd',
#  'touches_att_pen_area',
#  'touches_live_ball',
#  'dribbles_completed',
#  'dribbles',
#  'dribbles_completed_pct',
#  'passes_received',
#  'miscontrols',
#  'dispossessed',
#  'fouls',
#  'fouled',
#  'aerials_won',
#  'aerials_lost',
#  'aerials_won_pct',
#  'team_possession',
#  'team_goals_assists_per90',
#  'team_goals_pens_per90',
#  'team_goals_assists_pens_per90',
#  'team_xg_per90',
#  'team_gk_goals_against_per90',
#  'team_gk_save_pct',
#  'team_gk_clean_sheets_pct',
#  'team_passes_pct',
#  'team_passes_pct_medium',
#  'team_passes_pct_long',
#  'team_sca_per90',
#  'team_gca_per90',
#  'team_dribble_tackles_pct',
#  'team_aerials_won_pct',
#  'vs_team_possession',
#  'vs_team_goals_per90',
#  'vs_team_assists_per90',
#  'vs_team_xg_per90',
#  'vs_team_gk_save_pct',
#  'vs_team_gk_clean_sheets_pct',
#  'vs_team_gk_pct_passes_launched',
#  'vs_team_gk_crosses_stopped_pct',
#  'vs_team_shots_on_target_per90',
#  'vs_team_passes_pct',
#  'vs_team_passes_pct_short',
#  'vs_team_passes_pct_medium',
#  'vs_team_passes_pct_long',
#  'vs_team_sca_per90',
#  'vs_team_gca_per90',
#  'vs_team_dribble_tackles_pct',
#  'vs_team_dribbles_completed_pct',
#  'vs_team_aerials_won_pct']

# %% [markdown]
# Define and select the dataset features: abs features and rel features.
#
# Rel features are divided by the player minutes played.
#
# Rel features (game corrected) are divided by the player number of games instead of minutes.
# For example, a player who plays 20 minutes and scores, would be to match for stats averaging. It is better to consider the goals made per match.

# %%
features_abs = ['r',
 'games',
 'games_starts',                
 'minutes',
 'shots_on_target_pct',
 'goals_per_shot',
 'goals_per_shot_on_target',
 'passes_pct',
 'dribble_tackles_pct',
 'dribbles_completed_pct',
 'aerials_won_pct',
 'team_possession',
 'team_goals_assists_per90',
 'team_goals_pens_per90',
 'team_goals_assists_pens_per90',
 'team_xg_per90',
 'team_gk_goals_against_per90',
 'team_gk_save_pct',
 'team_gk_clean_sheets_pct',
 'team_passes_pct',
 'team_passes_pct_medium',
 'team_passes_pct_long',
 'team_sca_per90',
 'team_gca_per90',
 'team_dribble_tackles_pct',
 'team_aerials_won_pct',
 'vs_team_possession',
 'vs_team_goals_per90',
 'vs_team_assists_per90',
 'vs_team_xg_per90',
 'vs_team_gk_save_pct',
 'vs_team_gk_clean_sheets_pct',
 'vs_team_gk_pct_passes_launched',
 'vs_team_gk_crosses_stopped_pct',
 'vs_team_shots_on_target_per90',
 'vs_team_passes_pct',
 'vs_team_passes_pct_short',
 'vs_team_passes_pct_medium',
 'vs_team_passes_pct_long',
 'vs_team_sca_per90',
 'vs_team_gca_per90',
 'vs_team_dribble_tackles_pct',
 'vs_team_dribbles_completed_pct',
 'vs_team_aerials_won_pct',
 'opp_team_possession',
 'opp_team_goals_assists_per90',
 'opp_team_goals_pens_per90',
 'opp_team_goals_assists_pens_per90',
 'opp_team_xg_per90',
 'opp_team_gk_goals_against_per90',
 'opp_team_gk_save_pct',
 'opp_team_gk_clean_sheets_pct',
 'opp_team_passes_pct',
 'opp_team_passes_pct_medium',
 'opp_team_passes_pct_long',
 'opp_team_sca_per90',
 'opp_team_gca_per90',
 'opp_team_dribble_tackles_pct',
 'opp_team_aerials_won_pct',
 'opp_vs_team_possession',
 'opp_vs_team_goals_per90',
 'opp_vs_team_assists_per90',
 'opp_vs_team_xg_per90',
 'opp_vs_team_gk_save_pct',
 'opp_vs_team_gk_clean_sheets_pct',
 'opp_vs_team_gk_pct_passes_launched',
 'opp_vs_team_gk_crosses_stopped_pct',
 'opp_vs_team_shots_on_target_per90',
 'opp_vs_team_passes_pct',
 'opp_vs_team_passes_pct_short',
 'opp_vs_team_passes_pct_medium',
 'opp_vs_team_passes_pct_long',
 'opp_vs_team_sca_per90',
 'opp_vs_team_gca_per90',
 'opp_vs_team_dribble_tackles_pct',
 'opp_vs_team_dribbles_completed_pct',
 'opp_vs_team_aerials_won_pct',
                
 'vote_avg',
 'vote_std']

features_rel = [
 'goals',
 'assists',
 'cards_yellow',
 'cards_red',
 'xg',
 'npxg',
 'shots_on_target',
 'passes_completed',
 'passes_into_final_third',
 'passes_into_penalty_area',
 'progressive_passes',
 'passes_live',
 'passes_dead',
 'through_balls',
 'passes_switches',
 'crosses',
 'corner_kicks',
 'dribble_tackles',
 'dribbles_vs',
 'dribbled_past',
 'blocks',
 'blocked_shots',
 'blocked_passes',
 'interceptions',
 'clearances',
 'errors',
 'touches',
 'touches_def_pen_area',
 'touches_def_3rd',
 'touches_mid_3rd',
 'touches_att_3rd',
 'touches_att_pen_area',
 'touches_live_ball',
 'dribbles_completed',
 'dribbles',
 'passes_received',
 'miscontrols',
 'dispossessed',
 'fouls',
 'fouled',
 'aerials_won',
 'aerials_lost']

features_rel_gamecorr = [
    'goals',
    'assists',
    'xg',
    'npxg',
    'cards_yellow',
    'cards_red'
]

# %% [markdown]
# Function for merging match data (player, team, opponent team) and select only the desired features, applying the desired corrections.

# %%
def player_match_data_ext(player, pteam, oppteam):
    pdata = player_match_data(player, pteam, oppteam)
    
    if(not isinstance(pdata, pd.DataFrame)):
        return None
    
    out = pd.concat([pdata[features_abs], pdata[features_rel]], axis = 1)
    
    out[features_rel] = out[features_rel] / max(pdata['minutes'][0], 1)
    
    out[features_rel_gamecorr] = out[features_rel_gamecorr] * (pdata['minutes'][0] / max(pdata['games'][0], 1) / 90)
    
    return out

# %% [markdown]
# Columns variable for the match data, to be then added to votes data.

# %%
test = player_match_data_ext('Frattesi', 'Sassuolo', 'Atalanta')

add_columns = test.columns

test
# Out:
#           r  games  games_starts  minutes  shots_on_target_pct  \
# Frattesi  C     19            19     1560                 48.6
#
#           goals_per_shot  goals_per_shot_on_target  passes_pct  \
# Frattesi            0.11                      0.24        77.9
#
#           dribble_tackles_pct  dribbles_completed_pct  ...  touches_live_ball  \
# Frattesi                 54.5                    54.5  ...           0.482051
#
#           dribbles_completed  dribbles  passes_received  miscontrols  \
# Frattesi            0.015385  0.028205         0.322436     0.016667
#
#           dispossessed     fouls    fouled  aerials_won  aerials_lost
# Frattesi      0.017308  0.014744  0.023077     0.010256      0.007051
#
# [1 rows x 121 columns]

# %% [markdown]
# Load Fantacalcio votes data for each match of the season.

# %%
votes = pd.read_excel('mid_outputs/players_votes.xlsx', index_col = 0)
votes
# Out:
#       matchday       player      team    oppteam  home  vote  goals  assists  \
# 0            1        Musso  Atalanta  Sampdoria     0   6.0      0        0
# 1            1        Toloi  Atalanta  Sampdoria     0   7.0      1        0
# 2            1     Djimsiti  Atalanta  Sampdoria     0   6.0      0        0
# 3            1     Hateboer  Atalanta  Sampdoria     0   6.0      0        0
# 4            1        Okoli  Atalanta  Sampdoria     0   5.5      0        0
# ...        ...          ...       ...        ...   ...   ...    ...      ...
# 5423        19         Ilic    Verona      Lecce     1   7.0      0        1
# 5424        19  Sulemana I.    Verona      Lecce     1   6.0      0        0
# 5425        19      Lasagna    Verona      Lecce     1   5.5      0        0
# 5426        19       Kallon    Verona      Lecce     1   6.0      0        0
# 5427        19       Djuric    Verona      Lecce     1   6.0      0        0
#
#       cards_malus  fantavote
# 0             0.5        5.5
# 1             0.0       10.0
# 2             0.0        6.0
# 3             0.5        5.5
# 4             0.5        5.0
# ...           ...        ...
# 5423          0.0        8.0
# 5424          0.0        6.0
# 5425          0.0        5.5
# 5426          0.0        6.0
# 5427          0.0        6.0
#
# [5428 rows x 10 columns]

# %% [markdown]
# Merge votes data with match data for the player.

# %%
db = votes.copy()

delta = pd.DataFrame(columns = add_columns)

for i in range(db.shape[0]):
    ext_data = player_match_data_ext(db['player'][i], db['team'][i], db['oppteam'][i])
    
    if(not isinstance(ext_data, pd.DataFrame)):
        continue
    
    ext_data = ext_data.rename(index = {db['player'][i] : i})
    
    delta = pd.concat([delta, ext_data], axis = 0)
    
    if(i % 100 == 0):
        print(i)
    
db = pd.concat([db, delta], axis = 1)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400

# %%
db
# Out:
#       matchday       player      team    oppteam  home  vote  goals  assists  \
# 0            1        Musso  Atalanta  Sampdoria     0   6.0      0        0
# 1            1        Toloi  Atalanta  Sampdoria     0   7.0      1        0
# 2            1     Djimsiti  Atalanta  Sampdoria     0   6.0      0        0
# 3            1     Hateboer  Atalanta  Sampdoria     0   6.0      0        0
# 4            1        Okoli  Atalanta  Sampdoria     0   5.5      0        0
# ...        ...          ...       ...        ...   ...   ...    ...      ...
# 5423        19         Ilic    Verona      Lecce     1   7.0      0        1
# 5424        19  Sulemana I.    Verona      Lecce     1   6.0      0        0
# 5425        19      Lasagna    Verona      Lecce     1   5.5      0        0
# 5426        19       Kallon    Verona      Lecce     1   6.0      0        0
# 5427        19       Djuric    Verona      Lecce     1   6.0      0        0
#
#       cards_malus  fantavote  ... touches_live_ball dribbles_completed  \
# 0             0.5        5.5  ...          0.000000           0.000000
# 1             0.0       10.0  ...          0.684211           0.000849
# 2             0.0        6.0  ...          0.753541           0.000000
# 3             0.5        5.5  ...          0.586090           0.003393
# 4             0.5        5.0  ...          0.607101           0.000000
# ...           ...        ...  ...               ...                ...
# 5423          0.0        8.0  ...          0.572268           0.007051
# 5424          0.0        6.0  ...          0.477966           0.010169
# 5425          0.0        5.5  ...          0.301282           0.007479
# 5426          0.0        6.0  ...          0.409310           0.008026
# 5427          0.0        6.0  ...          0.516181           0.001618
#
#       dribbles passes_received  miscontrols  dispossessed     fouls    fouled  \
# 0     0.000000        0.000000     0.000000      0.000000  0.000000  0.000000
# 1     0.005093        0.407470     0.007640      0.000849  0.006791  0.005093
# 2     0.002833        0.521246     0.002833      0.008499  0.002833  0.002833
# 3     0.006785        0.357082     0.006785      0.004241  0.012723  0.001696
# 4     0.001183        0.279290     0.013018      0.003550  0.015385  0.008284
# ...        ...             ...          ...           ...       ...       ...
# 5423  0.018801        0.277321     0.019976      0.005875  0.010576  0.010576
# 5424  0.030508        0.206780     0.016949      0.013559  0.020339  0.006780
# 5425  0.025641        0.191239     0.036325      0.025641  0.019231  0.017094
# 5426  0.033708        0.293740     0.033708      0.024077  0.017657  0.027287
# 5427  0.004854        0.451456     0.027508      0.006472  0.024272  0.021036
#
#       aerials_won  aerials_lost
# 0        0.000000      0.000000
# 1        0.016129      0.011885
# 2        0.005666      0.008499
# 3        0.015267      0.011874
# 4        0.047337      0.027219
# ...           ...           ...
# 5423     0.011751      0.015276
# 5424     0.020339      0.027119
# 5425     0.007479      0.032051
# 5426     0.011236      0.025682
# 5427     0.166667      0.043689
#
# [5428 rows x 131 columns]

# %% [markdown]
# Remove undesired database entries.

# %%
db = db.drop(db[db.r == 'P'].index) # remove goalkeepers
db = db.drop(db[db.r != db.r].index) # remove non existing players (by searching NaN values)
db = db.drop(db[db.xg != db.xg].index)

# %%
db
# Out:
#       matchday       player      team    oppteam  home  vote  goals  assists  \
# 1            1        Toloi  Atalanta  Sampdoria     0   7.0      1        0
# 2            1     Djimsiti  Atalanta  Sampdoria     0   6.0      0        0
# 3            1     Hateboer  Atalanta  Sampdoria     0   6.0      0        0
# 4            1        Okoli  Atalanta  Sampdoria     0   5.5      0        0
# 5            1       Zortea  Atalanta  Sampdoria     0   6.0      0        0
# ...        ...          ...       ...        ...   ...   ...    ...      ...
# 5423        19         Ilic    Verona      Lecce     1   7.0      0        1
# 5424        19  Sulemana I.    Verona      Lecce     1   6.0      0        0
# 5425        19      Lasagna    Verona      Lecce     1   5.5      0        0
# 5426        19       Kallon    Verona      Lecce     1   6.0      0        0
# 5427        19       Djuric    Verona      Lecce     1   6.0      0        0
#
#       cards_malus  fantavote  ... touches_live_ball dribbles_completed  \
# 1             0.0       10.0  ...          0.684211           0.000849
# 2             0.0        6.0  ...          0.753541           0.000000
# 3             0.5        5.5  ...          0.586090           0.003393
# 4             0.5        5.0  ...          0.607101           0.000000
# 5             0.5        5.5  ...          0.648649           0.045045
# ...           ...        ...  ...               ...                ...
# 5423          0.0        8.0  ...          0.572268           0.007051
# 5424          0.0        6.0  ...          0.477966           0.010169
# 5425          0.0        5.5  ...          0.301282           0.007479
# 5426          0.0        6.0  ...          0.409310           0.008026
# 5427          0.0        6.0  ...          0.516181           0.001618
#
#       dribbles passes_received  miscontrols  dispossessed     fouls    fouled  \
# 1     0.005093        0.407470     0.007640      0.000849  0.006791  0.005093
# 2     0.002833        0.521246     0.002833      0.008499  0.002833  0.002833
# 3     0.006785        0.357082     0.006785      0.004241  0.012723  0.001696
# 4     0.001183        0.279290     0.013018      0.003550  0.015385  0.008284
# 5     0.094595        0.364865     0.027027      0.009009  0.018018  0.000000
# ...        ...             ...          ...           ...       ...       ...
# 5423  0.018801        0.277321     0.019976      0.005875  0.010576  0.010576
# 5424  0.030508        0.206780     0.016949      0.013559  0.020339  0.006780
# 5425  0.025641        0.191239     0.036325      0.025641  0.019231  0.017094
# 5426  0.033708        0.293740     0.033708      0.024077  0.017657  0.027287
# 5427  0.004854        0.451456     0.027508      0.006472  0.024272  0.021036
#
#       aerials_won  aerials_lost
# 1        0.016129      0.011885
# 2        0.005666      0.008499
# 3        0.015267      0.011874
# 4        0.047337      0.027219
# 5        0.022523      0.004505
# ...           ...           ...
# 5423     0.011751      0.015276
# 5424     0.020339      0.027119
# 5425     0.007479      0.032051
# 5426     0.011236      0.025682
# 5427     0.166667      0.043689
#
# [4906 rows x 131 columns]

# %% [markdown]
# Save outfield players database to file.

# %%
db.to_excel('mid_outputs/database_entries.xlsx')

# %% [markdown]
# Do the same process for goalkeepers, generating a different database.

# %%
for i in range(db.columns.shape[0]):
    print(str(i) + " - " + str(db.columns[i]))
# Out:
# 0 - matchday
# 1 - player
# 2 - team
# 3 - oppteam
# 4 - home
# 5 - vote
# 6 - goals
# 7 - assists
# 8 - cards_malus
# 9 - fantavote
# 10 - r
# 11 - games
# 12 - games_starts
# 13 - minutes
# 14 - shots_on_target_pct
# 15 - goals_per_shot
# 16 - goals_per_shot_on_target
# 17 - passes_pct
# 18 - dribble_tackles_pct
# 19 - dribbles_completed_pct
# 20 - aerials_won_pct
# 21 - team_possession
# 22 - team_goals_assists_per90
# 23 - team_goals_pens_per90
# 24 - team_goals_assists_pens_per90
# 25 - team_xg_per90
# 26 - team_gk_goals_against_per90
# 27 - team_gk_save_pct
# 28 - team_gk_clean_sheets_pct
# 29 - team_passes_pct
# 30 - team_passes_pct_medium
# 31 - team_passes_pct_long
# 32 - team_sca_per90
# 33 - team_gca_per90
# 34 - team_dribble_tackles_pct
# 35 - team_aerials_won_pct
# 36 - vs_team_possession
# 37 - vs_team_goals_per90
# 38 - vs_team_assists_per90
# 39 - vs_team_xg_per90
# 40 - vs_team_gk_save_pct
# 41 - vs_team_gk_clean_sheets_pct
# 42 - vs_team_gk_pct_passes_launched
# 43 - vs_team_gk_crosses_stopped_pct
# 44 - vs_team_shots_on_target_per90
# 45 - vs_team_passes_pct
# 46 - vs_team_passes_pct_short
# 47 - vs_team_passes_pct_medium
# 48 - vs_team_passes_pct_long
# 49 - vs_team_sca_per90
# 50 - vs_team_gca_per90
# 51 - vs_team_dribble_tackles_pct
# 52 - vs_team_dribbles_completed_pct
# 53 - vs_team_aerials_won_pct
# 54 - opp_team_possession
# 55 - opp_team_goals_assists_per90
# 56 - opp_team_goals_pens_per90
# 57 - opp_team_goals_assists_pens_per90
# 58 - opp_team_xg_per90
# 59 - opp_team_gk_goals_against_per90
# 60 - opp_team_gk_save_pct
# 61 - opp_team_gk_clean_sheets_pct
# 62 - opp_team_passes_pct
# 63 - opp_team_passes_pct_medium
# 64 - opp_team_passes_pct_long
# 65 - opp_team_sca_per90
# 66 - opp_team_gca_per90
# 67 - opp_team_dribble_tackles_pct
# 68 - opp_team_aerials_won_pct
# 69 - opp_vs_team_possession
# 70 - opp_vs_team_goals_per90
# 71 - opp_vs_team_assists_per90
# 72 - opp_vs_team_xg_per90
# 73 - opp_vs_team_gk_save_pct
# 74 - opp_vs_team_gk_clean_sheets_pct
# 75 - opp_vs_team_gk_pct_passes_launched
# 76 - opp_vs_team_gk_crosses_stopped_pct
# 77 - opp_vs_team_shots_on_target_per90
# 78 - opp_vs_team_passes_pct
# 79 - opp_vs_team_passes_pct_short
# 80 - opp_vs_team_passes_pct_medium
# 81 - opp_vs_team_passes_pct_long
# 82 - opp_vs_team_sca_per90
# 83 - opp_vs_team_gca_per90
# 84 - opp_vs_team_dribble_tackles_pct
# 85 - opp_vs_team_dribbles_completed_pct
# 86 - opp_vs_team_aerials_won_pct
# 87 - vote_avg
# 88 - vote_std
# 89 - goals
# 90 - assists
# 91 - cards_yellow
# 92 - cards_red
# 93 - xg
# 94 - npxg
# 95 - shots_on_target
# 96 - passes_completed
# 97 - passes_into_final_third
# 98 - passes_into_penalty_area
# 99 - progressive_passes
# 100 - passes_live
# 101 - passes_dead
# 102 - through_balls
# 103 - passes_switches
# 104 - crosses
# 105 - corner_kicks
# 106 - dribble_tackles
# 107 - dribbles_vs
# 108 - dribbled_past
# 109 - blocks
# 110 - blocked_shots
# 111 - blocked_passes
# 112 - interceptions
# 113 - clearances
# 114 - errors
# 115 - touches
# 116 - touches_def_pen_area
# 117 - touches_def_3rd
# 118 - touches_mid_3rd
# 119 - touches_att_3rd
# 120 - touches_att_pen_area
# 121 - touches_live_ball
# 122 - dribbles_completed
# 123 - dribbles
# 124 - passes_received
# 125 - miscontrols
# 126 - dispossessed
# 127 - fouls
# 128 - fouled
# 129 - aerials_won
# 130 - aerials_lost

# %%
rx = pd.read_excel('tmp/playermatchdata_sel_gk.xlsx', index_col = 0, header = None)   

out = list()

for i in range(1, rx.shape[1]):
        if(rx[i][2] == "x"):
            out.append(rx[i][0])
            
out
# Out:
# ['r',
#  'fb_ID',
#  'gk_games',
#  'gk_games_starts',
#  'gk_minutes',
#  'gk_goals_against_per90',
#  'gk_shots_on_target_against',
#  'gk_saves',
#  'gk_save_pct',
#  'gk_clean_sheets_pct',
#  'gk_free_kick_goals_against',
#  'gk_corner_kick_goals_against',
#  'gk_own_goals_against',
#  'gk_psxg',
#  'gk_psnpxg_per_shot_on_target_against',
#  'gk_psxg_net',
#  'gk_psxg_net_per90',
#  'gk_passes_completed_launched',
#  'gk_passes_launched',
#  'gk_passes_pct_launched',
#  'gk_passes',
#  'gk_passes_throws',
#  'gk_pct_passes_launched',
#  'gk_passes_length_avg',
#  'gk_goal_kicks',
#  'gk_pct_goal_kicks_launched',
#  'gk_goal_kick_length_avg',
#  'gk_crosses',
#  'gk_crosses_stopped',
#  'gk_crosses_stopped_pct',
#  'gk_def_actions_outside_pen_area',
#  'gk_def_actions_outside_pen_area_per90',
#  'gk_avg_distance_def_actions',
#  'team_possession',
#  'team_goals_assists_per90',
#  'team_goals_pens_per90',
#  'team_goals_assists_pens_per90',
#  'team_xg_per90',
#  'team_gk_goals_against_per90',
#  'team_gk_save_pct',
#  'team_gk_clean_sheets_pct',
#  'team_passes_pct',
#  'team_passes_pct_medium',
#  'team_passes_pct_long',
#  'team_sca_per90',
#  'team_gca_per90',
#  'team_dribble_tackles_pct',
#  'team_aerials_won_pct',
#  'vs_team_possession',
#  'vs_team_goals_per90',
#  'vs_team_assists_per90',
#  'vs_team_xg_per90',
#  'vs_team_gk_save_pct',
#  'vs_team_gk_clean_sheets_pct',
#  'vs_team_gk_pct_passes_launched',
#  'vs_team_gk_crosses_stopped_pct',
#  'vs_team_shots_on_target_per90',
#  'vs_team_passes_pct',
#  'vs_team_passes_pct_short',
#  'vs_team_passes_pct_medium',
#  'vs_team_passes_pct_long',
#  'vs_team_sca_per90',
#  'vs_team_gca_per90',
#  'vs_team_dribble_tackles_pct',
#  'vs_team_dribbles_completed_pct',
#  'vs_team_aerials_won_pct']

# %%
features_abs_gk = [
 'gk_games',
 'gk_games_starts',
 'gk_minutes',
 'gk_goals_against_per90', 
 'gk_save_pct',
 'gk_clean_sheets_pct',
 'gk_psxg_net_per90',
 'gk_passes_pct_launched',
 'gk_pct_passes_launched',
 'gk_passes_length_avg',
 'gk_pct_goal_kicks_launched',
 'gk_goal_kick_length_avg',
 'gk_crosses_stopped_pct',
 'gk_def_actions_outside_pen_area_per90',
 'gk_avg_distance_def_actions',
    
 'team_possession',
 'team_goals_assists_per90',
 'team_goals_pens_per90',
 'team_goals_assists_pens_per90',
 'team_xg_per90',
 'team_gk_goals_against_per90',
 'team_gk_save_pct',
 'team_gk_clean_sheets_pct',
 'team_passes_pct',
 'team_passes_pct_medium',
 'team_passes_pct_long',
 'team_sca_per90',
 'team_gca_per90',
 'team_dribble_tackles_pct',
 'team_aerials_won_pct',
 'vs_team_possession',
 'vs_team_goals_per90',
 'vs_team_assists_per90',
 'vs_team_xg_per90',
 'vs_team_gk_save_pct',
 'vs_team_gk_clean_sheets_pct',
 'vs_team_gk_pct_passes_launched',
 'vs_team_gk_crosses_stopped_pct',
 'vs_team_shots_on_target_per90',
 'vs_team_passes_pct',
 'vs_team_passes_pct_short',
 'vs_team_passes_pct_medium',
 'vs_team_passes_pct_long',
 'vs_team_sca_per90',
 'vs_team_gca_per90',
 'vs_team_dribble_tackles_pct',
 'vs_team_dribbles_completed_pct',
 'vs_team_aerials_won_pct',
 'opp_team_possession',
 'opp_team_goals_assists_per90',
 'opp_team_goals_pens_per90',
 'opp_team_goals_assists_pens_per90',
 'opp_team_xg_per90',
 'opp_team_gk_goals_against_per90',
 'opp_team_gk_save_pct',
 'opp_team_gk_clean_sheets_pct',
 'opp_team_passes_pct',
 'opp_team_passes_pct_medium',
 'opp_team_passes_pct_long',
 'opp_team_sca_per90',
 'opp_team_gca_per90',
 'opp_team_dribble_tackles_pct',
 'opp_team_aerials_won_pct',
 'opp_vs_team_possession',
 'opp_vs_team_goals_per90',
 'opp_vs_team_assists_per90',
 'opp_vs_team_xg_per90',
 'opp_vs_team_gk_save_pct',
 'opp_vs_team_gk_clean_sheets_pct',
 'opp_vs_team_gk_pct_passes_launched',
 'opp_vs_team_gk_crosses_stopped_pct',
 'opp_vs_team_shots_on_target_per90',
 'opp_vs_team_passes_pct',
 'opp_vs_team_passes_pct_short',
 'opp_vs_team_passes_pct_medium',
 'opp_vs_team_passes_pct_long',
 'opp_vs_team_sca_per90',
 'opp_vs_team_gca_per90',
 'opp_vs_team_dribble_tackles_pct',
 'opp_vs_team_dribbles_completed_pct',
 'opp_vs_team_aerials_won_pct',
                
 'vote_avg',
 'vote_std']

features_rel_gk = [
 'gk_shots_on_target_against',
 'gk_saves',
 'gk_free_kick_goals_against',
 'gk_corner_kick_goals_against',
 'gk_own_goals_against',
 'gk_psxg',
 'gk_psnpxg_per_shot_on_target_against',
 'gk_psxg_net',
 'gk_passes_completed_launched',
 'gk_passes_launched',
 'gk_passes',
 'gk_passes_throws',
 'gk_goal_kicks',
 'gk_crosses',
 'gk_crosses_stopped',
]

# %%
def player_match_data_ext_gk(player, pteam, oppteam):
    pdata = player_match_data(player, pteam, oppteam)
    
    if(not isinstance(pdata, pd.DataFrame)):
        return None
    
    if(pdata['gk_games'][0] <= 0):
        return None
    
    out = pd.concat([pdata[features_abs_gk], pdata[features_rel_gk]], axis = 1)
    
    out[features_rel_gk] = out[features_rel_gk] / max(pdata['minutes'][0], 1)

    return out

# %%
test = player_match_data_ext_gk('Consigli', 'Sassuolo', 'Atalanta')

add_columns_gk = test.columns

test
# Out:
#           gk_games  gk_games_starts  gk_minutes  gk_goals_against_per90  \
# Consigli      17.0             17.0      1530.0                    1.53
#
#           gk_save_pct  gk_clean_sheets_pct  gk_psxg_net_per90  \
# Consigli         56.6                 29.4              -0.26
#
#           gk_passes_pct_launched  gk_pct_passes_launched  \
# Consigli                    41.3                    30.9
#
#           gk_passes_length_avg  ...  gk_psxg  \
# Consigli                  34.4  ...     21.6
#
#           gk_psnpxg_per_shot_on_target_against  gk_psxg_net  \
# Consigli                                  0.37         -4.4
#
#           gk_passes_completed_launched  gk_passes_launched  gk_passes  \
# Consigli                         100.0               242.0      621.0
#
#           gk_passes_throws  gk_goal_kicks  gk_crosses  gk_crosses_stopped
# Consigli              87.0          157.0       220.0                13.0
#
# [1 rows x 98 columns]

# %%
db_gk = votes.copy()

delta = pd.DataFrame(columns = add_columns_gk)

for i in range(db_gk.shape[0]):
    ext_data = player_match_data_ext_gk(db_gk['player'][i], db_gk['team'][i], db_gk['oppteam'][i])
    
    if(i % 100 == 0):
        print(i)
        
    if(not isinstance(ext_data, pd.DataFrame)):
        continue
    
    ext_data = ext_data.rename(index = {db_gk['player'][i] : i})
    
    delta = pd.concat([delta, ext_data], axis = 0)
    
    
    
db_gk = pd.concat([db_gk, delta], axis = 1)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400

# %%
db_gk
# Out:
#       matchday       player      team    oppteam  home  vote  goals  assists  \
# 0            1        Musso  Atalanta  Sampdoria     0   6.0      0        0
# 1            1        Toloi  Atalanta  Sampdoria     0   7.0      1        0
# 2            1     Djimsiti  Atalanta  Sampdoria     0   6.0      0        0
# 3            1     Hateboer  Atalanta  Sampdoria     0   6.0      0        0
# 4            1        Okoli  Atalanta  Sampdoria     0   5.5      0        0
# ...        ...          ...       ...        ...   ...   ...    ...      ...
# 5423        19         Ilic    Verona      Lecce     1   7.0      0        1
# 5424        19  Sulemana I.    Verona      Lecce     1   6.0      0        0
# 5425        19      Lasagna    Verona      Lecce     1   5.5      0        0
# 5426        19       Kallon    Verona      Lecce     1   6.0      0        0
# 5427        19       Djuric    Verona      Lecce     1   6.0      0        0
#
#       cards_malus  fantavote  ...  gk_psxg  \
# 0             0.5        5.5  ...     10.4
# 1             0.0       10.0  ...      NaN
# 2             0.0        6.0  ...      NaN
# 3             0.5        5.5  ...      NaN
# 4             0.5        5.0  ...      NaN
# ...           ...        ...  ...      ...
# 5423          0.0        8.0  ...      NaN
# 5424          0.0        6.0  ...      NaN
# 5425          0.0        5.5  ...      NaN
# 5426          0.0        6.0  ...      NaN
# 5427          0.0        6.0  ...      NaN
#
#       gk_psnpxg_per_shot_on_target_against  gk_psxg_net  \
# 0                                     0.22         -2.6
# 1                                      NaN          NaN
# 2                                      NaN          NaN
# 3                                      NaN          NaN
# 4                                      NaN          NaN
# ...                                    ...          ...
# 5423                                   NaN          NaN
# 5424                                   NaN          NaN
# 5425                                   NaN          NaN
# 5426                                   NaN          NaN
# 5427                                   NaN          NaN
#
#       gk_passes_completed_launched  gk_passes_launched  gk_passes  \
# 0                             78.0               167.0      321.0
# 1                              NaN                 NaN        NaN
# 2                              NaN                 NaN        NaN
# 3                              NaN                 NaN        NaN
# 4                              NaN                 NaN        NaN
# ...                            ...                 ...        ...
# 5423                           NaN                 NaN        NaN
# 5424                           NaN                 NaN        NaN
# 5425                           NaN                 NaN        NaN
# 5426                           NaN                 NaN        NaN
# 5427                           NaN                 NaN        NaN
#
#       gk_passes_throws  gk_goal_kicks  gk_crosses  gk_crosses_stopped
# 0                 93.0           86.0       147.0                 8.0
# 1                  NaN            NaN         NaN                 NaN
# 2                  NaN            NaN         NaN                 NaN
# 3                  NaN            NaN         NaN                 NaN
# 4                  NaN            NaN         NaN                 NaN
# ...                ...            ...         ...                 ...
# 5423               NaN            NaN         NaN                 NaN
# 5424               NaN            NaN         NaN                 NaN
# 5425               NaN            NaN         NaN                 NaN
# 5426               NaN            NaN         NaN                 NaN
# 5427               NaN            NaN         NaN                 NaN
#
# [5428 rows x 108 columns]

# %%
db_gk = db_gk.drop(db_gk[db_gk.gk_games != db_gk.gk_games].index) # remove non extisting players

# %%
db_gk
# Out:
#       matchday               player        team     oppteam  home  vote  \
# 0            1                Musso    Atalanta   Sampdoria     0   6.0
# 15           1            Skorupski     Bologna       Lazio     0   6.5
# 44           1              Vicario      Empoli      Spezia     0   5.5
# 57           1              Gollini  Fiorentina   Cremonese     1   5.0
# 71           1           Handanovic       Inter       Lecce     0   6.5
# ...        ...                  ...         ...         ...   ...   ...
# 5362        19               Pegolo    Sassuolo       Monza     0   6.5
# 5374        19            Dragowski      Spezia        Roma     1   6.0
# 5388        19  Milinkovic-Savic V.      Torino  Fiorentina     0   7.0
# 5401        19            Silvestri     Udinese   Sampdoria     0   6.0
# 5414        19             Montipo'      Verona       Lecce     1   6.5
#
#       goals  assists  cards_malus  fantavote  ...    gk_psxg  \
# 0         0        0          0.5        5.5  ...  10.400000
# 15       -2        0          0.0        4.5  ...  28.700000
# 44       -1        0          0.0        4.5  ...  24.000000
# 57       -2        0          0.0        3.0  ...  15.600000
# 71       -1        0          0.0        5.5  ...  10.600000
# ...     ...      ...          ...        ...  ...        ...
# 5362     -1        0          0.0        5.5  ...  15.466667
# 5374     -2        0          0.0        4.0  ...  26.000000
# 5388      0        0          0.0        7.0  ...  20.300000
# 5401      0        0          0.0        6.0  ...  22.100000
# 5414      0        0          0.0        6.5  ...  25.200000
#
#       gk_psnpxg_per_shot_on_target_against  gk_psxg_net  \
# 0                                 0.220000    -2.600000
# 15                                0.280000     0.700000
# 44                                0.270000     2.000000
# 57                                0.270000     1.600000
# 71                                0.300000    -1.400000
# ...                                    ...          ...
# 5362                              0.373333    -2.866667
# 5374                              0.280000    -3.000000
# 5388                              0.240000     0.300000
# 5401                              0.320000     1.100000
# 5414                              0.250000    -4.800000
#
#       gk_passes_completed_launched  gk_passes_launched   gk_passes  \
# 0                        78.000000          167.000000  321.000000
# 15                       87.000000          219.000000  545.000000
# 44                       88.000000          277.000000  690.000000
# 57                       34.000000           92.000000  425.000000
# 71                       27.000000           52.000000  266.000000
# ...                            ...                 ...         ...
# 5362                     69.666667          167.333333  434.333333
# 5374                     85.000000          255.000000  479.000000
# 5388                    138.000000          493.000000  746.000000
# 5401                     76.000000          200.000000  406.000000
# 5414                    176.000000          358.000000  447.000000
#
#       gk_passes_throws  gk_goal_kicks  gk_crosses  gk_crosses_stopped
# 0            93.000000           86.0       147.0            8.000000
# 15          116.000000          141.0       280.0           18.000000
# 44          108.000000          103.0       399.0           25.000000
# 57           69.000000          114.0       197.0            6.000000
# 71           46.000000           45.0        79.0            2.000000
# ...                ...            ...         ...                 ...
# 5362         61.333333          110.0       156.0            9.333333
# 5374         87.000000          106.0       235.0            9.000000
# 5388         85.000000          142.0       232.0           18.000000
# 5401         72.000000          153.0       253.0            4.000000
# 5414         62.000000          153.0       261.0           10.000000
#
# [375 rows x 108 columns]

# %% [markdown]
# Save goalkeepers players database to file.

# %%
db_gk.to_excel('mid_outputs/database_entries_gk.xlsx')

# %%
for i in range(db_gk.columns.shape[0]):
    print(str(i) + " - " + str(db_gk.columns[i]))
# Out:
# 0 - matchday
# 1 - player
# 2 - team
# 3 - oppteam
# 4 - home
# 5 - vote
# 6 - goals
# 7 - assists
# 8 - cards_malus
# 9 - fantavote
# 10 - gk_games
# 11 - gk_games_starts
# 12 - gk_minutes
# 13 - gk_goals_against_per90
# 14 - gk_save_pct
# 15 - gk_clean_sheets_pct
# 16 - gk_psxg_net_per90
# 17 - gk_passes_pct_launched
# 18 - gk_pct_passes_launched
# 19 - gk_passes_length_avg
# 20 - gk_pct_goal_kicks_launched
# 21 - gk_goal_kick_length_avg
# 22 - gk_crosses_stopped_pct
# 23 - gk_def_actions_outside_pen_area_per90
# 24 - gk_avg_distance_def_actions
# 25 - team_possession
# 26 - team_goals_assists_per90
# 27 - team_goals_pens_per90
# 28 - team_goals_assists_pens_per90
# 29 - team_xg_per90
# 30 - team_gk_goals_against_per90
# 31 - team_gk_save_pct
# 32 - team_gk_clean_sheets_pct
# 33 - team_passes_pct
# 34 - team_passes_pct_medium
# 35 - team_passes_pct_long
# 36 - team_sca_per90
# 37 - team_gca_per90
# 38 - team_dribble_tackles_pct
# 39 - team_aerials_won_pct
# 40 - vs_team_possession
# 41 - vs_team_goals_per90
# 42 - vs_team_assists_per90
# 43 - vs_team_xg_per90
# 44 - vs_team_gk_save_pct
# 45 - vs_team_gk_clean_sheets_pct
# 46 - vs_team_gk_pct_passes_launched
# 47 - vs_team_gk_crosses_stopped_pct
# 48 - vs_team_shots_on_target_per90
# 49 - vs_team_passes_pct
# 50 - vs_team_passes_pct_short
# 51 - vs_team_passes_pct_medium
# 52 - vs_team_passes_pct_long
# 53 - vs_team_sca_per90
# 54 - vs_team_gca_per90
# 55 - vs_team_dribble_tackles_pct
# 56 - vs_team_dribbles_completed_pct
# 57 - vs_team_aerials_won_pct
# 58 - opp_team_possession
# 59 - opp_team_goals_assists_per90
# 60 - opp_team_goals_pens_per90
# 61 - opp_team_goals_assists_pens_per90
# 62 - opp_team_xg_per90
# 63 - opp_team_gk_goals_against_per90
# 64 - opp_team_gk_save_pct
# 65 - opp_team_gk_clean_sheets_pct
# 66 - opp_team_passes_pct
# 67 - opp_team_passes_pct_medium
# 68 - opp_team_passes_pct_long
# 69 - opp_team_sca_per90
# 70 - opp_team_gca_per90
# 71 - opp_team_dribble_tackles_pct
# 72 - opp_team_aerials_won_pct
# 73 - opp_vs_team_possession
# 74 - opp_vs_team_goals_per90
# 75 - opp_vs_team_assists_per90
# 76 - opp_vs_team_xg_per90
# 77 - opp_vs_team_gk_save_pct
# 78 - opp_vs_team_gk_clean_sheets_pct
# 79 - opp_vs_team_gk_pct_passes_launched
# 80 - opp_vs_team_gk_crosses_stopped_pct
# 81 - opp_vs_team_shots_on_target_per90
# 82 - opp_vs_team_passes_pct
# 83 - opp_vs_team_passes_pct_short
# 84 - opp_vs_team_passes_pct_medium
# 85 - opp_vs_team_passes_pct_long
# 86 - opp_vs_team_sca_per90
# 87 - opp_vs_team_gca_per90
# 88 - opp_vs_team_dribble_tackles_pct
# 89 - opp_vs_team_dribbles_completed_pct
# 90 - opp_vs_team_aerials_won_pct
# 91 - vote_avg
# 92 - vote_std
# 93 - gk_shots_on_target_against
# 94 - gk_saves
# 95 - gk_free_kick_goals_against
# 96 - gk_corner_kick_goals_against
# 97 - gk_own_goals_against
# 98 - gk_psxg
# 99 - gk_psnpxg_per_shot_on_target_against
# 100 - gk_psxg_net
# 101 - gk_passes_completed_launched
# 102 - gk_passes_launched
# 103 - gk_passes
# 104 - gk_passes_throws
# 105 - gk_goal_kicks
# 106 - gk_crosses
# 107 - gk_crosses_stopped
