# %% [markdown]
# Player/match dataset creation
#
# For each serie A (already happened) match and player, a database entry is generated, with this form:
#
# [y = player votes data, player data, team data, vs team data, opp team data, vs opp team data]

# %%
import pandas as pd

# %% [markdown]
# Load team data from FBref

# %%
rcsv = pd.read_csv('fbref_data/teams.csv')   
team = pd.DataFrame(rcsv)

rcsv = pd.read_csv('fbref_data/teams_vs.csv')   
vs_team = pd.DataFrame(rcsv)

for i in range(1, team.shape[1]):
    team = team.rename(columns = {team.columns[i] : 'team_' + team.columns[i]})
    
for i in range(1, vs_team.shape[1]):
    vs_team = vs_team.rename(columns = {vs_team.columns[i] : 'vs_team_' + vs_team.columns[i]})
    
vs_team.pop('team')

team_data = pd.concat([team, vs_team], axis = 1)

team_data['team_idx'] = team_data['team']
for i in range(team_data.shape[0]):
    team_data.loc[i, 'team_idx'] = team_data.loc[i, 'team_idx'].split(' ')[-1]

team_data = team_data.set_index('team_idx')

team_data
# Out:
#                       team  team_players_used  team_possession  team_games  \
# team_idx
# Atalanta          Atalanta               20.0             51.7         3.0
# Bologna            Bologna               20.0             55.3         3.0
# Cagliari          Cagliari               19.0             35.0         3.0
# Empoli              Empoli               26.0             48.0         3.0
# Fiorentina      Fiorentina               21.0             62.3         3.0
# Frosinone        Frosinone               21.0             46.0         3.0
# Genoa                Genoa               18.0             33.0         3.0
# Verona       Hellas Verona               19.0             44.7         3.0
# Inter                Inter               18.0             51.3         3.0
# Juventus          Juventus               21.0             53.0         3.0
# Lazio                Lazio               19.0             53.3         3.0
# Lecce                Lecce               18.0             45.0         3.0
# Milan                Milan               18.0             54.0         3.0
# Monza                Monza               21.0             55.3         3.0
# Napoli              Napoli               18.0             60.3         3.0
# Roma                  Roma               21.0             58.3         3.0
# Salernitana    Salernitana               21.0             50.0         3.0
# Sassuolo          Sassuolo               22.0             43.0         3.0
# Torino              Torino               20.0             53.7         3.0
# Udinese            Udinese               18.0             46.7         3.0
#
#              team_games_starts  team_minutes  team_goals  team_assists  \
# team_idx
# Atalanta                  33.0         270.0         6.0           6.0
# Bologna                   33.0         270.0         3.0           2.0
# Cagliari                  33.0         270.0         1.0           1.0
# Empoli                    33.0         270.0         0.0           0.0
# Fiorentina                33.0         270.0         6.0           5.0
# Frosinone                 33.0         270.0         3.0           2.0
# Genoa                     33.0         270.0         2.0           1.0
# Verona                    33.0         270.0         4.0           2.0
# Inter                     33.0         270.0         8.0           7.0
# Juventus                  33.0         270.0         6.0           4.0
# Lazio                     33.0         270.0         3.0           3.0
# Lecce                     33.0         270.0         6.0           5.0
# Milan                     33.0         270.0         8.0           5.0
# Monza                     33.0         270.0         2.0           2.0
# Napoli                    33.0         270.0         6.0           3.0
# Roma                      33.0         270.0         4.0           3.0
# Salernitana               33.0         270.0         3.0           3.0
# Sassuolo                  33.0         270.0         3.0           2.0
# Torino                    33.0         270.0         2.0           2.0
# Udinese                   33.0         270.0         1.0           1.0
#
#              team_pens_made  team_pens_att  ...  vs_team_fouls  \
# team_idx                                    ...
# Atalanta                0.0            0.0  ...           28.0
# Bologna                 0.0            1.0  ...           32.0
# Cagliari                0.0            0.0  ...           27.0
# Empoli                  0.0            0.0  ...           45.0
# Fiorentina              0.0            0.0  ...           42.0
# Frosinone               1.0            1.0  ...           41.0
# Genoa                   0.0            0.0  ...           35.0
# Verona                  0.0            0.0  ...           37.0
# Inter                   1.0            1.0  ...           34.0
# Juventus                1.0            2.0  ...           39.0
# Lazio                   0.0            0.0  ...           36.0
# Lecce                   1.0            1.0  ...           47.0
# Milan                   3.0            3.0  ...           40.0
# Monza                   0.0            0.0  ...           26.0
# Napoli                  1.0            2.0  ...           33.0
# Roma                    0.0            0.0  ...           41.0
# Salernitana             0.0            0.0  ...           48.0
# Sassuolo                1.0            1.0  ...           35.0
# Torino                  0.0            0.0  ...           32.0
# Udinese                 0.0            0.0  ...           31.0
#
#              vs_team_fouled  vs_team_offsides  vs_team_pens_won  \
# team_idx
# Atalanta               33.0               2.0               0.0
# Bologna                30.0               7.0               0.0
# Cagliari               29.0               4.0               0.0
# Empoli                 38.0               6.0               1.0
# Fiorentina             36.0               3.0               1.0
# Frosinone              31.0               4.0               0.0
# Genoa                  31.0               6.0               0.0
# Verona                 47.0               6.0               1.0
# Inter                  30.0               3.0               0.0
# Juventus               36.0               5.0               0.0
# Lazio                  31.0               6.0               0.0
# Lecce                  43.0               4.0               0.0
# Milan                  31.0               5.0               0.0
# Monza                  35.0               6.0               0.0
# Napoli                 33.0               6.0               1.0
# Roma                   36.0               2.0               1.0
# Salernitana            34.0               2.0               0.0
# Sassuolo               25.0              10.0               1.0
# Torino                 33.0               5.0               1.0
# Udinese                41.0               7.0               0.0
#
#              vs_team_pens_conceded  vs_team_own_goals  \
# team_idx
# Atalanta                       0.0                0.0
# Bologna                        1.0                0.0
# Cagliari                       0.0                0.0
# Empoli                         0.0                0.0
# Fiorentina                     0.0                0.0
# Frosinone                      1.0                0.0
# Genoa                          0.0                0.0
# Verona                         0.0                0.0
# Inter                          1.0                0.0
# Juventus                       2.0                0.0
# Lazio                          0.0                0.0
# Lecce                          1.0                0.0
# Milan                          3.0                0.0
# Monza                          0.0                0.0
# Napoli                         2.0                0.0
# Roma                           0.0                0.0
# Salernitana                    0.0                0.0
# Sassuolo                       1.0                0.0
# Torino                         0.0                0.0
# Udinese                        0.0                0.0
#
#              vs_team_ball_recoveries  vs_team_aerials_won  \
# team_idx
# Atalanta                       157.0                 44.0
# Bologna                        157.0                 23.0
# Cagliari                       165.0                 44.0
# Empoli                         152.0                 42.0
# Fiorentina                     142.0                 38.0
# Frosinone                      168.0                 46.0
# Genoa                          148.0                 32.0
# Verona                         138.0                 54.0
# Inter                          128.0                 24.0
# Juventus                       134.0                 22.0
# Lazio                          155.0                 39.0
# Lecce                          150.0                 33.0
# Milan                          145.0                 34.0
# Monza                          144.0                 37.0
# Napoli                         124.0                 19.0
# Roma                           114.0                 45.0
# Salernitana                    151.0                 68.0
# Sassuolo                       159.0                 40.0
# Torino                         151.0                 46.0
# Udinese                        137.0                 38.0
#
#              vs_team_aerials_lost  vs_team_aerials_won_pct
# team_idx
# Atalanta                     42.0                     51.2
# Bologna                      29.0                     44.2
# Cagliari                     37.0                     54.3
# Empoli                       30.0                     58.3
# Fiorentina                   32.0                     54.3
# Frosinone                    42.0                     52.3
# Genoa                        44.0                     42.1
# Verona                       71.0                     43.2
# Inter                        36.0                     40.0
# Juventus                     26.0                     45.8
# Lazio                        26.0                     60.0
# Lecce                        46.0                     41.8
# Milan                        27.0                     55.7
# Monza                        27.0                     57.8
# Napoli                       33.0                     36.5
# Roma                         64.0                     41.3
# Salernitana                  37.0                     64.8
# Sassuolo                     30.0                     57.1
# Torino                       41.0                     52.9
# Udinese                      48.0                     44.2
#
# [20 rows x 303 columns]

# %%
team_data.to_excel('mid_outputs/team_data.xlsx')

# %% [markdown]
# Load data generated from players_dataset_creation

# %%
rx = pd.read_excel('mid_outputs/players_stats.xlsx', index_col = 3)   
players = pd.DataFrame(rx)

players
# Out:
#            Unnamed: 0    id  r         team    surname initial  fb_ID     age  \
# name
# Maignan             0  4312  P        Milan    Maignan     NaN    406  28-068
# Meret               1   572  P       Napoli      Meret     NaN    408  26-171
# Sommer              2  2428  P        Inter     Sommer     NaN    420  34-266
# Szczesny            3   453  P     Juventus   Szczesny     NaN    421  33-144
# Provedel            4  2814  P        Lazio   Provedel     NaN    416  29-176
# ...               ...   ... ..          ...        ...     ...    ...     ...
# Bidaoui           530  6242  A    Frosinone    Bidaoui     NaN     -1       0
# Burnete           531  6418  A        Lecce    Burnete     NaN     51  19-221
# Corfitzen         532  6419  A        Lecce  Corfitzen     NaN     -1       0
# Stewart           533  6427  A  Salernitana    Stewart     NaN     -1       0
# Yildiz            534  6434  A     Juventus     Yildiz     NaN     -1       0
#
#            birth_year  games  ...  gk_pct_goal_kicks_launched  \
# name                          ...
# Maignan          1995      0  ...                        65.0
# Meret            1997      0  ...                         0.0
# Sommer           1988      0  ...                        23.8
# Szczesny         1990      0  ...                        66.7
# Provedel         1994      0  ...                        27.3
# ...               ...    ...  ...                         ...
# Bidaoui             0      0  ...                         0.0
# Burnete          2004      1  ...                         0.0
# Corfitzen           0      0  ...                         0.0
# Stewart             0      0  ...                         0.0
# Yildiz              0      0  ...                         0.0
#
#            gk_goal_kick_length_avg  gk_crosses  gk_crosses_stopped  \
# name
# Maignan                       49.3          43                  12
# Meret                         21.4          15                   1
# Sommer                        31.0          35                   1
# Szczesny                      53.3          16                   1
# Provedel                      31.6          39                   2
# ...                            ...         ...                 ...
# Bidaoui                        0.0           0                   0
# Burnete                        0.0           0                   0
# Corfitzen                      0.0           0                   0
# Stewart                        0.0           0                   0
# Yildiz                         0.0           0                   0
#
#            gk_crosses_stopped_pct  gk_def_actions_outside_pen_area  \
# name
# Maignan                      27.9                                3
# Meret                         6.7                                5
# Sommer                        2.9                                0
# Szczesny                      6.3                                0
# Provedel                      5.1                                6
# ...                           ...                              ...
# Bidaoui                       0.0                                0
# Burnete                       0.0                                0
# Corfitzen                     0.0                                0
# Stewart                       0.0                                0
# Yildiz                        0.0                                0
#
#            gk_def_actions_outside_pen_area_per90  gk_avg_distance_def_actions  \
# name
# Maignan                                     1.00                         10.3
# Meret                                       1.67                         18.1
# Sommer                                      0.00                          6.8
# Szczesny                                    0.00                         10.8
# Provedel                                    2.00                         16.3
# ...                                          ...                          ...
# Bidaoui                                     0.00                          0.0
# Burnete                                     0.00                          0.0
# Corfitzen                                   0.00                          0.0
# Stewart                                     0.00                          0.0
# Yildiz                                      0.00                          0.0
#
#            vote_avg  vote_std
# name
# Maignan    6.000000  0.000000
# Meret      5.833333  0.235702
# Sommer     6.000000  0.000000
# Szczesny   7.000000  0.000000
# Provedel   6.166667  0.235702
# ...             ...       ...
# Bidaoui    6.455501  0.000000
# Burnete    6.000000  0.000000
# Corfitzen  5.900518  0.000000
# Stewart    5.417886  0.000000
# Yildiz     5.825580  0.000000
#
# [535 rows x 160 columns]

# %% [markdown]
# Function for merging match data (player, team, opponent team)

# %%
def player_match_data(player, pteam, oppteam):
    if(not(player in players.index)):
        return None
    
    pdata = players.loc[[player]]
    
    pteam_stats = team_data.loc[[pteam]].rename(index = {pteam : player})
    
    oppteam_stats = team_data.loc[[oppteam]].rename(index = {oppteam : player})
    
    oppteam_stats = oppteam_stats.rename(lambda x: 'opp_' + x, axis='columns')
    
    out = pd.concat([pdata, pteam_stats, oppteam_stats], axis = 1)
    
    return(out)

# %% [markdown]
# Output to excel file data for a player.
#
# The file is copied and there the desired features are manually selected and printed.

# %%
test = player_match_data('Barella', 'Inter', 'Atalanta')
test.to_excel('tmp/playermatchdata.xlsx')

test
# Out:
#          Unnamed: 0    id  r   team  surname initial  fb_ID     age  \
# Barella         259  1870  C  Inter  Barella     NaN     20  26-214
#
#          birth_year  games  ...  opp_vs_team_fouls  opp_vs_team_fouled  \
# Barella        1997      3  ...               28.0                33.0
#
#          opp_vs_team_offsides  opp_vs_team_pens_won  \
# Barella                   2.0                   0.0
#
#          opp_vs_team_pens_conceded  opp_vs_team_own_goals  \
# Barella                        0.0                    0.0
#
#          opp_vs_team_ball_recoveries  opp_vs_team_aerials_won  \
# Barella                        157.0                     44.0
#
#          opp_vs_team_aerials_lost  opp_vs_team_aerials_won_pct
# Barella                      42.0                         51.2
#
# [1 rows x 766 columns]

# %%
pteam = 'Inter'
pteam_stats = team_data.loc[[pteam]]
pteam_stats.index[0]
# Out:
# 'Inter'

# %%
rx = pd.read_excel('tmp/playermatchdata_sel.xlsx', index_col = 0, header = None)   

out = list()

for i in range(1, rx.shape[1]):
        if(rx[i][2] == "x"):
            out.append(rx[i][0])
            
out
# Out:
# ['r',
#  'fb_ID',
#  'games',
#  'games_starts',
#  'minutes',
#  'goals',
#  'assists',
#  'cards_yellow',
#  'cards_red',
#  'xg',
#  'npxg',
#  'shots_on_target',
#  'shots_on_target_pct',
#  'goals_per_shot',
#  'goals_per_shot_on_target',
#  'passes_completed',
#  'passes_pct',
#  'passes_into_final_third',
#  'passes_into_penalty_area',
#  'progressive_passes',
#  'passes_live',
#  'passes_dead',
#  'through_balls',
#  'passes_switches',
#  'crosses',
#  'corner_kicks',
#  'dribble_tackles',
#  'dribbles_vs',
#  'dribble_tackles_pct',
#  'dribbled_past',
#  'blocks',
#  'blocked_shots',
#  'blocked_passes',
#  'interceptions',
#  'clearances',
#  'errors',
#  'touches',
#  'touches_def_pen_area',
#  'touches_def_3rd',
#  'touches_mid_3rd',
#  'touches_att_3rd',
#  'touches_att_pen_area',
#  'touches_live_ball',
#  'dribbles_completed',
#  'dribbles',
#  'dribbles_completed_pct',
#  'carries',
#  'progressive_carries',
#  'carries_into_final_third',
#  'carries_into_penalty_area',
#  'passes_received',
#  'miscontrols',
#  'dispossessed',
#  'fouls',
#  'fouled',
#  'aerials_won',
#  'aerials_lost',
#  'aerials_won_pct',
#  'team_possession',
#  'team_goals_assists_per90',
#  'team_goals_pens_per90',
#  'team_goals_assists_pens_per90',
#  'team_xg_per90',
#  'team_gk_goals_against_per90',
#  'team_gk_save_pct',
#  'team_gk_clean_sheets_pct',
#  'team_passes_pct',
#  'team_passes_pct_medium',
#  'team_passes_pct_long',
#  'team_sca_per90',
#  'team_gca_per90',
#  'team_dribble_tackles_pct',
#  'team_aerials_won_pct',
#  'vs_team_possession',
#  'vs_team_goals_per90',
#  'vs_team_assists_per90',
#  'vs_team_xg_per90',
#  'vs_team_gk_save_pct',
#  'vs_team_gk_clean_sheets_pct',
#  'vs_team_gk_pct_passes_launched',
#  'vs_team_gk_crosses_stopped_pct',
#  'vs_team_shots_on_target_per90',
#  'vs_team_passes_pct',
#  'vs_team_passes_pct_short',
#  'vs_team_passes_pct_medium',
#  'vs_team_passes_pct_long',
#  'vs_team_sca_per90',
#  'vs_team_gca_per90',
#  'vs_team_dribble_tackles_pct',
#  'vs_team_dribbles_completed_pct',
#  'vs_team_aerials_won_pct']

# %% [markdown]
# Define and select the dataset features: abs features and rel features.
#
# Rel features are divided by the player minutes played.
#
# Rel features (game corrected) are divided by the player number of games instead of minutes.
# For example, a player who plays 20 minutes and scores, would be to match for stats averaging. It is better to consider the goals made per match.

# %%
features_abs = ['r',
 'games',
 'games_starts',                
 'minutes',
 'shots_on_target_pct',
 'goals_per_shot',
 'goals_per_shot_on_target',
 'passes_pct',
 #'dribble_tackles_pct',
 #'dribbles_completed_pct',
 'aerials_won_pct',
 'team_possession',
 'team_goals_assists_per90',
 'team_goals_pens_per90',
 'team_goals_assists_pens_per90',
 'team_xg_per90',
 'team_gk_goals_against_per90',
 'team_gk_save_pct',
 'team_gk_clean_sheets_pct',
 'team_passes_pct',
 'team_passes_pct_medium',
 'team_passes_pct_long',
 'team_sca_per90',
 'team_gca_per90',
 #'team_dribble_tackles_pct',
 'team_aerials_won_pct',
 'vs_team_possession',
 'vs_team_goals_per90',
 'vs_team_assists_per90',
 'vs_team_xg_per90',
 'vs_team_gk_save_pct',
 'vs_team_gk_clean_sheets_pct',
 'vs_team_gk_pct_passes_launched',
 'vs_team_gk_crosses_stopped_pct',
 'vs_team_shots_on_target_per90',
 'vs_team_passes_pct',
 'vs_team_passes_pct_short',
 'vs_team_passes_pct_medium',
 'vs_team_passes_pct_long',
 'vs_team_sca_per90',
 'vs_team_gca_per90',
 #'vs_team_dribble_tackles_pct',
 #'vs_team_dribbles_completed_pct',
 'vs_team_aerials_won_pct',
 'opp_team_possession',
 'opp_team_goals_assists_per90',
 'opp_team_goals_pens_per90',
 'opp_team_goals_assists_pens_per90',
 'opp_team_xg_per90',
 'opp_team_gk_goals_against_per90',
 'opp_team_gk_save_pct',
 'opp_team_gk_clean_sheets_pct',
 'opp_team_passes_pct',
 'opp_team_passes_pct_medium',
 'opp_team_passes_pct_long',
 'opp_team_sca_per90',
 'opp_team_gca_per90',
 #'opp_team_dribble_tackles_pct',
 'opp_team_aerials_won_pct',
 'opp_vs_team_possession',
 'opp_vs_team_goals_per90',
 'opp_vs_team_assists_per90',
 'opp_vs_team_xg_per90',
 'opp_vs_team_gk_save_pct',
 'opp_vs_team_gk_clean_sheets_pct',
 'opp_vs_team_gk_pct_passes_launched',
 'opp_vs_team_gk_crosses_stopped_pct',
 'opp_vs_team_shots_on_target_per90',
 'opp_vs_team_passes_pct',
 'opp_vs_team_passes_pct_short',
 'opp_vs_team_passes_pct_medium',
 'opp_vs_team_passes_pct_long',
 'opp_vs_team_sca_per90',
 'opp_vs_team_gca_per90',
 #'opp_vs_team_dribble_tackles_pct',
 #'opp_vs_team_dribbles_completed_pct',
 'opp_vs_team_aerials_won_pct',
                
 'vote_avg',
 'vote_std']

features_rel = [
 'goals',
 'assists',
 'cards_yellow',
 'cards_red',
 'xg',
 'npxg',
 'shots_on_target',
 'passes_completed',
 'passes_into_final_third',
 'passes_into_penalty_area',
 'progressive_passes',
 'passes_live',
 'passes_dead',
 'through_balls',
 'passes_switches',
 'crosses',
 'corner_kicks',
 #'dribble_tackles',
 #'dribbles_vs',
 #'dribbled_past',
 'blocks',
 'blocked_shots',
 'blocked_passes',
 'interceptions',
 'clearances',
 'errors',
 'touches',
 'touches_def_pen_area',
 'touches_def_3rd',
 'touches_mid_3rd',
 'touches_att_3rd',
 'touches_att_pen_area',
 'touches_live_ball',
 #'dribbles_completed',
 #'dribbles',
 'passes_received',
 'miscontrols',
 'dispossessed',
 'fouls',
 'fouled',
 'aerials_won',
 'aerials_lost',
 'carries',
 'progressive_carries',
 'carries_into_final_third',
 'carries_into_penalty_area']

features_rel_gamecorr = [
    'goals',
    'assists',
    'xg',
    'npxg',
    'cards_yellow',
    'cards_red'
]

# %% [markdown]
# Function for merging match data (player, team, opponent team) and select only the desired features, applying the desired corrections.

# %%
def player_match_data_ext(player, pteam, oppteam):
    pdata = player_match_data(player, pteam, oppteam)
    
    if(not isinstance(pdata, pd.DataFrame)):
        return None
    
    out = pd.concat([pdata[features_abs], pdata[features_rel]], axis = 1)
    
    out[features_rel] = out[features_rel] / max(pdata['minutes'][0], 1)
    
    out[features_rel_gamecorr] = out[features_rel_gamecorr] * (pdata['minutes'][0] / max(pdata['games'][0], 1) / 90)
    
    return out

# %% [markdown]
# Columns variable for the match data, to be then added to votes data.

# %%
test = player_match_data_ext('Barella', 'Inter', 'Atalanta')

add_columns = test.columns

test
# Out:
#          r  games  games_starts  minutes  shots_on_target_pct  goals_per_shot  \
# Barella  C      3             3      218                 25.0             0.0
#
#          goals_per_shot_on_target  passes_pct  aerials_won_pct  \
# Barella                       0.0        86.1            100.0
#
#          team_possession  ...  miscontrols  dispossessed     fouls    fouled  \
# Barella             51.3  ...          0.0           0.0  0.004587  0.013761
#
#          aerials_won  aerials_lost   carries  progressive_carries  \
# Barella     0.004587           0.0  0.555046              0.03211
#
#          carries_into_final_third  carries_into_penalty_area
# Barella                  0.027523                        0.0
#
# [1 rows x 112 columns]

# %% [markdown]
# Load Fantacalcio votes data for each match of the season.

# %%
votes = pd.read_excel('mid_outputs/players_votes.xlsx', index_col = 0)
votes
# Out:
#      matchday      player      team   oppteam  home  vote  goals  assists  \
# 0           1       Musso  Atalanta  Sassuolo     0   6.5      0        0
# 1           1  Zappacosta  Atalanta  Sassuolo     0   6.5      0        0
# 2           1    Djimsiti  Atalanta  Sassuolo     0   6.0      0        0
# 3           1   Kolasinac  Atalanta  Sassuolo     0   6.5      0        0
# 4           1      Zortea  Atalanta  Sassuolo     0   7.0      1        0
# ..        ...         ...       ...       ...   ...   ...    ...      ...
# 859         3  Folorunsho    Verona  Sassuolo     0   5.0      0        0
# 860         3      Serdar    Verona  Sassuolo     0   5.5      0        0
# 861         3   Bonazzoli    Verona  Sassuolo     0   5.5      0        0
# 862         3      Djuric    Verona  Sassuolo     0   6.0      0        0
# 863         3      Ngonge    Verona  Sassuolo     0   6.5      1        0
#
#      cards_malus  fantavote
# 0            0.0        6.5
# 1            0.0        6.5
# 2            0.0        6.0
# 3            0.0        6.5
# 4            0.0       10.0
# ..           ...        ...
# 859          0.0        5.0
# 860          0.0        5.5
# 861          0.0        5.5
# 862          0.0        6.0
# 863          0.0        9.5
#
# [864 rows x 10 columns]

# %% [markdown]
# Merge votes data with match data for the player.

# %%
db = votes.copy()

delta = pd.DataFrame(columns = add_columns)

for i in range(db.shape[0]):
    ext_data = player_match_data_ext(db['player'][i], db['team'][i], db['oppteam'][i])
    
    if(not isinstance(ext_data, pd.DataFrame)):
        continue
    
    ext_data = ext_data.rename(index = {db['player'][i] : i})
    
    delta = pd.concat([delta, ext_data], axis = 0)
    
    if(i % 100 == 0):
        print(i)
    
db = pd.concat([db, delta], axis = 1)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800

# %%
db
# Out:
#      matchday      player      team   oppteam  home  vote  goals  assists  \
# 0           1       Musso  Atalanta  Sassuolo     0   6.5      0        0
# 1           1  Zappacosta  Atalanta  Sassuolo     0   6.5      0        0
# 2           1    Djimsiti  Atalanta  Sassuolo     0   6.0      0        0
# 3           1   Kolasinac  Atalanta  Sassuolo     0   6.5      0        0
# 4           1      Zortea  Atalanta  Sassuolo     0   7.0      1        0
# ..        ...         ...       ...       ...   ...   ...    ...      ...
# 859         3  Folorunsho    Verona  Sassuolo     0   5.0      0        0
# 860         3      Serdar    Verona  Sassuolo     0   5.5      0        0
# 861         3   Bonazzoli    Verona  Sassuolo     0   5.5      0        0
# 862         3      Djuric    Verona  Sassuolo     0   6.0      0        0
# 863         3      Ngonge    Verona  Sassuolo     0   6.5      1        0
#
#      cards_malus  fantavote  ... miscontrols dispossessed     fouls    fouled  \
# 0            0.0        6.5  ...    0.000000     0.000000  0.000000  0.000000
# 1            0.0        6.5  ...    0.026316     0.015789  0.010526  0.021053
# 2            0.0        6.0  ...    0.007874     0.000000  0.007874  0.000000
# 3            0.0        6.5  ...    0.003717     0.003717  0.000000  0.011152
# 4            0.0       10.0  ...    0.000000     0.015625  0.015625  0.000000
# ..           ...        ...  ...         ...          ...       ...       ...
# 859          0.0        5.0  ...    0.024490     0.008163  0.016327  0.040816
# 860          0.0        5.5  ...    0.036145     0.012048  0.012048  0.000000
# 861          0.0        5.5  ...    0.045977     0.011494  0.000000  0.034483
# 862          0.0        6.0  ...    0.024390     0.008130  0.048780  0.008130
# 863          0.0        9.5  ...    0.022727     0.009091  0.040909  0.013636
#
#      aerials_won  aerials_lost   carries  progressive_carries  \
# 0       0.000000      0.000000  0.000000             0.000000
# 1       0.005263      0.021053  0.394737             0.047368
# 2       0.019685      0.027559  0.350394             0.000000
# 3       0.011152      0.018587  0.457249             0.022305
# 4       0.000000      0.015625  0.515625             0.062500
# ..           ...           ...       ...                  ...
# 859     0.016327      0.053061  0.204082             0.016327
# 860     0.012048      0.036145  0.204819             0.000000
# 861     0.000000      0.034483  0.344828             0.022989
# 862     0.130081      0.081301  0.178862             0.000000
# 863     0.013636      0.018182  0.227273             0.040909
#
#      carries_into_final_third  carries_into_penalty_area
# 0                    0.000000                   0.000000
# 1                    0.026316                   0.015789
# 2                    0.000000                   0.000000
# 3                    0.033457                   0.003717
# 4                    0.046875                   0.015625
# ..                        ...                        ...
# 859                  0.024490                   0.000000
# 860                  0.000000                   0.000000
# 861                  0.022989                   0.011494
# 862                  0.000000                   0.000000
# 863                  0.013636                   0.018182
#
# [864 rows x 122 columns]

# %% [markdown]
# Remove undesired database entries.

# %%
db = db.drop(db[db.r == 'P'].index) # remove goalkeepers
db = db.drop(db[db.r != db.r].index) # remove non existing players (by searching NaN values)
db = db.drop(db[db.xg != db.xg].index)

# %%
db
# Out:
#      matchday      player      team   oppteam  home  vote  goals  assists  \
# 1           1  Zappacosta  Atalanta  Sassuolo     0   6.5      0        0
# 2           1    Djimsiti  Atalanta  Sassuolo     0   6.0      0        0
# 3           1   Kolasinac  Atalanta  Sassuolo     0   6.5      0        0
# 4           1      Zortea  Atalanta  Sassuolo     0   7.0      1        0
# 5           1     Ruggeri  Atalanta  Sassuolo     0   6.5      0        1
# ..        ...         ...       ...       ...   ...   ...    ...      ...
# 859         3  Folorunsho    Verona  Sassuolo     0   5.0      0        0
# 860         3      Serdar    Verona  Sassuolo     0   5.5      0        0
# 861         3   Bonazzoli    Verona  Sassuolo     0   5.5      0        0
# 862         3      Djuric    Verona  Sassuolo     0   6.0      0        0
# 863         3      Ngonge    Verona  Sassuolo     0   6.5      1        0
#
#      cards_malus  fantavote  ... miscontrols dispossessed     fouls    fouled  \
# 1            0.0        6.5  ...    0.026316     0.015789  0.010526  0.021053
# 2            0.0        6.0  ...    0.007874     0.000000  0.007874  0.000000
# 3            0.0        6.5  ...    0.003717     0.003717  0.000000  0.011152
# 4            0.0       10.0  ...    0.000000     0.015625  0.015625  0.000000
# 5            0.0        7.5  ...    0.012295     0.004098  0.016393  0.000000
# ..           ...        ...  ...         ...          ...       ...       ...
# 859          0.0        5.0  ...    0.024490     0.008163  0.016327  0.040816
# 860          0.0        5.5  ...    0.036145     0.012048  0.012048  0.000000
# 861          0.0        5.5  ...    0.045977     0.011494  0.000000  0.034483
# 862          0.0        6.0  ...    0.024390     0.008130  0.048780  0.008130
# 863          0.0        9.5  ...    0.022727     0.009091  0.040909  0.013636
#
#      aerials_won  aerials_lost   carries  progressive_carries  \
# 1       0.005263      0.021053  0.394737             0.047368
# 2       0.019685      0.027559  0.350394             0.000000
# 3       0.011152      0.018587  0.457249             0.022305
# 4       0.000000      0.015625  0.515625             0.062500
# 5       0.004098      0.024590  0.434426             0.016393
# ..           ...           ...       ...                  ...
# 859     0.016327      0.053061  0.204082             0.016327
# 860     0.012048      0.036145  0.204819             0.000000
# 861     0.000000      0.034483  0.344828             0.022989
# 862     0.130081      0.081301  0.178862             0.000000
# 863     0.013636      0.018182  0.227273             0.040909
#
#      carries_into_final_third  carries_into_penalty_area
# 1                    0.026316                   0.015789
# 2                    0.000000                   0.000000
# 3                    0.033457                   0.003717
# 4                    0.046875                   0.015625
# 5                    0.016393                   0.004098
# ..                        ...                        ...
# 859                  0.024490                   0.000000
# 860                  0.000000                   0.000000
# 861                  0.022989                   0.011494
# 862                  0.000000                   0.000000
# 863                  0.013636                   0.018182
#
# [795 rows x 122 columns]

# %% [markdown]
# Save outfield players database to file.

# %%
db.to_excel('mid_outputs/database_entries.xlsx')

# %% [markdown]
# Do the same process for goalkeepers, generating a different database.

# %%
for i in range(db.columns.shape[0]):
    print(str(i) + " - " + str(db.columns[i]))
# Out:
# 0 - matchday
# 1 - player
# 2 - team
# 3 - oppteam
# 4 - home
# 5 - vote
# 6 - goals
# 7 - assists
# 8 - cards_malus
# 9 - fantavote
# 10 - r
# 11 - games
# 12 - games_starts
# 13 - minutes
# 14 - shots_on_target_pct
# 15 - goals_per_shot
# 16 - goals_per_shot_on_target
# 17 - passes_pct
# 18 - aerials_won_pct
# 19 - team_possession
# 20 - team_goals_assists_per90
# 21 - team_goals_pens_per90
# 22 - team_goals_assists_pens_per90
# 23 - team_xg_per90
# 24 - team_gk_goals_against_per90
# 25 - team_gk_save_pct
# 26 - team_gk_clean_sheets_pct
# 27 - team_passes_pct
# 28 - team_passes_pct_medium
# 29 - team_passes_pct_long
# 30 - team_sca_per90
# 31 - team_gca_per90
# 32 - team_aerials_won_pct
# 33 - vs_team_possession
# 34 - vs_team_goals_per90
# 35 - vs_team_assists_per90
# 36 - vs_team_xg_per90
# 37 - vs_team_gk_save_pct
# 38 - vs_team_gk_clean_sheets_pct
# 39 - vs_team_gk_pct_passes_launched
# 40 - vs_team_gk_crosses_stopped_pct
# 41 - vs_team_shots_on_target_per90
# 42 - vs_team_passes_pct
# 43 - vs_team_passes_pct_short
# 44 - vs_team_passes_pct_medium
# 45 - vs_team_passes_pct_long
# 46 - vs_team_sca_per90
# 47 - vs_team_gca_per90
# 48 - vs_team_aerials_won_pct
# 49 - opp_team_possession
# 50 - opp_team_goals_assists_per90
# 51 - opp_team_goals_pens_per90
# 52 - opp_team_goals_assists_pens_per90
# 53 - opp_team_xg_per90
# 54 - opp_team_gk_goals_against_per90
# 55 - opp_team_gk_save_pct
# 56 - opp_team_gk_clean_sheets_pct
# 57 - opp_team_passes_pct
# 58 - opp_team_passes_pct_medium
# 59 - opp_team_passes_pct_long
# 60 - opp_team_sca_per90
# 61 - opp_team_gca_per90
# 62 - opp_team_aerials_won_pct
# 63 - opp_vs_team_possession
# 64 - opp_vs_team_goals_per90
# 65 - opp_vs_team_assists_per90
# 66 - opp_vs_team_xg_per90
# 67 - opp_vs_team_gk_save_pct
# 68 - opp_vs_team_gk_clean_sheets_pct
# 69 - opp_vs_team_gk_pct_passes_launched
# 70 - opp_vs_team_gk_crosses_stopped_pct
# 71 - opp_vs_team_shots_on_target_per90
# 72 - opp_vs_team_passes_pct
# 73 - opp_vs_team_passes_pct_short
# 74 - opp_vs_team_passes_pct_medium
# 75 - opp_vs_team_passes_pct_long
# 76 - opp_vs_team_sca_per90
# 77 - opp_vs_team_gca_per90
# 78 - opp_vs_team_aerials_won_pct
# 79 - vote_avg
# 80 - vote_std
# 81 - goals
# 82 - assists
# 83 - cards_yellow
# 84 - cards_red
# 85 - xg
# 86 - npxg
# 87 - shots_on_target
# 88 - passes_completed
# 89 - passes_into_final_third
# 90 - passes_into_penalty_area
# 91 - progressive_passes
# 92 - passes_live
# 93 - passes_dead
# 94 - through_balls
# 95 - passes_switches
# 96 - crosses
# 97 - corner_kicks
# 98 - blocks
# 99 - blocked_shots
# 100 - blocked_passes
# 101 - interceptions
# 102 - clearances
# 103 - errors
# 104 - touches
# 105 - touches_def_pen_area
# 106 - touches_def_3rd
# 107 - touches_mid_3rd
# 108 - touches_att_3rd
# 109 - touches_att_pen_area
# 110 - touches_live_ball
# 111 - passes_received
# 112 - miscontrols
# 113 - dispossessed
# 114 - fouls
# 115 - fouled
# 116 - aerials_won
# 117 - aerials_lost
# 118 - carries
# 119 - progressive_carries
# 120 - carries_into_final_third
# 121 - carries_into_penalty_area

# %%
rx = pd.read_excel('tmp/playermatchdata_sel_gk.xlsx', index_col = 0, header = None)   

out = list()

for i in range(1, rx.shape[1]):
        if(rx[i][2] == "x"):
            out.append(rx[i][0])
            
out
# Out:
# ['r',
#  'fb_ID',
#  'gk_games',
#  'gk_games_starts',
#  'gk_minutes',
#  'gk_goals_against_per90',
#  'gk_shots_on_target_against',
#  'gk_saves',
#  'gk_save_pct',
#  'gk_clean_sheets_pct',
#  'gk_free_kick_goals_against',
#  'gk_corner_kick_goals_against',
#  'gk_own_goals_against',
#  'gk_psxg',
#  'gk_psnpxg_per_shot_on_target_against',
#  'gk_psxg_net',
#  'gk_psxg_net_per90',
#  'gk_passes_completed_launched',
#  'gk_passes_launched',
#  'gk_passes_pct_launched',
#  'gk_passes',
#  'gk_passes_throws',
#  'gk_pct_passes_launched',
#  'gk_passes_length_avg',
#  'gk_goal_kicks',
#  'gk_pct_goal_kicks_launched',
#  'gk_goal_kick_length_avg',
#  'gk_crosses',
#  'gk_crosses_stopped',
#  'gk_crosses_stopped_pct',
#  'gk_def_actions_outside_pen_area',
#  'gk_def_actions_outside_pen_area_per90',
#  'gk_avg_distance_def_actions',
#  'team_possession',
#  'team_goals_assists_per90',
#  'team_goals_pens_per90',
#  'team_goals_assists_pens_per90',
#  'team_xg_per90',
#  'team_gk_goals_against_per90',
#  'team_gk_save_pct',
#  'team_gk_clean_sheets_pct',
#  'team_passes_pct',
#  'team_passes_pct_medium',
#  'team_passes_pct_long',
#  'team_sca_per90',
#  'team_gca_per90',
#  'team_dribble_tackles_pct',
#  'team_aerials_won_pct',
#  'vs_team_possession',
#  'vs_team_goals_per90',
#  'vs_team_assists_per90',
#  'vs_team_xg_per90',
#  'vs_team_gk_save_pct',
#  'vs_team_gk_clean_sheets_pct',
#  'vs_team_gk_pct_passes_launched',
#  'vs_team_gk_crosses_stopped_pct',
#  'vs_team_shots_on_target_per90',
#  'vs_team_passes_pct',
#  'vs_team_passes_pct_short',
#  'vs_team_passes_pct_medium',
#  'vs_team_passes_pct_long',
#  'vs_team_sca_per90',
#  'vs_team_gca_per90',
#  'vs_team_dribble_tackles_pct',
#  'vs_team_dribbles_completed_pct',
#  'vs_team_aerials_won_pct']

# %%
features_abs_gk = [
 'gk_games',
 'gk_games_starts',
 'gk_minutes',
 'gk_goals_against_per90', 
 'gk_save_pct',
 'gk_clean_sheets_pct',
 'gk_psxg_net_per90',
 'gk_passes_pct_launched',
 'gk_pct_passes_launched',
 'gk_passes_length_avg',
 'gk_pct_goal_kicks_launched',
 'gk_goal_kick_length_avg',
 'gk_crosses_stopped_pct',
 'gk_def_actions_outside_pen_area_per90',
 'gk_avg_distance_def_actions',
    
 'team_possession',
 'team_goals_assists_per90',
 'team_goals_pens_per90',
 'team_goals_assists_pens_per90',
 'team_xg_per90',
 'team_gk_goals_against_per90',
 'team_gk_save_pct',
 'team_gk_clean_sheets_pct',
 'team_passes_pct',
 'team_passes_pct_medium',
 'team_passes_pct_long',
 'team_sca_per90',
 'team_gca_per90',
 #'team_dribble_tackles_pct',
 'team_aerials_won_pct',
 'vs_team_possession',
 'vs_team_goals_per90',
 'vs_team_assists_per90',
 'vs_team_xg_per90',
 'vs_team_gk_save_pct',
 'vs_team_gk_clean_sheets_pct',
 'vs_team_gk_pct_passes_launched',
 'vs_team_gk_crosses_stopped_pct',
 'vs_team_shots_on_target_per90',
 'vs_team_passes_pct',
 'vs_team_passes_pct_short',
 'vs_team_passes_pct_medium',
 'vs_team_passes_pct_long',
 'vs_team_sca_per90',
 'vs_team_gca_per90',
 #'vs_team_dribble_tackles_pct',
 #'vs_team_dribbles_completed_pct',
 'vs_team_aerials_won_pct',
 'opp_team_possession',
 'opp_team_goals_assists_per90',
 'opp_team_goals_pens_per90',
 'opp_team_goals_assists_pens_per90',
 'opp_team_xg_per90',
 'opp_team_gk_goals_against_per90',
 'opp_team_gk_save_pct',
 'opp_team_gk_clean_sheets_pct',
 'opp_team_passes_pct',
 'opp_team_passes_pct_medium',
 'opp_team_passes_pct_long',
 'opp_team_sca_per90',
 'opp_team_gca_per90',
 #'opp_team_dribble_tackles_pct',
 'opp_team_aerials_won_pct',
 'opp_vs_team_possession',
 'opp_vs_team_goals_per90',
 'opp_vs_team_assists_per90',
 'opp_vs_team_xg_per90',
 'opp_vs_team_gk_save_pct',
 'opp_vs_team_gk_clean_sheets_pct',
 'opp_vs_team_gk_pct_passes_launched',
 'opp_vs_team_gk_crosses_stopped_pct',
 'opp_vs_team_shots_on_target_per90',
 'opp_vs_team_passes_pct',
 'opp_vs_team_passes_pct_short',
 'opp_vs_team_passes_pct_medium',
 'opp_vs_team_passes_pct_long',
 'opp_vs_team_sca_per90',
 'opp_vs_team_gca_per90',
 #'opp_vs_team_dribble_tackles_pct',
 #'opp_vs_team_dribbles_completed_pct',
 'opp_vs_team_aerials_won_pct',
                
 'vote_avg',
 'vote_std']

features_rel_gk = [
 'gk_shots_on_target_against',
 'gk_saves',
 'gk_free_kick_goals_against',
 'gk_corner_kick_goals_against',
 'gk_own_goals_against',
 'gk_psxg',
 'gk_psnpxg_per_shot_on_target_against',
 'gk_psxg_net',
 'gk_passes_completed_launched',
 'gk_passes_launched',
 'gk_passes',
 'gk_passes_throws',
 'gk_goal_kicks',
 'gk_crosses',
 'gk_crosses_stopped',
]

# %%
def player_match_data_ext_gk(player, pteam, oppteam):
    pdata = player_match_data(player, pteam, oppteam)
    
    if(not isinstance(pdata, pd.DataFrame)):
        return None
    
    if(pdata['gk_games'][0] <= 0):
        return None
    
    out = pd.concat([pdata[features_abs_gk], pdata[features_rel_gk]], axis = 1)
    
    out[features_rel_gk] = out[features_rel_gk] / max(pdata['minutes'][0], 1)

    return out

# %%
test = player_match_data_ext_gk('Consigli', 'Sassuolo', 'Atalanta')

add_columns_gk = test.columns

test
# Out:
#           gk_games  gk_games_starts  gk_minutes  gk_goals_against_per90  \
# Consigli         3                3         270                    1.67
#
#           gk_save_pct  gk_clean_sheets_pct  gk_psxg_net_per90  \
# Consigli         66.7                  0.0              -0.58
#
#           gk_passes_pct_launched  gk_pct_passes_launched  \
# Consigli                    23.9                    38.9
#
#           gk_passes_length_avg  ...  gk_psxg  \
# Consigli                  37.1  ...      3.3
#
#           gk_psnpxg_per_shot_on_target_against  gk_psxg_net  \
# Consigli                                  0.19         -1.7
#
#           gk_passes_completed_launched  gk_passes_launched  gk_passes  \
# Consigli                          11.0                46.0       95.0
#
#           gk_passes_throws  gk_goal_kicks  gk_crosses  gk_crosses_stopped
# Consigli              10.0           34.0        46.0                 2.0
#
# [1 rows x 92 columns]

# %%
db_gk = votes.copy()

delta = pd.DataFrame(columns = add_columns_gk)

for i in range(db_gk.shape[0]):
    ext_data = player_match_data_ext_gk(db_gk['player'][i], db_gk['team'][i], db_gk['oppteam'][i])
    
    if(i % 100 == 0):
        print(i)
        
    if(not isinstance(ext_data, pd.DataFrame)):
        continue
    
    ext_data = ext_data.rename(index = {db_gk['player'][i] : i})
    
    delta = pd.concat([delta, ext_data], axis = 0)
    
    
    
db_gk = pd.concat([db_gk, delta], axis = 1)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800

# %%
db_gk
# Out:
#      matchday      player      team   oppteam  home  vote  goals  assists  \
# 0           1       Musso  Atalanta  Sassuolo     0   6.5      0        0
# 1           1  Zappacosta  Atalanta  Sassuolo     0   6.5      0        0
# 2           1    Djimsiti  Atalanta  Sassuolo     0   6.0      0        0
# 3           1   Kolasinac  Atalanta  Sassuolo     0   6.5      0        0
# 4           1      Zortea  Atalanta  Sassuolo     0   7.0      1        0
# ..        ...         ...       ...       ...   ...   ...    ...      ...
# 859         3  Folorunsho    Verona  Sassuolo     0   5.0      0        0
# 860         3      Serdar    Verona  Sassuolo     0   5.5      0        0
# 861         3   Bonazzoli    Verona  Sassuolo     0   5.5      0        0
# 862         3      Djuric    Verona  Sassuolo     0   6.0      0        0
# 863         3      Ngonge    Verona  Sassuolo     0   6.5      1        0
#
#      cards_malus  fantavote  ... gk_psxg gk_psnpxg_per_shot_on_target_against  \
# 0            0.0        6.5  ...     2.1                                 0.21
# 1            0.0        6.5  ...     NaN                                  NaN
# 2            0.0        6.0  ...     NaN                                  NaN
# 3            0.0        6.5  ...     NaN                                  NaN
# 4            0.0       10.0  ...     NaN                                  NaN
# ..           ...        ...  ...     ...                                  ...
# 859          0.0        5.0  ...     NaN                                  NaN
# 860          0.0        5.5  ...     NaN                                  NaN
# 861          0.0        5.5  ...     NaN                                  NaN
# 862          0.0        6.0  ...     NaN                                  NaN
# 863          0.0        9.5  ...     NaN                                  NaN
#
#     gk_psxg_net  gk_passes_completed_launched  gk_passes_launched  gk_passes  \
# 0           0.1                          11.0                34.0       88.0
# 1           NaN                           NaN                 NaN        NaN
# 2           NaN                           NaN                 NaN        NaN
# 3           NaN                           NaN                 NaN        NaN
# 4           NaN                           NaN                 NaN        NaN
# ..          ...                           ...                 ...        ...
# 859         NaN                           NaN                 NaN        NaN
# 860         NaN                           NaN                 NaN        NaN
# 861         NaN                           NaN                 NaN        NaN
# 862         NaN                           NaN                 NaN        NaN
# 863         NaN                           NaN                 NaN        NaN
#
#      gk_passes_throws  gk_goal_kicks  gk_crosses  gk_crosses_stopped
# 0                18.0           18.0        28.0                 2.0
# 1                 NaN            NaN         NaN                 NaN
# 2                 NaN            NaN         NaN                 NaN
# 3                 NaN            NaN         NaN                 NaN
# 4                 NaN            NaN         NaN                 NaN
# ..                ...            ...         ...                 ...
# 859               NaN            NaN         NaN                 NaN
# 860               NaN            NaN         NaN                 NaN
# 861               NaN            NaN         NaN                 NaN
# 862               NaN            NaN         NaN                 NaN
# 863               NaN            NaN         NaN                 NaN
#
# [864 rows x 102 columns]

# %%
db_gk = db_gk.drop(db_gk[db_gk.gk_games != db_gk.gk_games].index) # remove non extisting players

# %%
db_gk
# Out:
#      matchday               player         team      oppteam  home  vote  \
# 0           1                Musso     Atalanta     Sassuolo     0   6.5
# 16          1            Skorupski      Bologna        Milan     1   6.0
# 29          1            Radunovic     Cagliari       Torino     0   6.5
# 44          1              Caprile       Empoli       Verona     1   5.0
# 57          1          Terracciano   Fiorentina        Genoa     0   6.0
# 69          1               Turati    Frosinone       Napoli     1   5.5
# 84          1         Martinez Jo.        Genoa   Fiorentina     1   6.0
# 98          1               Sommer        Inter        Monza     1   6.0
# 112         1             Szczesny     Juventus      Udinese     0   7.0
# 127         1             Provedel        Lazio        Lecce     0   6.0
# 142         1              Falcone        Lecce        Lazio     1   7.0
# 158         1              Maignan        Milan      Bologna     0   6.0
# 173         1          Di Gregorio        Monza        Inter     0   6.0
# 188         1                Meret       Napoli    Frosinone     0   6.0
# 202         1         Rui Patricio         Roma  Salernitana     1   6.0
# 217         1                Ochoa  Salernitana         Roma     0   6.5
# 229         1             Consigli     Sassuolo     Atalanta     1   6.0
# 242         1  Milinkovic-Savic V.       Torino     Cagliari     1   6.5
# 257         1            Silvestri      Udinese     Juventus     1   5.0
# 273         1             Montipo'       Verona       Empoli     0   6.5
# 287         2                Musso     Atalanta    Frosinone     0   6.0
# 302         2            Skorupski      Bologna     Juventus     0   6.5
# 316         2            Radunovic     Cagliari        Inter     1   6.0
# 330         2              Perisan       Empoli        Monza     0   5.0
# 346         2       Christensen O.   Fiorentina        Lecce     1   6.0
# 360         2           Cerofolini    Frosinone     Atalanta     1   6.5
# 373         2         Martinez Jo.        Genoa        Lazio     0   6.0
# 387         2               Sommer        Inter     Cagliari     0   6.0
# 402         2                Perin     Juventus      Bologna     1   6.0
# 416         2             Provedel        Lazio        Genoa     1   6.0
# 430         2              Falcone        Lecce   Fiorentina     0   6.0
# 444         2              Maignan        Milan       Torino     1   6.0
# 458         2          Di Gregorio        Monza       Empoli     1   7.5
# 471         2                Meret       Napoli     Sassuolo     1   6.0
# 483         2         Rui Patricio         Roma       Verona     0   5.0
# 499         2                Ochoa  Salernitana      Udinese     1   6.5
# 513         2             Consigli     Sassuolo       Napoli     0   6.0
# 529         2  Milinkovic-Savic V.       Torino        Milan     0   5.5
# 544         2            Silvestri      Udinese  Salernitana     0   5.5
# 557         2             Montipo'       Verona         Roma     1   6.0
# 571         3                Musso     Atalanta        Monza     1   6.5
# 584         3            Skorupski      Bologna     Cagliari     1   6.0
# 598         3            Radunovic     Cagliari      Bologna     0   4.5
# 614         3              Berisha       Empoli     Juventus     1   6.5
# 629         3       Christensen O.   Fiorentina        Inter     0   5.5
# 645         3               Turati    Frosinone      Udinese     0   6.0
# 657         3         Martinez Jo.        Genoa       Torino     0   6.0
# 672         3               Sommer        Inter   Fiorentina     1   6.0
# 687         3                Perin     Juventus       Empoli     0   6.0
# 701         3             Provedel        Lazio       Napoli     0   6.5
# 715         3              Falcone        Lecce  Salernitana     1   6.5
# 731         3              Maignan        Milan         Roma     0   6.0
# 746         3          Di Gregorio        Monza     Atalanta     0   6.0
# 762         3                Meret       Napoli        Lazio     1   5.5
# 776         3         Rui Patricio         Roma        Milan     1   6.0
# 791         3                Ochoa  Salernitana        Lecce     0   6.5
# 806         3             Consigli     Sassuolo       Verona     1   5.5
# 821         3  Milinkovic-Savic V.       Torino        Genoa     1   6.0
# 836         3            Silvestri      Udinese    Frosinone     1   6.0
# 850         3             Montipo'       Verona     Sassuolo     0   6.5
#
#      goals  assists  cards_malus  fantavote  ... gk_psxg  \
# 0        0        0          0.0        6.5  ...     2.1
# 16      -2        0          0.0        4.0  ...     3.0
# 29       0        0          0.0        6.5  ...     4.0
# 44      -1        0          0.0        4.0  ...     0.4
# 57      -1        0          0.0        5.0  ...     0.3
# 69      -3        0          0.0        2.5  ...     3.6
# 84      -4        0          0.0        2.0  ...     2.6
# 98       0        0          0.0        6.0  ...     1.2
# 112      0        0          0.0        7.0  ...     1.4
# 127     -2        0          0.0        4.0  ...     2.5
# 142     -1        0          0.0        6.0  ...     3.0
# 158      0        0          0.0        6.0  ...     0.6
# 173     -2        0          0.0        4.0  ...     4.2
# 188     -1        0          0.0        5.0  ...     2.2
# 202     -2        0          0.0        4.0  ...     3.6
# 217     -2        0          0.0        4.5  ...     3.7
# 229     -2        0          0.0        4.0  ...     3.3
# 242      0        0          0.0        6.5  ...     3.9
# 257     -3        0          0.0        2.0  ...     3.8
# 273      0        0          0.0        6.5  ...     4.3
# 287     -2        0          0.0        4.0  ...     2.1
# 302     -1        0          0.0        5.5  ...     3.0
# 316     -2        0          0.0        4.0  ...     4.0
# 330     -2        0          0.0        3.0  ...     0.7
# 346     -2        0          0.0        4.0  ...     3.2
# 360     -1        0          0.0        5.5  ...     1.0
# 373      0        0          0.0        6.0  ...     2.6
# 387      0        0          0.0        6.0  ...     1.2
# 402     -1        0          0.0        5.0  ...     1.2
# 416     -1        0          0.0        5.0  ...     2.5
# 430     -2        0          0.0        4.0  ...     3.0
# 444     -1        0          0.0        5.0  ...     0.6
# 458      0        0          0.0        7.5  ...     4.2
# 471      0        0          0.0        6.0  ...     2.2
# 483     -2        0          0.0        3.0  ...     3.6
# 499     -1        0          0.0        5.5  ...     3.7
# 513     -2        0          0.0        4.0  ...     3.3
# 529     -4        0          0.5        1.0  ...     3.9
# 544     -1        0          0.0        4.5  ...     3.8
# 557     -1        0          0.0        5.0  ...     4.3
# 571      0        0          0.0        6.5  ...     2.1
# 584     -1        0          0.0        5.0  ...     3.0
# 598     -2        0          0.0        2.5  ...     4.0
# 614     -2        0          0.0        4.5  ...     1.8
# 629     -4        0          0.0        1.5  ...     3.2
# 645      0        0          0.0        6.0  ...     3.6
# 657     -1        0          0.0        5.0  ...     2.6
# 672      0        0          0.0        6.0  ...     1.2
# 687      0        0          0.0        6.0  ...     1.2
# 701     -1        0          0.0        5.5  ...     2.5
# 715      0        0          0.0        6.5  ...     3.0
# 731     -1        0          0.0        5.0  ...     0.6
# 746     -3        0          0.0        3.0  ...     4.2
# 762     -2        0          0.0        3.5  ...     2.2
# 776     -2        0          0.0        4.0  ...     3.6
# 791     -2        0          0.0        4.5  ...     3.7
# 806     -1        0          0.0        4.5  ...     3.3
# 821      0        0          0.0        6.0  ...     3.9
# 836      0        0          0.0        6.0  ...     3.8
# 850     -3        0          0.0        3.5  ...     4.3
#
#     gk_psnpxg_per_shot_on_target_against gk_psxg_net  \
# 0                                   0.21         0.1
# 16                                  0.33        -1.0
# 29                                  0.34         0.0
# 44                                  0.11        -0.6
# 57                                  0.13        -0.7
# 69                                  0.26         0.6
# 84                                  0.27        -2.4
# 98                                  0.21         1.2
# 112                                 0.30         1.4
# 127                                 0.18        -1.5
# 142                                 0.25         0.0
# 158                                 0.08        -1.4
# 173                                 0.25        -0.8
# 188                                 0.31        -0.8
# 202                                 0.30        -2.4
# 217                                 0.19        -1.3
# 229                                 0.19        -1.7
# 242                                 0.17        -0.1
# 257                                 0.31        -0.2
# 273                                 0.20         0.3
# 287                                 0.21         0.1
# 302                                 0.33        -1.0
# 316                                 0.34         0.0
# 330                                 0.14        -1.3
# 346                                 0.18        -2.8
# 360                                 0.16         0.0
# 373                                 0.27        -2.4
# 387                                 0.21         1.2
# 402                                 0.30         0.2
# 416                                 0.18        -1.5
# 430                                 0.25         0.0
# 444                                 0.08        -1.4
# 458                                 0.25        -0.8
# 471                                 0.31        -0.8
# 483                                 0.30        -2.4
# 499                                 0.19        -1.3
# 513                                 0.19        -1.7
# 529                                 0.17        -0.1
# 544                                 0.31        -0.2
# 557                                 0.20         0.3
# 571                                 0.21         0.1
# 584                                 0.33        -1.0
# 598                                 0.34         0.0
# 614                                 0.18        -0.2
# 629                                 0.18        -2.8
# 645                                 0.26         0.6
# 657                                 0.27        -2.4
# 672                                 0.21         1.2
# 687                                 0.30         0.2
# 701                                 0.18        -1.5
# 715                                 0.25         0.0
# 731                                 0.08        -1.4
# 746                                 0.25        -0.8
# 762                                 0.31        -0.8
# 776                                 0.30        -2.4
# 791                                 0.19        -1.3
# 806                                 0.19        -1.7
# 821                                 0.17        -0.1
# 836                                 0.31        -0.2
# 850                                 0.20         0.3
#
#      gk_passes_completed_launched  gk_passes_launched  gk_passes  \
# 0                            11.0                34.0       88.0
# 16                           11.0                31.0       63.0
# 29                           16.0                41.0       53.0
# 44                            4.0                20.0       37.0
# 57                            3.0                 5.0       47.0
# 69                            5.0                19.0       61.0
# 84                           27.0                55.0       94.0
# 98                           19.0                32.0       81.0
# 112                           5.0                14.0       34.0
# 127                           6.0                16.0       89.0
# 142                          17.0                43.0       57.0
# 158                          20.0                57.0      170.0
# 173                           7.0                32.0      111.0
# 188                           3.0                10.0       78.0
# 202                           6.0                13.0       47.0
# 217                          13.0                52.0       70.0
# 229                          11.0                46.0       95.0
# 242                          15.0                47.0       85.0
# 257                          11.0                31.0       70.0
# 273                          27.0                72.0       84.0
# 287                          11.0                34.0       88.0
# 302                          11.0                31.0       63.0
# 316                          16.0                41.0       53.0
# 330                           1.0                 8.0       22.0
# 346                          14.0                31.0       78.0
# 360                           2.0                18.0       27.0
# 373                          27.0                55.0       94.0
# 387                          19.0                32.0       81.0
# 402                           5.0                13.0       42.0
# 416                           6.0                16.0       89.0
# 430                          17.0                43.0       57.0
# 444                          20.0                57.0      170.0
# 458                           7.0                32.0      111.0
# 471                           3.0                10.0       78.0
# 483                           6.0                13.0       47.0
# 499                          13.0                52.0       70.0
# 513                          11.0                46.0       95.0
# 529                          15.0                47.0       85.0
# 544                          11.0                31.0       70.0
# 557                          27.0                72.0       84.0
# 571                          11.0                34.0       88.0
# 584                          11.0                31.0       63.0
# 598                          16.0                41.0       53.0
# 614                           2.0                12.0       32.0
# 629                          14.0                31.0       78.0
# 645                           5.0                19.0       61.0
# 657                          27.0                55.0       94.0
# 672                          19.0                32.0       81.0
# 687                           5.0                13.0       42.0
# 701                           6.0                16.0       89.0
# 715                          17.0                43.0       57.0
# 731                          20.0                57.0      170.0
# 746                           7.0                32.0      111.0
# 762                           3.0                10.0       78.0
# 776                           6.0                13.0       47.0
# 791                          13.0                52.0       70.0
# 806                          11.0                46.0       95.0
# 821                          15.0                47.0       85.0
# 836                          11.0                31.0       70.0
# 850                          27.0                72.0       84.0
#
#      gk_passes_throws  gk_goal_kicks  gk_crosses  gk_crosses_stopped
# 0                18.0           18.0        28.0                 2.0
# 16               14.0           19.0        45.0                 2.0
# 29               14.0           28.0        49.0                 2.0
# 44                9.0            4.0        10.0                 2.0
# 57                3.0            4.0        11.0                 0.0
# 69               17.0           10.0        25.0                 2.0
# 84                9.0           14.0        64.0                 8.0
# 98               12.0           21.0        35.0                 1.0
# 112               6.0            3.0        16.0                 1.0
# 127              11.0           11.0        39.0                 2.0
# 142              14.0           24.0        32.0                 2.0
# 158              23.0           20.0        43.0                12.0
# 173              16.0           22.0        45.0                 2.0
# 188               7.0            8.0        15.0                 1.0
# 202               6.0           12.0        15.0                 0.0
# 217              12.0           31.0        51.0                 3.0
# 229              10.0           34.0        46.0                 2.0
# 242              19.0           29.0        23.0                 0.0
# 257              10.0           21.0        33.0                 0.0
# 273               7.0           28.0        44.0                 1.0
# 287              18.0           18.0        28.0                 2.0
# 302              14.0           19.0        45.0                 2.0
# 316              14.0           28.0        49.0                 2.0
# 330               8.0           12.0        18.0                 0.0
# 346               7.0            8.0        15.0                 0.0
# 360               2.0            5.0        18.0                 0.0
# 373               9.0           14.0        64.0                 8.0
# 387              12.0           21.0        35.0                 1.0
# 402               9.0           11.0        26.0                 2.0
# 416              11.0           11.0        39.0                 2.0
# 430              14.0           24.0        32.0                 2.0
# 444              23.0           20.0        43.0                12.0
# 458              16.0           22.0        45.0                 2.0
# 471               7.0            8.0        15.0                 1.0
# 483               6.0           12.0        15.0                 0.0
# 499              12.0           31.0        51.0                 3.0
# 513              10.0           34.0        46.0                 2.0
# 529              19.0           29.0        23.0                 0.0
# 544              10.0           21.0        33.0                 0.0
# 557               7.0           28.0        44.0                 1.0
# 571              18.0           18.0        28.0                 2.0
# 584              14.0           19.0        45.0                 2.0
# 598              14.0           28.0        49.0                 2.0
# 614               8.0            7.0        17.0                 0.0
# 629               7.0            8.0        15.0                 0.0
# 645              17.0           10.0        25.0                 2.0
# 657               9.0           14.0        64.0                 8.0
# 672              12.0           21.0        35.0                 1.0
# 687               9.0           11.0        26.0                 2.0
# 701              11.0           11.0        39.0                 2.0
# 715              14.0           24.0        32.0                 2.0
# 731              23.0           20.0        43.0                12.0
# 746              16.0           22.0        45.0                 2.0
# 762               7.0            8.0        15.0                 1.0
# 776               6.0           12.0        15.0                 0.0
# 791              12.0           31.0        51.0                 3.0
# 806              10.0           34.0        46.0                 2.0
# 821              19.0           29.0        23.0                 0.0
# 836              10.0           21.0        33.0                 0.0
# 850               7.0           28.0        44.0                 1.0
#
# [60 rows x 102 columns]

# %% [markdown]
# Save goalkeepers players database to file.

# %%
db_gk.to_excel('mid_outputs/database_entries_gk.xlsx')

# %%
for i in range(db_gk.columns.shape[0]):
    print(str(i) + " - " + str(db_gk.columns[i]))
# Out:
# 0 - matchday
# 1 - player
# 2 - team
# 3 - oppteam
# 4 - home
# 5 - vote
# 6 - goals
# 7 - assists
# 8 - cards_malus
# 9 - fantavote
# 10 - gk_games
# 11 - gk_games_starts
# 12 - gk_minutes
# 13 - gk_goals_against_per90
# 14 - gk_save_pct
# 15 - gk_clean_sheets_pct
# 16 - gk_psxg_net_per90
# 17 - gk_passes_pct_launched
# 18 - gk_pct_passes_launched
# 19 - gk_passes_length_avg
# 20 - gk_pct_goal_kicks_launched
# 21 - gk_goal_kick_length_avg
# 22 - gk_crosses_stopped_pct
# 23 - gk_def_actions_outside_pen_area_per90
# 24 - gk_avg_distance_def_actions
# 25 - team_possession
# 26 - team_goals_assists_per90
# 27 - team_goals_pens_per90
# 28 - team_goals_assists_pens_per90
# 29 - team_xg_per90
# 30 - team_gk_goals_against_per90
# 31 - team_gk_save_pct
# 32 - team_gk_clean_sheets_pct
# 33 - team_passes_pct
# 34 - team_passes_pct_medium
# 35 - team_passes_pct_long
# 36 - team_sca_per90
# 37 - team_gca_per90
# 38 - team_aerials_won_pct
# 39 - vs_team_possession
# 40 - vs_team_goals_per90
# 41 - vs_team_assists_per90
# 42 - vs_team_xg_per90
# 43 - vs_team_gk_save_pct
# 44 - vs_team_gk_clean_sheets_pct
# 45 - vs_team_gk_pct_passes_launched
# 46 - vs_team_gk_crosses_stopped_pct
# 47 - vs_team_shots_on_target_per90
# 48 - vs_team_passes_pct
# 49 - vs_team_passes_pct_short
# 50 - vs_team_passes_pct_medium
# 51 - vs_team_passes_pct_long
# 52 - vs_team_sca_per90
# 53 - vs_team_gca_per90
# 54 - vs_team_aerials_won_pct
# 55 - opp_team_possession
# 56 - opp_team_goals_assists_per90
# 57 - opp_team_goals_pens_per90
# 58 - opp_team_goals_assists_pens_per90
# 59 - opp_team_xg_per90
# 60 - opp_team_gk_goals_against_per90
# 61 - opp_team_gk_save_pct
# 62 - opp_team_gk_clean_sheets_pct
# 63 - opp_team_passes_pct
# 64 - opp_team_passes_pct_medium
# 65 - opp_team_passes_pct_long
# 66 - opp_team_sca_per90
# 67 - opp_team_gca_per90
# 68 - opp_team_aerials_won_pct
# 69 - opp_vs_team_possession
# 70 - opp_vs_team_goals_per90
# 71 - opp_vs_team_assists_per90
# 72 - opp_vs_team_xg_per90
# 73 - opp_vs_team_gk_save_pct
# 74 - opp_vs_team_gk_clean_sheets_pct
# 75 - opp_vs_team_gk_pct_passes_launched
# 76 - opp_vs_team_gk_crosses_stopped_pct
# 77 - opp_vs_team_shots_on_target_per90
# 78 - opp_vs_team_passes_pct
# 79 - opp_vs_team_passes_pct_short
# 80 - opp_vs_team_passes_pct_medium
# 81 - opp_vs_team_passes_pct_long
# 82 - opp_vs_team_sca_per90
# 83 - opp_vs_team_gca_per90
# 84 - opp_vs_team_aerials_won_pct
# 85 - vote_avg
# 86 - vote_std
# 87 - gk_shots_on_target_against
# 88 - gk_saves
# 89 - gk_free_kick_goals_against
# 90 - gk_corner_kick_goals_against
# 91 - gk_own_goals_against
# 92 - gk_psxg
# 93 - gk_psnpxg_per_shot_on_target_against
# 94 - gk_psxg_net
# 95 - gk_passes_completed_launched
# 96 - gk_passes_launched
# 97 - gk_passes
# 98 - gk_passes_throws
# 99 - gk_goal_kicks
# 100 - gk_crosses
# 101 - gk_crosses_stopped
