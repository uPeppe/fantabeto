# %% [markdown]
# Player/match dataset creation
#
# For each serie A (already happened) match and player, a database entry is generated, with this form:
#
# [y = player votes data, player data, team data, vs team data, opp team data, vs opp team data]

# %%
import pandas as pd

# %% [markdown]
# Load team data from FBref

# %%
rcsv = pd.read_csv('fbref_data/teams.csv')   
team = pd.DataFrame(rcsv)

rcsv = pd.read_csv('fbref_data/teams_vs.csv')   
vs_team = pd.DataFrame(rcsv)

for i in range(1, team.shape[1]):
    team = team.rename(columns = {team.columns[i] : 'team_' + team.columns[i]})
    
for i in range(1, vs_team.shape[1]):
    vs_team = vs_team.rename(columns = {vs_team.columns[i] : 'vs_team_' + vs_team.columns[i]})
    
vs_team.pop('team')

team_data = pd.concat([team, vs_team], axis = 1)

team_data['team_idx'] = team_data['team']
for i in range(team_data.shape[0]):
    team_data['team_idx'][i] = team_data['team_idx'][i].split(' ')[-1]

team_data = team_data.set_index('team_idx')

team_data
# Out:
# C:\Users\nicol\AppData\Local\Temp\ipykernel_5880\552672520.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   team_data['team_idx'][i] = team_data['team_idx'][i].split(' ')[-1]
#                       team  team_players_used  team_possession  team_games  \
# team_idx
# Atalanta          Atalanta               24.0             49.1        20.0
# Bologna            Bologna               24.0             52.6        20.0
# Cremonese        Cremonese               29.0             43.6        20.0
# Empoli              Empoli               26.0             46.4        20.0
# Fiorentina      Fiorentina               27.0             57.1        20.0
# Verona       Hellas Verona               32.0             43.5        20.0
# Inter                Inter               23.0             53.6        20.0
# Juventus          Juventus               26.0             49.4        20.0
# Lazio                Lazio               21.0             50.9        20.0
# Lecce                Lecce               26.0             42.5        20.0
# Milan                Milan               27.0             54.8        20.0
# Monza                Monza               29.0             55.1        20.0
# Napoli              Napoli               24.0             61.0        20.0
# Roma                  Roma               25.0             49.1        20.0
# Salernitana    Salernitana               28.0             44.8        20.0
# Sampdoria        Sampdoria               30.0             48.9        20.0
# Sassuolo          Sassuolo               27.0             48.3        20.0
# Spezia              Spezia               30.0             46.7        20.0
# Torino              Torino               24.0             52.9        20.0
# Udinese            Udinese               23.0             50.4        20.0
#
#              team_games_starts  team_minutes  team_goals  team_assists  \
# team_idx
# Atalanta                 220.0        1800.0        38.0          27.0
# Bologna                  220.0        1800.0        25.0          19.0
# Cremonese                220.0        1800.0        15.0           7.0
# Empoli                   220.0        1800.0        19.0          11.0
# Fiorentina               220.0        1800.0        22.0          17.0
# Verona                   220.0        1800.0        16.0          13.0
# Inter                    220.0        1800.0        39.0          26.0
# Juventus                 220.0        1800.0        30.0          23.0
# Lazio                    220.0        1800.0        35.0          25.0
# Lecce                    220.0        1800.0        18.0          12.0
# Milan                    220.0        1800.0        35.0          30.0
# Monza                    220.0        1800.0        24.0          15.0
# Napoli                   220.0        1800.0        48.0          39.0
# Roma                     220.0        1800.0        26.0          17.0
# Salernitana              220.0        1800.0        24.0          16.0
# Sampdoria                220.0        1800.0         8.0           7.0
# Sassuolo                 220.0        1800.0        23.0          17.0
# Spezia                   220.0        1800.0        15.0          10.0
# Torino                   220.0        1800.0        21.0          16.0
# Udinese                  220.0        1800.0        27.0          23.0
#
#              team_pens_made  team_pens_att  ...  vs_team_fouls  \
# team_idx                                    ...
# Atalanta                6.0            8.0  ...          220.0
# Bologna                 3.0            3.0  ...          252.0
# Cremonese               2.0            4.0  ...          217.0
# Empoli                  0.0            0.0  ...          260.0
# Fiorentina              2.0            4.0  ...          271.0
# Verona                  0.0            0.0  ...          201.0
# Inter                   2.0            2.0  ...          249.0
# Juventus                2.0            3.0  ...          220.0
# Lazio                   3.0            4.0  ...          278.0
# Lecce                   1.0            2.0  ...          263.0
# Milan                   2.0            2.0  ...          242.0
# Monza                   3.0            3.0  ...          291.0
# Napoli                  4.0            5.0  ...          272.0
# Roma                    3.0            5.0  ...          274.0
# Salernitana             1.0            1.0  ...          226.0
# Sampdoria               0.0            0.0  ...          316.0
# Sassuolo                4.0            5.0  ...          262.0
# Spezia                  2.0            2.0  ...          207.0
# Torino                  1.0            1.0  ...          221.0
# Udinese                 0.0            0.0  ...          261.0
#
#              vs_team_fouled  vs_team_offsides  vs_team_pens_won  \
# team_idx
# Atalanta              232.0              26.0               1.0
# Bologna               229.0              33.0               3.0
# Cremonese             254.0              32.0               3.0
# Empoli                226.0              32.0               2.0
# Fiorentina            243.0              53.0               1.0
# Verona                286.0              22.0               1.0
# Inter                 224.0              18.0               2.0
# Juventus              221.0              27.0               0.0
# Lazio                 196.0              44.0               1.0
# Lecce                 265.0              43.0               3.0
# Milan                 237.0              23.0               4.0
# Monza                 251.0              37.0               0.0
# Napoli                174.0              27.0               1.0
# Roma                  228.0              10.0               0.0
# Salernitana           233.0              49.0               7.0
# Sampdoria             277.0              56.0               3.0
# Sassuolo              190.0              67.0               2.0
# Spezia                261.0              46.0               1.0
# Torino                274.0              22.0               3.0
# Udinese               235.0              31.0               2.0
#
#              vs_team_pens_conceded  vs_team_own_goals  \
# team_idx
# Atalanta                       8.0                1.0
# Bologna                        3.0                1.0
# Cremonese                      4.0                0.0
# Empoli                         0.0                0.0
# Fiorentina                     4.0                0.0
# Verona                         0.0                2.0
# Inter                          2.0                1.0
# Juventus                       3.0                0.0
# Lazio                          4.0                1.0
# Lecce                          2.0                1.0
# Milan                          2.0                2.0
# Monza                          3.0                1.0
# Napoli                         4.0                0.0
# Roma                           5.0                0.0
# Salernitana                    1.0                1.0
# Sampdoria                      0.0                0.0
# Sassuolo                       5.0                0.0
# Spezia                         2.0                2.0
# Torino                         1.0                0.0
# Udinese                        0.0                1.0
#
#              vs_team_ball_recoveries  vs_team_aerials_won  \
# team_idx
# Atalanta                      1214.0                248.0
# Bologna                       1081.0                224.0
# Cremonese                     1106.0                367.0
# Empoli                        1062.0                231.0
# Fiorentina                    1005.0                261.0
# Verona                        1096.0                362.0
# Inter                          914.0                204.0
# Juventus                      1007.0                240.0
# Lazio                         1085.0                196.0
# Lecce                         1072.0                373.0
# Milan                         1005.0                234.0
# Monza                         1023.0                214.0
# Napoli                         995.0                210.0
# Roma                          1048.0                197.0
# Salernitana                   1084.0                258.0
# Sampdoria                     1075.0                324.0
# Sassuolo                      1043.0                229.0
# Spezia                        1182.0                322.0
# Torino                        1045.0                337.0
# Udinese                       1010.0                212.0
#
#              vs_team_aerials_lost  vs_team_aerials_won_pct
# team_idx
# Atalanta                    303.0                     45.0
# Bologna                     180.0                     55.4
# Cremonese                   273.0                     57.3
# Empoli                      203.0                     53.2
# Fiorentina                  302.0                     46.4
# Verona                      411.0                     46.8
# Inter                       251.0                     44.8
# Juventus                    247.0                     49.3
# Lazio                       193.0                     50.4
# Lecce                       295.0                     55.8
# Milan                       288.0                     44.8
# Monza                       225.0                     48.7
# Napoli                      244.0                     46.3
# Roma                        234.0                     45.7
# Salernitana                 240.0                     51.8
# Sampdoria                   327.0                     49.8
# Sassuolo                    183.0                     55.6
# Spezia                      281.0                     53.4
# Torino                      309.0                     52.2
# Udinese                     254.0                     45.5
#
# [20 rows x 321 columns]

# %%
team_data.to_excel('mid_outputs/team_data.xlsx')

# %% [markdown]
# Load data generated from players_dataset_creation

# %%
rx = pd.read_excel('mid_outputs/players_stats.xlsx', index_col = 3)   
players = pd.DataFrame(rx)

players
# Out:
#                      Unnamed: 0    id  r       team    surname initial  fb_ID  \
# name
# Meret                         0   572  P     Napoli      Meret     NaN    535
# Provedel                      1  2814  P      Lazio   Provedel     NaN    544
# Vicario                       2  4964  P     Empoli    Vicario     NaN    553
# Szczesny                      3   453  P   Juventus   Szczesny     NaN    550
# Falcone                       4  2134  P      Lecce    Falcone     NaN    530
# ...                         ...   ... ..        ...        ...     ...    ...
# De Luca                     538  5512  A  Sampdoria       Luca     NaN    130
# Voelkerling Persson         539  5837  A      Lecce    Persson     NaN    494
# Montevago                   540  6113  A  Sampdoria  Montevago     NaN    322
# Krollis                     541  6143  A     Spezia    Krollis     NaN     -1
# Vivaldo                     542  6160  A    Udinese    Vivaldo     NaN     -1
#
#                         age  birth_year  games  ...  \
# name                                            ...
# Meret                25-319        1997      0  ...
# Provedel             28-324        1994      0  ...
# Vicario              26-120        1996      0  ...
# Szczesny             32-292        1990      0  ...
# Falcone              27-298        1995      0  ...
# ...                     ...         ...    ...  ...
# De Luca              24-202        1998      1  ...
# Voelkerling Persson  20-020        2003      2  ...
# Montevago            19-323        2003      6  ...
# Krollis                   0           0      0  ...
# Vivaldo                   0           0      0  ...
#
#                      gk_pct_goal_kicks_launched  gk_goal_kick_length_avg  \
# name
# Meret                                      20.3                     27.5
# Provedel                                   33.6                     34.2
# Vicario                                    47.7                     42.5
# Szczesny                                   40.3                     38.9
# Falcone                                    75.0                     51.4
# ...                                         ...                      ...
# De Luca                                     0.0                      0.0
# Voelkerling Persson                         0.0                      0.0
# Montevago                                   0.0                      0.0
# Krollis                                     0.0                      0.0
# Vivaldo                                     0.0                      0.0
#
#                      gk_crosses  gk_crosses_stopped  gk_crosses_stopped_pct  \
# name
# Meret                     213.0                 6.0                     2.8
# Provedel                  266.0                 7.0                     2.6
# Vicario                   412.0                25.0                     6.1
# Szczesny                  159.0                 4.0                     2.5
# Falcone                   302.0                13.0                     4.3
# ...                         ...                 ...                     ...
# De Luca                     0.0                 0.0                     0.0
# Voelkerling Persson         0.0                 0.0                     0.0
# Montevago                   0.0                 0.0                     0.0
# Krollis                     0.0                 0.0                     0.0
# Vivaldo                     0.0                 0.0                     0.0
#
#                      gk_def_actions_outside_pen_area  \
# name
# Meret                                           24.0
# Provedel                                        37.0
# Vicario                                         10.0
# Szczesny                                        10.0
# Falcone                                         20.0
# ...                                              ...
# De Luca                                          0.0
# Voelkerling Persson                              0.0
# Montevago                                        0.0
# Krollis                                          0.0
# Vivaldo                                          0.0
#
#                      gk_def_actions_outside_pen_area_per90  \
# name
# Meret                                                 1.20
# Provedel                                              1.86
# Vicario                                               0.50
# Szczesny                                              0.74
# Falcone                                               1.00
# ...                                                    ...
# De Luca                                               0.00
# Voelkerling Persson                                   0.00
# Montevago                                             0.00
# Krollis                                               0.00
# Vivaldo                                               0.00
#
#                      gk_avg_distance_def_actions  vote_avg  vote_std
# name
# Meret                                       17.2  6.275000  0.486698
# Provedel                                    18.0  6.225000  0.334477
# Vicario                                     10.7  6.450000  0.384057
# Szczesny                                    15.1  6.035714  0.351745
# Falcone                                     12.5  6.325000  0.363146
# ...                                          ...       ...       ...
# De Luca                                      0.0  5.881660  0.665426
# Voelkerling Persson                          0.0  6.227492  0.259439
# Montevago                                    0.0  5.956291  0.615163
# Krollis                                      0.0  5.699562  0.705829
# Vivaldo                                      0.0  5.888111  0.648879
#
# [543 rows x 169 columns]

# %% [markdown]
# Function for merging match data (player, team, opponent team)

# %%
def player_match_data(player, pteam, oppteam):
    if(not(player in players.index)):
        return None
    
    pdata = players.loc[[player]]
    
    pteam_stats = team_data.loc[[pteam]].rename(index = {pteam : player})
    
    oppteam_stats = team_data.loc[[oppteam]].rename(index = {oppteam : player})
    
    oppteam_stats = oppteam_stats.rename(lambda x: 'opp_' + x, axis='columns')
    
    out = pd.concat([pdata, pteam_stats, oppteam_stats], axis = 1)
    
    return(out)

# %% [markdown]
# Output to excel file data for a player.
#
# The file is copied and there the desired features are manually selected and printed.

# %%
test = player_match_data('Frattesi', 'Sassuolo', 'Atalanta')
test.to_excel('tmp/playermatchdata.xlsx')

test
# Out:
#           Unnamed: 0    id  r      team   surname initial  fb_ID     age  \
# Frattesi         274  2848  C  Sassuolo  Frattesi     NaN    187  23-105
#
#           birth_year  games  ...  opp_vs_team_fouls  opp_vs_team_fouled  \
# Frattesi        1999     20  ...              220.0               232.0
#
#           opp_vs_team_offsides  opp_vs_team_pens_won  \
# Frattesi                  26.0                   1.0
#
#           opp_vs_team_pens_conceded  opp_vs_team_own_goals  \
# Frattesi                        8.0                    1.0
#
#           opp_vs_team_ball_recoveries  opp_vs_team_aerials_won  \
# Frattesi                       1214.0                    248.0
#
#           opp_vs_team_aerials_lost  opp_vs_team_aerials_won_pct
# Frattesi                     303.0                         45.0
#
# [1 rows x 811 columns]

# %%
pteam = 'Sassuolo'
pteam_stats = team_data.loc[[pteam]]
pteam_stats.index[0]
# Out:
# 'Sassuolo'

# %%
rx = pd.read_excel('tmp/playermatchdata_sel.xlsx', index_col = 0, header = None)   

out = list()

for i in range(1, rx.shape[1]):
        if(rx[i][2] == "x"):
            out.append(rx[i][0])
            
out
# Out:
# ['r',
#  'fb_ID',
#  'games',
#  'games_starts',
#  'minutes',
#  'goals',
#  'assists',
#  'cards_yellow',
#  'cards_red',
#  'xg',
#  'npxg',
#  'shots_on_target',
#  'shots_on_target_pct',
#  'goals_per_shot',
#  'goals_per_shot_on_target',
#  'passes_completed',
#  'passes_pct',
#  'passes_into_final_third',
#  'passes_into_penalty_area',
#  'progressive_passes',
#  'passes_live',
#  'passes_dead',
#  'through_balls',
#  'passes_switches',
#  'crosses',
#  'corner_kicks',
#  'dribble_tackles',
#  'dribbles_vs',
#  'dribble_tackles_pct',
#  'dribbled_past',
#  'blocks',
#  'blocked_shots',
#  'blocked_passes',
#  'interceptions',
#  'clearances',
#  'errors',
#  'touches',
#  'touches_def_pen_area',
#  'touches_def_3rd',
#  'touches_mid_3rd',
#  'touches_att_3rd',
#  'touches_att_pen_area',
#  'touches_live_ball',
#  'dribbles_completed',
#  'dribbles',
#  'dribbles_completed_pct',
#  'carries',
#  'progressive_carries',
#  'carries_into_final_third',
#  'carries_into_penalty_area',
#  'passes_received',
#  'miscontrols',
#  'dispossessed',
#  'fouls',
#  'fouled',
#  'aerials_won',
#  'aerials_lost',
#  'aerials_won_pct',
#  'team_possession',
#  'team_goals_assists_per90',
#  'team_goals_pens_per90',
#  'team_goals_assists_pens_per90',
#  'team_xg_per90',
#  'team_gk_goals_against_per90',
#  'team_gk_save_pct',
#  'team_gk_clean_sheets_pct',
#  'team_passes_pct',
#  'team_passes_pct_medium',
#  'team_passes_pct_long',
#  'team_sca_per90',
#  'team_gca_per90',
#  'team_dribble_tackles_pct',
#  'team_aerials_won_pct',
#  'vs_team_possession',
#  'vs_team_goals_per90',
#  'vs_team_assists_per90',
#  'vs_team_xg_per90',
#  'vs_team_gk_save_pct',
#  'vs_team_gk_clean_sheets_pct',
#  'vs_team_gk_pct_passes_launched',
#  'vs_team_gk_crosses_stopped_pct',
#  'vs_team_shots_on_target_per90',
#  'vs_team_passes_pct',
#  'vs_team_passes_pct_short',
#  'vs_team_passes_pct_medium',
#  'vs_team_passes_pct_long',
#  'vs_team_sca_per90',
#  'vs_team_gca_per90',
#  'vs_team_dribble_tackles_pct',
#  'vs_team_dribbles_completed_pct',
#  'vs_team_aerials_won_pct']

# %% [markdown]
# Define and select the dataset features: abs features and rel features.
#
# Rel features are divided by the player minutes played.
#
# Rel features (game corrected) are divided by the player number of games instead of minutes.
# For example, a player who plays 20 minutes and scores, would be to match for stats averaging. It is better to consider the goals made per match.

# %%
features_abs = ['r',
 'games',
 'games_starts',                
 'minutes',
 'shots_on_target_pct',
 'goals_per_shot',
 'goals_per_shot_on_target',
 'passes_pct',
 'dribble_tackles_pct',
 'dribbles_completed_pct',
 'aerials_won_pct',
 'team_possession',
 'team_goals_assists_per90',
 'team_goals_pens_per90',
 'team_goals_assists_pens_per90',
 'team_xg_per90',
 'team_gk_goals_against_per90',
 'team_gk_save_pct',
 'team_gk_clean_sheets_pct',
 'team_passes_pct',
 'team_passes_pct_medium',
 'team_passes_pct_long',
 'team_sca_per90',
 'team_gca_per90',
 'team_dribble_tackles_pct',
 'team_aerials_won_pct',
 'vs_team_possession',
 'vs_team_goals_per90',
 'vs_team_assists_per90',
 'vs_team_xg_per90',
 'vs_team_gk_save_pct',
 'vs_team_gk_clean_sheets_pct',
 'vs_team_gk_pct_passes_launched',
 'vs_team_gk_crosses_stopped_pct',
 'vs_team_shots_on_target_per90',
 'vs_team_passes_pct',
 'vs_team_passes_pct_short',
 'vs_team_passes_pct_medium',
 'vs_team_passes_pct_long',
 'vs_team_sca_per90',
 'vs_team_gca_per90',
 'vs_team_dribble_tackles_pct',
 'vs_team_dribbles_completed_pct',
 'vs_team_aerials_won_pct',
 'opp_team_possession',
 'opp_team_goals_assists_per90',
 'opp_team_goals_pens_per90',
 'opp_team_goals_assists_pens_per90',
 'opp_team_xg_per90',
 'opp_team_gk_goals_against_per90',
 'opp_team_gk_save_pct',
 'opp_team_gk_clean_sheets_pct',
 'opp_team_passes_pct',
 'opp_team_passes_pct_medium',
 'opp_team_passes_pct_long',
 'opp_team_sca_per90',
 'opp_team_gca_per90',
 'opp_team_dribble_tackles_pct',
 'opp_team_aerials_won_pct',
 'opp_vs_team_possession',
 'opp_vs_team_goals_per90',
 'opp_vs_team_assists_per90',
 'opp_vs_team_xg_per90',
 'opp_vs_team_gk_save_pct',
 'opp_vs_team_gk_clean_sheets_pct',
 'opp_vs_team_gk_pct_passes_launched',
 'opp_vs_team_gk_crosses_stopped_pct',
 'opp_vs_team_shots_on_target_per90',
 'opp_vs_team_passes_pct',
 'opp_vs_team_passes_pct_short',
 'opp_vs_team_passes_pct_medium',
 'opp_vs_team_passes_pct_long',
 'opp_vs_team_sca_per90',
 'opp_vs_team_gca_per90',
 'opp_vs_team_dribble_tackles_pct',
 'opp_vs_team_dribbles_completed_pct',
 'opp_vs_team_aerials_won_pct',
                
 'vote_avg',
 'vote_std']

features_rel = [
 'goals',
 'assists',
 'cards_yellow',
 'cards_red',
 'xg',
 'npxg',
 'shots_on_target',
 'passes_completed',
 'passes_into_final_third',
 'passes_into_penalty_area',
 'progressive_passes',
 'passes_live',
 'passes_dead',
 'through_balls',
 'passes_switches',
 'crosses',
 'corner_kicks',
 'dribble_tackles',
 'dribbles_vs',
 'dribbled_past',
 'blocks',
 'blocked_shots',
 'blocked_passes',
 'interceptions',
 'clearances',
 'errors',
 'touches',
 'touches_def_pen_area',
 'touches_def_3rd',
 'touches_mid_3rd',
 'touches_att_3rd',
 'touches_att_pen_area',
 'touches_live_ball',
 'dribbles_completed',
 'dribbles',
 'passes_received',
 'miscontrols',
 'dispossessed',
 'fouls',
 'fouled',
 'aerials_won',
 'aerials_lost',
 'carries',
 'progressive_carries',
 'carries_into_final_third',
 'carries_into_penalty_area']

features_rel_gamecorr = [
    'goals',
    'assists',
    'xg',
    'npxg',
    'cards_yellow',
    'cards_red'
]

# %% [markdown]
# Function for merging match data (player, team, opponent team) and select only the desired features, applying the desired corrections.

# %%
def player_match_data_ext(player, pteam, oppteam):
    pdata = player_match_data(player, pteam, oppteam)
    
    if(not isinstance(pdata, pd.DataFrame)):
        return None
    
    out = pd.concat([pdata[features_abs], pdata[features_rel]], axis = 1)
    
    out[features_rel] = out[features_rel] / max(pdata['minutes'][0], 1)
    
    out[features_rel_gamecorr] = out[features_rel_gamecorr] * (pdata['minutes'][0] / max(pdata['games'][0], 1) / 90)
    
    return out

# %% [markdown]
# Columns variable for the match data, to be then added to votes data.

# %%
test = player_match_data_ext('Frattesi', 'Sassuolo', 'Atalanta')

add_columns = test.columns

test
# Out:
#           r  games  games_starts  minutes  shots_on_target_pct  \
# Frattesi  C     20            20     1636                 50.0
#
#           goals_per_shot  goals_per_shot_on_target  passes_pct  \
# Frattesi            0.14                      0.28        77.7
#
#           dribble_tackles_pct  dribbles_completed_pct  ...  miscontrols  \
# Frattesi                 58.3                    52.2  ...     0.017726
#
#           dispossessed     fouls    fouled  aerials_won  aerials_lost  \
# Frattesi      0.017115  0.015892  0.022005      0.00978      0.007335
#
#            carries  progressive_carries  carries_into_final_third  \
# Frattesi  0.271394             0.026284                  0.018337
#
#           carries_into_penalty_area
# Frattesi                   0.008557
#
# [1 rows x 125 columns]

# %% [markdown]
# Load Fantacalcio votes data for each match of the season.

# %%
votes = pd.read_excel('mid_outputs/players_votes.xlsx', index_col = 0)
votes
# Out:
#       matchday       player      team    oppteam  home  vote  goals  assists  \
# 0            1        Musso  Atalanta  Sampdoria     0   6.0      0        0
# 1            1        Toloi  Atalanta  Sampdoria     0   7.0      1        0
# 2            1     Djimsiti  Atalanta  Sampdoria     0   6.0      0        0
# 3            1     Hateboer  Atalanta  Sampdoria     0   6.0      0        0
# 4            1        Okoli  Atalanta  Sampdoria     0   5.5      0        0
# ...        ...          ...       ...        ...   ...   ...    ...      ...
# 5710        20  Sulemana I.    Verona    Udinese     0   5.5      0        0
# 5711        20      Lasagna    Verona    Udinese     0   5.5      0        0
# 5712        20        Braaf    Verona    Udinese     0   5.0      0        0
# 5713        20       Djuric    Verona    Udinese     0   6.0      0        0
# 5714        20       Ngonge    Verona    Udinese     0   6.0      0        0
#
#       cards_malus  fantavote
# 0             0.5        5.5
# 1             0.0       10.0
# 2             0.0        6.0
# 3             0.5        5.5
# 4             0.5        5.0
# ...           ...        ...
# 5710          0.5        5.0
# 5711          0.0        5.5
# 5712          0.0        5.0
# 5713          0.0        6.0
# 5714          0.0        6.0
#
# [5715 rows x 10 columns]

# %% [markdown]
# Merge votes data with match data for the player.

# %%
db = votes.copy()

delta = pd.DataFrame(columns = add_columns)

for i in range(db.shape[0]):
    ext_data = player_match_data_ext(db['player'][i], db['team'][i], db['oppteam'][i])
    
    if(not isinstance(ext_data, pd.DataFrame)):
        continue
    
    ext_data = ext_data.rename(index = {db['player'][i] : i})
    
    delta = pd.concat([delta, ext_data], axis = 0)
    
    if(i % 100 == 0):
        print(i)
    
db = pd.concat([db, delta], axis = 1)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 700
# 800
# 900
# 1000
# 1100
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700

# %%
db
# Out:
#       matchday       player      team    oppteam  home  vote  goals  assists  \
# 0            1        Musso  Atalanta  Sampdoria     0   6.0      0        0
# 1            1        Toloi  Atalanta  Sampdoria     0   7.0      1        0
# 2            1     Djimsiti  Atalanta  Sampdoria     0   6.0      0        0
# 3            1     Hateboer  Atalanta  Sampdoria     0   6.0      0        0
# 4            1        Okoli  Atalanta  Sampdoria     0   5.5      0        0
# ...        ...          ...       ...        ...   ...   ...    ...      ...
# 5710        20  Sulemana I.    Verona    Udinese     0   5.5      0        0
# 5711        20      Lasagna    Verona    Udinese     0   5.5      0        0
# 5712        20        Braaf    Verona    Udinese     0   5.0      0        0
# 5713        20       Djuric    Verona    Udinese     0   6.0      0        0
# 5714        20       Ngonge    Verona    Udinese     0   6.0      0        0
#
#       cards_malus  fantavote  ... miscontrols dispossessed     fouls  \
# 0             0.5        5.5  ...    0.000000     0.000000  0.000000
# 1             0.0       10.0  ...    0.007886     0.001577  0.006309
# 2             0.0        6.0  ...    0.002257     0.006772  0.006772
# 3             0.5        5.5  ...    0.006304     0.004728  0.012608
# 4             0.5        5.0  ...    0.013018     0.003550  0.015385
# ...           ...        ...  ...         ...          ...       ...
# 5710          0.5        5.0  ...    0.017045     0.014205  0.019886
# 5711          0.0        5.5  ...    0.035088     0.025341  0.019493
# 5712          0.0        5.0  ...    0.041667     0.069444  0.027778
# 5713          0.0        6.0  ...    0.027027     0.005690  0.021337
# 5714          0.0        6.0  ...    0.000000     0.055556  0.000000
#
#         fouled  aerials_won  aerials_lost   carries  progressive_carries  \
# 0     0.000000     0.000000      0.000000  0.000000             0.000000
# 1     0.006309     0.014984      0.011830  0.364353             0.008675
# 2     0.004515     0.020316      0.015801  0.483070             0.004515
# 3     0.001576     0.016548      0.011032  0.284476             0.012608
# 4     0.008284     0.047337      0.027219  0.269822             0.002367
# ...        ...          ...           ...       ...                  ...
# 5710  0.005682     0.017045      0.022727  0.221591             0.008523
# 5711  0.015595     0.006823      0.030214  0.170565             0.024366
# 5712  0.000000     0.000000      0.027778  0.208333             0.013889
# 5713  0.019915     0.160740      0.039829  0.204836             0.001422
# 5714  0.000000     0.000000      0.111111  0.388889             0.111111
#
#       carries_into_final_third  carries_into_penalty_area
# 0                     0.000000                   0.000000
# 1                     0.016562                   0.000000
# 2                     0.004515                   0.000000
# 3                     0.008668                   0.000788
# 4                     0.004734                   0.000000
# ...                        ...                        ...
# 5710                  0.011364                   0.000000
# 5711                  0.013645                   0.009747
# 5712                  0.000000                   0.000000
# 5713                  0.002845                   0.002845
# 5714                  0.000000                   0.111111
#
# [5715 rows x 135 columns]

# %% [markdown]
# Remove undesired database entries.

# %%
db = db.drop(db[db.r == 'P'].index) # remove goalkeepers
db = db.drop(db[db.r != db.r].index) # remove non existing players (by searching NaN values)
db = db.drop(db[db.xg != db.xg].index)

# %%
db
# Out:
#       matchday       player      team    oppteam  home  vote  goals  assists  \
# 1            1        Toloi  Atalanta  Sampdoria     0   7.0      1        0
# 2            1     Djimsiti  Atalanta  Sampdoria     0   6.0      0        0
# 3            1     Hateboer  Atalanta  Sampdoria     0   6.0      0        0
# 4            1        Okoli  Atalanta  Sampdoria     0   5.5      0        0
# 5            1       Zortea  Atalanta  Sampdoria     0   6.0      0        0
# ...        ...          ...       ...        ...   ...   ...    ...      ...
# 5710        20  Sulemana I.    Verona    Udinese     0   5.5      0        0
# 5711        20      Lasagna    Verona    Udinese     0   5.5      0        0
# 5712        20        Braaf    Verona    Udinese     0   5.0      0        0
# 5713        20       Djuric    Verona    Udinese     0   6.0      0        0
# 5714        20       Ngonge    Verona    Udinese     0   6.0      0        0
#
#       cards_malus  fantavote  ... miscontrols dispossessed     fouls  \
# 1             0.0       10.0  ...    0.007886     0.001577  0.006309
# 2             0.0        6.0  ...    0.002257     0.006772  0.006772
# 3             0.5        5.5  ...    0.006304     0.004728  0.012608
# 4             0.5        5.0  ...    0.013018     0.003550  0.015385
# 5             0.5        5.5  ...    0.027027     0.009009  0.018018
# ...           ...        ...  ...         ...          ...       ...
# 5710          0.5        5.0  ...    0.017045     0.014205  0.019886
# 5711          0.0        5.5  ...    0.035088     0.025341  0.019493
# 5712          0.0        5.0  ...    0.041667     0.069444  0.027778
# 5713          0.0        6.0  ...    0.027027     0.005690  0.021337
# 5714          0.0        6.0  ...    0.000000     0.055556  0.000000
#
#         fouled  aerials_won  aerials_lost   carries  progressive_carries  \
# 1     0.006309     0.014984      0.011830  0.364353             0.008675
# 2     0.004515     0.020316      0.015801  0.483070             0.004515
# 3     0.001576     0.016548      0.011032  0.284476             0.012608
# 4     0.008284     0.047337      0.027219  0.269822             0.002367
# 5     0.000000     0.022523      0.004505  0.351351             0.049550
# ...        ...          ...           ...       ...                  ...
# 5710  0.005682     0.017045      0.022727  0.221591             0.008523
# 5711  0.015595     0.006823      0.030214  0.170565             0.024366
# 5712  0.000000     0.000000      0.027778  0.208333             0.013889
# 5713  0.019915     0.160740      0.039829  0.204836             0.001422
# 5714  0.000000     0.000000      0.111111  0.388889             0.111111
#
#       carries_into_final_third  carries_into_penalty_area
# 1                     0.016562                   0.000000
# 2                     0.004515                   0.000000
# 3                     0.008668                   0.000788
# 4                     0.004734                   0.000000
# 5                     0.031532                   0.009009
# ...                        ...                        ...
# 5710                  0.011364                   0.000000
# 5711                  0.013645                   0.009747
# 5712                  0.000000                   0.000000
# 5713                  0.002845                   0.002845
# 5714                  0.000000                   0.111111
#
# [5069 rows x 135 columns]

# %% [markdown]
# Save outfield players database to file.

# %%
db.to_excel('mid_outputs/database_entries.xlsx')

# %% [markdown]
# Do the same process for goalkeepers, generating a different database.

# %%
for i in range(db.columns.shape[0]):
    print(str(i) + " - " + str(db.columns[i]))
# Out:
# 0 - matchday
# 1 - player
# 2 - team
# 3 - oppteam
# 4 - home
# 5 - vote
# 6 - goals
# 7 - assists
# 8 - cards_malus
# 9 - fantavote
# 10 - r
# 11 - games
# 12 - games_starts
# 13 - minutes
# 14 - shots_on_target_pct
# 15 - goals_per_shot
# 16 - goals_per_shot_on_target
# 17 - passes_pct
# 18 - dribble_tackles_pct
# 19 - dribbles_completed_pct
# 20 - aerials_won_pct
# 21 - team_possession
# 22 - team_goals_assists_per90
# 23 - team_goals_pens_per90
# 24 - team_goals_assists_pens_per90
# 25 - team_xg_per90
# 26 - team_gk_goals_against_per90
# 27 - team_gk_save_pct
# 28 - team_gk_clean_sheets_pct
# 29 - team_passes_pct
# 30 - team_passes_pct_medium
# 31 - team_passes_pct_long
# 32 - team_sca_per90
# 33 - team_gca_per90
# 34 - team_dribble_tackles_pct
# 35 - team_aerials_won_pct
# 36 - vs_team_possession
# 37 - vs_team_goals_per90
# 38 - vs_team_assists_per90
# 39 - vs_team_xg_per90
# 40 - vs_team_gk_save_pct
# 41 - vs_team_gk_clean_sheets_pct
# 42 - vs_team_gk_pct_passes_launched
# 43 - vs_team_gk_crosses_stopped_pct
# 44 - vs_team_shots_on_target_per90
# 45 - vs_team_passes_pct
# 46 - vs_team_passes_pct_short
# 47 - vs_team_passes_pct_medium
# 48 - vs_team_passes_pct_long
# 49 - vs_team_sca_per90
# 50 - vs_team_gca_per90
# 51 - vs_team_dribble_tackles_pct
# 52 - vs_team_dribbles_completed_pct
# 53 - vs_team_aerials_won_pct
# 54 - opp_team_possession
# 55 - opp_team_goals_assists_per90
# 56 - opp_team_goals_pens_per90
# 57 - opp_team_goals_assists_pens_per90
# 58 - opp_team_xg_per90
# 59 - opp_team_gk_goals_against_per90
# 60 - opp_team_gk_save_pct
# 61 - opp_team_gk_clean_sheets_pct
# 62 - opp_team_passes_pct
# 63 - opp_team_passes_pct_medium
# 64 - opp_team_passes_pct_long
# 65 - opp_team_sca_per90
# 66 - opp_team_gca_per90
# 67 - opp_team_dribble_tackles_pct
# 68 - opp_team_aerials_won_pct
# 69 - opp_vs_team_possession
# 70 - opp_vs_team_goals_per90
# 71 - opp_vs_team_assists_per90
# 72 - opp_vs_team_xg_per90
# 73 - opp_vs_team_gk_save_pct
# 74 - opp_vs_team_gk_clean_sheets_pct
# 75 - opp_vs_team_gk_pct_passes_launched
# 76 - opp_vs_team_gk_crosses_stopped_pct
# 77 - opp_vs_team_shots_on_target_per90
# 78 - opp_vs_team_passes_pct
# 79 - opp_vs_team_passes_pct_short
# 80 - opp_vs_team_passes_pct_medium
# 81 - opp_vs_team_passes_pct_long
# 82 - opp_vs_team_sca_per90
# 83 - opp_vs_team_gca_per90
# 84 - opp_vs_team_dribble_tackles_pct
# 85 - opp_vs_team_dribbles_completed_pct
# 86 - opp_vs_team_aerials_won_pct
# 87 - vote_avg
# 88 - vote_std
# 89 - goals
# 90 - assists
# 91 - cards_yellow
# 92 - cards_red
# 93 - xg
# 94 - npxg
# 95 - shots_on_target
# 96 - passes_completed
# 97 - passes_into_final_third
# 98 - passes_into_penalty_area
# 99 - progressive_passes
# 100 - passes_live
# 101 - passes_dead
# 102 - through_balls
# 103 - passes_switches
# 104 - crosses
# 105 - corner_kicks
# 106 - dribble_tackles
# 107 - dribbles_vs
# 108 - dribbled_past
# 109 - blocks
# 110 - blocked_shots
# 111 - blocked_passes
# 112 - interceptions
# 113 - clearances
# 114 - errors
# 115 - touches
# 116 - touches_def_pen_area
# 117 - touches_def_3rd
# 118 - touches_mid_3rd
# 119 - touches_att_3rd
# 120 - touches_att_pen_area
# 121 - touches_live_ball
# 122 - dribbles_completed
# 123 - dribbles
# 124 - passes_received
# 125 - miscontrols
# 126 - dispossessed
# 127 - fouls
# 128 - fouled
# 129 - aerials_won
# 130 - aerials_lost

# %%
rx = pd.read_excel('tmp/playermatchdata_sel_gk.xlsx', index_col = 0, header = None)   

out = list()

for i in range(1, rx.shape[1]):
        if(rx[i][2] == "x"):
            out.append(rx[i][0])
            
out
# Out:
# ['r',
#  'fb_ID',
#  'gk_games',
#  'gk_games_starts',
#  'gk_minutes',
#  'gk_goals_against_per90',
#  'gk_shots_on_target_against',
#  'gk_saves',
#  'gk_save_pct',
#  'gk_clean_sheets_pct',
#  'gk_free_kick_goals_against',
#  'gk_corner_kick_goals_against',
#  'gk_own_goals_against',
#  'gk_psxg',
#  'gk_psnpxg_per_shot_on_target_against',
#  'gk_psxg_net',
#  'gk_psxg_net_per90',
#  'gk_passes_completed_launched',
#  'gk_passes_launched',
#  'gk_passes_pct_launched',
#  'gk_passes',
#  'gk_passes_throws',
#  'gk_pct_passes_launched',
#  'gk_passes_length_avg',
#  'gk_goal_kicks',
#  'gk_pct_goal_kicks_launched',
#  'gk_goal_kick_length_avg',
#  'gk_crosses',
#  'gk_crosses_stopped',
#  'gk_crosses_stopped_pct',
#  'gk_def_actions_outside_pen_area',
#  'gk_def_actions_outside_pen_area_per90',
#  'gk_avg_distance_def_actions',
#  'team_possession',
#  'team_goals_assists_per90',
#  'team_goals_pens_per90',
#  'team_goals_assists_pens_per90',
#  'team_xg_per90',
#  'team_gk_goals_against_per90',
#  'team_gk_save_pct',
#  'team_gk_clean_sheets_pct',
#  'team_passes_pct',
#  'team_passes_pct_medium',
#  'team_passes_pct_long',
#  'team_sca_per90',
#  'team_gca_per90',
#  'team_dribble_tackles_pct',
#  'team_aerials_won_pct',
#  'vs_team_possession',
#  'vs_team_goals_per90',
#  'vs_team_assists_per90',
#  'vs_team_xg_per90',
#  'vs_team_gk_save_pct',
#  'vs_team_gk_clean_sheets_pct',
#  'vs_team_gk_pct_passes_launched',
#  'vs_team_gk_crosses_stopped_pct',
#  'vs_team_shots_on_target_per90',
#  'vs_team_passes_pct',
#  'vs_team_passes_pct_short',
#  'vs_team_passes_pct_medium',
#  'vs_team_passes_pct_long',
#  'vs_team_sca_per90',
#  'vs_team_gca_per90',
#  'vs_team_dribble_tackles_pct',
#  'vs_team_dribbles_completed_pct',
#  'vs_team_aerials_won_pct']

# %%
features_abs_gk = [
 'gk_games',
 'gk_games_starts',
 'gk_minutes',
 'gk_goals_against_per90', 
 'gk_save_pct',
 'gk_clean_sheets_pct',
 'gk_psxg_net_per90',
 'gk_passes_pct_launched',
 'gk_pct_passes_launched',
 'gk_passes_length_avg',
 'gk_pct_goal_kicks_launched',
 'gk_goal_kick_length_avg',
 'gk_crosses_stopped_pct',
 'gk_def_actions_outside_pen_area_per90',
 'gk_avg_distance_def_actions',
    
 'team_possession',
 'team_goals_assists_per90',
 'team_goals_pens_per90',
 'team_goals_assists_pens_per90',
 'team_xg_per90',
 'team_gk_goals_against_per90',
 'team_gk_save_pct',
 'team_gk_clean_sheets_pct',
 'team_passes_pct',
 'team_passes_pct_medium',
 'team_passes_pct_long',
 'team_sca_per90',
 'team_gca_per90',
 'team_dribble_tackles_pct',
 'team_aerials_won_pct',
 'vs_team_possession',
 'vs_team_goals_per90',
 'vs_team_assists_per90',
 'vs_team_xg_per90',
 'vs_team_gk_save_pct',
 'vs_team_gk_clean_sheets_pct',
 'vs_team_gk_pct_passes_launched',
 'vs_team_gk_crosses_stopped_pct',
 'vs_team_shots_on_target_per90',
 'vs_team_passes_pct',
 'vs_team_passes_pct_short',
 'vs_team_passes_pct_medium',
 'vs_team_passes_pct_long',
 'vs_team_sca_per90',
 'vs_team_gca_per90',
 'vs_team_dribble_tackles_pct',
 'vs_team_dribbles_completed_pct',
 'vs_team_aerials_won_pct',
 'opp_team_possession',
 'opp_team_goals_assists_per90',
 'opp_team_goals_pens_per90',
 'opp_team_goals_assists_pens_per90',
 'opp_team_xg_per90',
 'opp_team_gk_goals_against_per90',
 'opp_team_gk_save_pct',
 'opp_team_gk_clean_sheets_pct',
 'opp_team_passes_pct',
 'opp_team_passes_pct_medium',
 'opp_team_passes_pct_long',
 'opp_team_sca_per90',
 'opp_team_gca_per90',
 'opp_team_dribble_tackles_pct',
 'opp_team_aerials_won_pct',
 'opp_vs_team_possession',
 'opp_vs_team_goals_per90',
 'opp_vs_team_assists_per90',
 'opp_vs_team_xg_per90',
 'opp_vs_team_gk_save_pct',
 'opp_vs_team_gk_clean_sheets_pct',
 'opp_vs_team_gk_pct_passes_launched',
 'opp_vs_team_gk_crosses_stopped_pct',
 'opp_vs_team_shots_on_target_per90',
 'opp_vs_team_passes_pct',
 'opp_vs_team_passes_pct_short',
 'opp_vs_team_passes_pct_medium',
 'opp_vs_team_passes_pct_long',
 'opp_vs_team_sca_per90',
 'opp_vs_team_gca_per90',
 'opp_vs_team_dribble_tackles_pct',
 'opp_vs_team_dribbles_completed_pct',
 'opp_vs_team_aerials_won_pct',
                
 'vote_avg',
 'vote_std']

features_rel_gk = [
 'gk_shots_on_target_against',
 'gk_saves',
 'gk_free_kick_goals_against',
 'gk_corner_kick_goals_against',
 'gk_own_goals_against',
 'gk_psxg',
 'gk_psnpxg_per_shot_on_target_against',
 'gk_psxg_net',
 'gk_passes_completed_launched',
 'gk_passes_launched',
 'gk_passes',
 'gk_passes_throws',
 'gk_goal_kicks',
 'gk_crosses',
 'gk_crosses_stopped',
]

# %%
def player_match_data_ext_gk(player, pteam, oppteam):
    pdata = player_match_data(player, pteam, oppteam)
    
    if(not isinstance(pdata, pd.DataFrame)):
        return None
    
    if(pdata['gk_games'][0] <= 0):
        return None
    
    out = pd.concat([pdata[features_abs_gk], pdata[features_rel_gk]], axis = 1)
    
    out[features_rel_gk] = out[features_rel_gk] / max(pdata['minutes'][0], 1)

    return out

# %%
test = player_match_data_ext_gk('Consigli', 'Sassuolo', 'Atalanta')

add_columns_gk = test.columns

test
# Out:
#           gk_games  gk_games_starts  gk_minutes  gk_goals_against_per90  \
# Consigli      18.0             18.0      1620.0                    1.56
#
#           gk_save_pct  gk_clean_sheets_pct  gk_psxg_net_per90  \
# Consigli         56.9                 27.8              -0.29
#
#           gk_passes_pct_launched  gk_pct_passes_launched  \
# Consigli                    42.1                    31.8
#
#           gk_passes_length_avg  ...  gk_psxg  \
# Consigli                  34.6  ...     22.8
#
#           gk_psnpxg_per_shot_on_target_against  gk_psxg_net  \
# Consigli                                  0.36         -5.2
#
#           gk_passes_completed_launched  gk_passes_launched  gk_passes  \
# Consigli                         110.0               261.0      651.0
#
#           gk_passes_throws  gk_goal_kicks  gk_crosses  gk_crosses_stopped
# Consigli              95.0          167.0       236.0                14.0
#
# [1 rows x 98 columns]

# %%
db_gk = votes.copy()

delta = pd.DataFrame(columns = add_columns_gk)

for i in range(db_gk.shape[0]):
    ext_data = player_match_data_ext_gk(db_gk['player'][i], db_gk['team'][i], db_gk['oppteam'][i])
    
    if(i % 100 == 0):
        print(i)
        
    if(not isinstance(ext_data, pd.DataFrame)):
        continue
    
    ext_data = ext_data.rename(index = {db_gk['player'][i] : i})
    
    delta = pd.concat([delta, ext_data], axis = 0)
    
    
    
db_gk = pd.concat([db_gk, delta], axis = 1)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# 2500
# 2600
# 2700
# 2800
# 2900
# 3000
# 3100
# 3200
# 3300
# 3400
# 3500
# 3600
# 3700
# 3800
# 3900
# 4000
# 4100
# 4200
# 4300
# 4400
# 4500
# 4600
# 4700
# 4800
# 4900
# 5000
# 5100
# 5200
# 5300
# 5400
# 5500
# 5600
# 5700

# %%
db_gk
# Out:
#       matchday       player      team    oppteam  home  vote  goals  assists  \
# 0            1        Musso  Atalanta  Sampdoria     0   6.0      0        0
# 1            1        Toloi  Atalanta  Sampdoria     0   7.0      1        0
# 2            1     Djimsiti  Atalanta  Sampdoria     0   6.0      0        0
# 3            1     Hateboer  Atalanta  Sampdoria     0   6.0      0        0
# 4            1        Okoli  Atalanta  Sampdoria     0   5.5      0        0
# ...        ...          ...       ...        ...   ...   ...    ...      ...
# 5710        20  Sulemana I.    Verona    Udinese     0   5.5      0        0
# 5711        20      Lasagna    Verona    Udinese     0   5.5      0        0
# 5712        20        Braaf    Verona    Udinese     0   5.0      0        0
# 5713        20       Djuric    Verona    Udinese     0   6.0      0        0
# 5714        20       Ngonge    Verona    Udinese     0   6.0      0        0
#
#       cards_malus  fantavote  ...  gk_psxg  \
# 0             0.5        5.5  ...     11.1
# 1             0.0       10.0  ...      NaN
# 2             0.0        6.0  ...      NaN
# 3             0.5        5.5  ...      NaN
# 4             0.5        5.0  ...      NaN
# ...           ...        ...  ...      ...
# 5710          0.5        5.0  ...      NaN
# 5711          0.0        5.5  ...      NaN
# 5712          0.0        5.0  ...      NaN
# 5713          0.0        6.0  ...      NaN
# 5714          0.0        6.0  ...      NaN
#
#       gk_psnpxg_per_shot_on_target_against  gk_psxg_net  \
# 0                                     0.22         -1.9
# 1                                      NaN          NaN
# 2                                      NaN          NaN
# 3                                      NaN          NaN
# 4                                      NaN          NaN
# ...                                    ...          ...
# 5710                                   NaN          NaN
# 5711                                   NaN          NaN
# 5712                                   NaN          NaN
# 5713                                   NaN          NaN
# 5714                                   NaN          NaN
#
#       gk_passes_completed_launched  gk_passes_launched  gk_passes  \
# 0                             79.0               172.0      340.0
# 1                              NaN                 NaN        NaN
# 2                              NaN                 NaN        NaN
# 3                              NaN                 NaN        NaN
# 4                              NaN                 NaN        NaN
# ...                            ...                 ...        ...
# 5710                           NaN                 NaN        NaN
# 5711                           NaN                 NaN        NaN
# 5712                           NaN                 NaN        NaN
# 5713                           NaN                 NaN        NaN
# 5714                           NaN                 NaN        NaN
#
#       gk_passes_throws  gk_goal_kicks  gk_crosses  gk_crosses_stopped
# 0                 98.0           92.0       161.0                 8.0
# 1                  NaN            NaN         NaN                 NaN
# 2                  NaN            NaN         NaN                 NaN
# 3                  NaN            NaN         NaN                 NaN
# 4                  NaN            NaN         NaN                 NaN
# ...                ...            ...         ...                 ...
# 5710               NaN            NaN         NaN                 NaN
# 5711               NaN            NaN         NaN                 NaN
# 5712               NaN            NaN         NaN                 NaN
# 5713               NaN            NaN         NaN                 NaN
# 5714               NaN            NaN         NaN                 NaN
#
# [5715 rows x 108 columns]

# %%
db_gk = db_gk.drop(db_gk[db_gk.gk_games != db_gk.gk_games].index) # remove non extisting players

# %%
db_gk
# Out:
#       matchday               player        team    oppteam  home  vote  goals  \
# 0            1                Musso    Atalanta  Sampdoria     0   6.0      0
# 15           1            Skorupski     Bologna      Lazio     0   6.5     -2
# 44           1              Vicario      Empoli     Spezia     0   5.5     -1
# 57           1              Gollini  Fiorentina  Cremonese     1   5.0     -2
# 71           1           Handanovic       Inter      Lecce     0   6.5     -1
# ...        ...                  ...         ...        ...   ...   ...    ...
# 5645        20             Consigli    Sassuolo      Milan     0   6.0     -2
# 5658        20            Dragowski      Spezia    Bologna     0   6.5     -2
# 5673        20  Milinkovic-Savic V.      Torino     Empoli     0   5.5     -2
# 5688        20            Silvestri     Udinese     Verona     1   6.0     -1
# 5700        20             Montipo'      Verona    Udinese     0   6.5     -1
#
#       assists  cards_malus  fantavote  ...  gk_psxg  \
# 0           0          0.5        5.5  ...    11.10
# 15          0          0.0        4.5  ...    28.70
# 44          0          0.0        4.5  ...    25.00
# 57          0          0.0        3.0  ...     9.15
# 71          0          0.0        5.5  ...    10.60
# ...       ...          ...        ...  ...      ...
# 5645        0          0.0        4.0  ...    22.80
# 5658        0          0.0        4.5  ...    26.00
# 5673        0          0.0        3.5  ...    21.30
# 5688        0          0.0        5.0  ...    22.60
# 5700        0          0.0        5.5  ...    26.80
#
#       gk_psnpxg_per_shot_on_target_against  gk_psxg_net  \
# 0                                    0.220        -1.90
# 15                                   0.280         0.70
# 44                                   0.270         1.00
# 57                                   0.245         0.65
# 71                                   0.300        -1.40
# ...                                    ...          ...
# 5645                                 0.360        -5.20
# 5658                                 0.280        -3.00
# 5673                                 0.240        -0.70
# 5688                                 0.320         1.60
# 5700                                 0.250        -4.20
#
#       gk_passes_completed_launched  gk_passes_launched  gk_passes  \
# 0                             79.0               172.0      340.0
# 15                            86.0               220.0      545.0
# 44                           101.0               307.0      740.0
# 57                            23.5                66.5      279.5
# 71                            27.0                52.0      266.0
# ...                            ...                 ...        ...
# 5645                         110.0               261.0      651.0
# 5658                          85.0               255.0      479.0
# 5673                         145.0               510.0      763.0
# 5688                          83.0               211.0      432.0
# 5700                         187.0               374.0      462.0
#
#       gk_passes_throws  gk_goal_kicks  gk_crosses  gk_crosses_stopped
# 0                 98.0           92.0       161.0                 8.0
# 15               116.0          141.0       280.0                18.0
# 44               112.0          107.0       412.0                25.0
# 57                44.5           64.5       118.5                 3.5
# 71                46.0           45.0        79.0                 2.0
# ...                ...            ...         ...                 ...
# 5645              95.0          167.0       236.0                14.0
# 5658              87.0          106.0       235.0                 9.0
# 5673              87.0          149.0       244.0                18.0
# 5688              74.0          154.0       263.0                 5.0
# 5700              64.0          159.0       279.0                12.0
#
# [395 rows x 108 columns]

# %% [markdown]
# Save goalkeepers players database to file.

# %%
db_gk.to_excel('mid_outputs/database_entries_gk.xlsx')

# %%
for i in range(db_gk.columns.shape[0]):
    print(str(i) + " - " + str(db_gk.columns[i]))
# Out:
# 0 - matchday
# 1 - player
# 2 - team
# 3 - oppteam
# 4 - home
# 5 - vote
# 6 - goals
# 7 - assists
# 8 - cards_malus
# 9 - fantavote
# 10 - gk_games
# 11 - gk_games_starts
# 12 - gk_minutes
# 13 - gk_goals_against_per90
# 14 - gk_save_pct
# 15 - gk_clean_sheets_pct
# 16 - gk_psxg_net_per90
# 17 - gk_passes_pct_launched
# 18 - gk_pct_passes_launched
# 19 - gk_passes_length_avg
# 20 - gk_pct_goal_kicks_launched
# 21 - gk_goal_kick_length_avg
# 22 - gk_crosses_stopped_pct
# 23 - gk_def_actions_outside_pen_area_per90
# 24 - gk_avg_distance_def_actions
# 25 - team_possession
# 26 - team_goals_assists_per90
# 27 - team_goals_pens_per90
# 28 - team_goals_assists_pens_per90
# 29 - team_xg_per90
# 30 - team_gk_goals_against_per90
# 31 - team_gk_save_pct
# 32 - team_gk_clean_sheets_pct
# 33 - team_passes_pct
# 34 - team_passes_pct_medium
# 35 - team_passes_pct_long
# 36 - team_sca_per90
# 37 - team_gca_per90
# 38 - team_dribble_tackles_pct
# 39 - team_aerials_won_pct
# 40 - vs_team_possession
# 41 - vs_team_goals_per90
# 42 - vs_team_assists_per90
# 43 - vs_team_xg_per90
# 44 - vs_team_gk_save_pct
# 45 - vs_team_gk_clean_sheets_pct
# 46 - vs_team_gk_pct_passes_launched
# 47 - vs_team_gk_crosses_stopped_pct
# 48 - vs_team_shots_on_target_per90
# 49 - vs_team_passes_pct
# 50 - vs_team_passes_pct_short
# 51 - vs_team_passes_pct_medium
# 52 - vs_team_passes_pct_long
# 53 - vs_team_sca_per90
# 54 - vs_team_gca_per90
# 55 - vs_team_dribble_tackles_pct
# 56 - vs_team_dribbles_completed_pct
# 57 - vs_team_aerials_won_pct
# 58 - opp_team_possession
# 59 - opp_team_goals_assists_per90
# 60 - opp_team_goals_pens_per90
# 61 - opp_team_goals_assists_pens_per90
# 62 - opp_team_xg_per90
# 63 - opp_team_gk_goals_against_per90
# 64 - opp_team_gk_save_pct
# 65 - opp_team_gk_clean_sheets_pct
# 66 - opp_team_passes_pct
# 67 - opp_team_passes_pct_medium
# 68 - opp_team_passes_pct_long
# 69 - opp_team_sca_per90
# 70 - opp_team_gca_per90
# 71 - opp_team_dribble_tackles_pct
# 72 - opp_team_aerials_won_pct
# 73 - opp_vs_team_possession
# 74 - opp_vs_team_goals_per90
# 75 - opp_vs_team_assists_per90
# 76 - opp_vs_team_xg_per90
# 77 - opp_vs_team_gk_save_pct
# 78 - opp_vs_team_gk_clean_sheets_pct
# 79 - opp_vs_team_gk_pct_passes_launched
# 80 - opp_vs_team_gk_crosses_stopped_pct
# 81 - opp_vs_team_shots_on_target_per90
# 82 - opp_vs_team_passes_pct
# 83 - opp_vs_team_passes_pct_short
# 84 - opp_vs_team_passes_pct_medium
# 85 - opp_vs_team_passes_pct_long
# 86 - opp_vs_team_sca_per90
# 87 - opp_vs_team_gca_per90
# 88 - opp_vs_team_dribble_tackles_pct
# 89 - opp_vs_team_dribbles_completed_pct
# 90 - opp_vs_team_aerials_won_pct
# 91 - vote_avg
# 92 - vote_std
# 93 - gk_shots_on_target_against
# 94 - gk_saves
# 95 - gk_free_kick_goals_against
# 96 - gk_corner_kick_goals_against
# 97 - gk_own_goals_against
# 98 - gk_psxg
# 99 - gk_psnpxg_per_shot_on_target_against
# 100 - gk_psxg_net
# 101 - gk_passes_completed_launched
# 102 - gk_passes_launched
# 103 - gk_passes
# 104 - gk_passes_throws
# 105 - gk_goal_kicks
# 106 - gk_crosses
# 107 - gk_crosses_stopped
